# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import nibabel as nib
from time import time
from xml.etree import ElementTree as ET
import os
import pandas as pd
import sys
import scipy
from scipy.interpolate import interp1d
from scipy.ndimage.filters import gaussian_filter
from scipy import signal
from scipy.ndimage.interpolation import shift
from numpy.linalg import *
from scipy.linalg import toeplitz
import scipy.linalg as sl
from sklearn.cluster import KMeans
import skimage
from sklearn.linear_model import LassoLarsIC
import smtplib
from email.mime.text import MIMEText
import re
import traceback
from IPython.core.magic import register_cell_magic
from functools import wraps

sys.path.insert(0, '/home/users/brezovec/.local/lib/python3.6/site-packages/lib/python/')
import ants

sys.path.insert(0, '/home/users/brezovec/projects/lysis/')
from bruker import *

# %matplotlib inline

# %%
def load_numpy_brain(file, channel=None, flip=False):
    # If no channel specified, load all channels, else load specified channel
    brain = nib.load(file).get_data()
    if channel == 'red':
        brain = brain[:,:,:,:,0] # for red brain.
    if channel  == 'green':
        brain = brain[:,:,:,:,1] # for green brain.
    #brain = np.swapaxes(brain, 0, 1)
    if flip is True:
        brain = np.flip(brain, 2)
    brain = np.squeeze(brain)
    brain = np.asarray(brain, 'float64')
    #brain = ants.from_numpy(brain)
    return brain

def load_brains_from_dir(folder):
    brain_files = sorted(os.listdir(folder))
    full_brain_files = [folder+brain_file for brain_file in brain_files]
    brains = [load_brain(brain) for brain in full_brain_files]
    return brains

def rotate_brain(brain):
    try:
        if type(brain) is not np.ndarray:
            brain = brain.numpy()
        brain = np.swapaxes(brain, 0, 1)
        brain = ants.from_numpy(brain)
    except:
        brain = None
    return brain

# %%
def set_resolution(brain, xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    statevalues = root.findall('PVStateShard')[0].findall('PVStateValue')
    for statevalue in statevalues:
        key = statevalue.get('key')
        if key == 'micronsPerPixel':
            indices = statevalue.findall('IndexedValue')
            for index in indices:
                axis = index.get('index')
                if axis == 'XAxis':
                    x = float(index.get('value'))
                elif axis == 'YAxis':
                    y = float(index.get('value'))
                elif axis == 'ZAxis':
                    z = float(index.get('value'))
                else:
                    print('Error')
    try:
        brain.set_spacing([x,y,z])
    except:
        print('Failed')
        
def get_resolution(xml_file):
    tree = ET.parse(xml_file)
    root = tree.getroot()
    statevalues = root.findall('PVStateShard')[0].findall('PVStateValue')
    for statevalue in statevalues:
        key = statevalue.get('key')
        if key == 'micronsPerPixel':
            indices = statevalue.findall('IndexedValue')
            for index in indices:
                axis = index.get('index')
                if axis == 'XAxis':
                    x = float(index.get('value'))
                elif axis == 'YAxis':
                    y = float(index.get('value'))
                elif axis == 'ZAxis':
                    z = float(index.get('value'))
                else:
                    print('Error')
    return x, y, z

# %%
def correlate_brain(brain, to_cor):
    try:
        brain_array = brain.numpy()
        y = np.shape(brain_array)[0]
        x = np.shape(brain_array)[1]
        z = np.shape(brain_array)[2]
        t = np.shape(brain_array)[3]
        print('y: {}, x: {}, z: {}, t: {}'.format(y, x, z, t))

        # first, flatten x and y
        print('flattening...')
        brain_for_cor = np.reshape(brain_array,(y*x,z,t))
        print('done flattening.')
        print('correlating...')
        cors = []
        print('Z-slice: ', end='')
        for z_slice in range(z):
            if z_slice == z:
                print(z_slice, '.')
            else:
                print('{}, '.format(z_slice), end='')
            cors.append(np.corrcoef(brain_for_cor[:,z_slice,:], to_cor[:,z_slice])[-1,:])
        print('done correlating.')
        print('final touches...')
        cors = np.asarray(cors)

        # remove very last cor entry since this is self correlation
        cors = cors[:,:-1]

        #reshape back to correct brain shape
        cor_brain = np.reshape(cors,((z,y,x)))
        print('done.')
    except:
        print('try failed')
        cor_brain = None
    return cor_brain

# %%
def calc_event_triggered_delays(numpy_brain,
                                movement_times,
                                timestamps,
                                search_before=2000,
                                search_after=2000):
    
    useful_frames = []

    # For each movement time, find brain slices that occur near in time
    for i, movement_time in enumerate(movement_times):
        print('{} of {}. '.format(i+1, len(movement_times)), end='')
        # Define what time range to look across
        search_start = movement_time - search_before
        search_end = movement_time + search_after

        # Look at each z-slice
        for z in range(len(numpy_brain[0,0,:,0])):

            # Get times of the current slice
            slice_times = timestamps[:,z]

            # Find slices near current movement time
            for f, slice_time in enumerate(slice_times):
                if search_start <= slice_time <= search_end:

                    # Calculate delay
                    delay = slice_time - movement_time

                    # Save the index of the found slice, along with it's delay relative to movement
                    useful_frames.append({'slice': z, 'frame': f, 'delay': delay})
    return useful_frames

# %%
def slice_moving_avg(voxel_slices, delays, start=-4000, stop=4000, step=100):
    
    means = []
    centers = []
    
    for window in range(int((stop - start) / step)):
        
        window_start = start + window * step
        window_end = window_start + step

        above = np.asarray([delay > window_start for delay in delays])
        below = np.asarray([delay < window_end for delay in delays])
        indicies = np.where(above & below)[0]
        
        values = [voxel_slices[index,:,:] for index in indicies]
        mean = np.mean(values, axis = 0)
        means.append(mean)
        
    return means

# %%
def signal_metric(numpy_brain, useful_frames, metric='variance'):

    brain_triggered = []
    mean_signal = []
    
    mean_brain = np.mean(numpy_brain, axis = 3)

    for z in range(len(numpy_brain[0,0,:,0])):
        print(z)

        voxel_slices = []
        delays = []

        for frame in useful_frames:
            if frame['slice'] == z:

                voxel_slice = numpy_brain[:,:,z,frame['frame']]
                voxel_slices.append(voxel_slice)

                delay = frame['delay']
                delays.append(delay)

        means = slice_moving_avg(np.asarray(voxel_slices), delays)
        means_smoothed = scipy.ndimage.filters.gaussian_filter1d(means, sigma=1, axis=0)
        mean_signal.append(means_smoothed)

        if metric == 'df':
            minimums = np.amin(means_smoothed, axis=0)
            maximums = np.amax(means_smoothed, axis=0)
            value = (maximums - minimums) #/ minimums
        elif metric == 'variance':
            value = np.var(means_smoothed, axis=0)
        elif metric == 'd_from_mean':
            minimums = np.amin(means, axis=0) # note, not using smoothed
            minimums = mean_brain[:,:,z] - minimums
            maximums = np.amax(means, axis=0) # note, not using smoothed
            maximums = maximums - mean_brain[:,:,z]
            value = np.maximum(minimums, maximums)
        elif metric == 'integrated_f':
            value = np.sum(np.abs(means), axis = 0)
            
        brain_triggered.append(value)
    
    brain_triggered = np.asarray(brain_triggered)
    
    return brain_triggered, mean_signal

# %%
def single_moving_avg(voxels, delays, start=-2000, stop=2000, step=100):
    means = []
    centers = []
    for window in range(int((stop - start) / step)):
        window_start = start + window * step
        window_end = window_start + step
        center = window_start + (step / 2)
        centers.append(center)
        above = np.asarray([delay > window_start for delay in delays])
        below = np.asarray([delay < window_end for delay in delays])
        indicies = np.where(above & below)[0]
        mean = np.mean([voxels[index] for index in indicies])
        means.append(mean)
    return means, centers

# %%
def send_email(subject='', message=''):
    server = smtplib.SMTP('smtp.gmail.com', 587)
    server.starttls()
    server.login("python.notific@gmail.com", "9!tTT77x!ma8cGy")

    msg = MIMEText(message)
    msg['Subject'] = subject

    to = "brezovec@stanford.edu"
    server.sendmail(to, to, msg.as_string())
    server.quit()

# %%
@register_cell_magic
def error_handler(line, cell):
    try:
        exec(cell)
    except:
        var = traceback.format_exc()
        send_email('ERROR',var)
        raise # if you want the full trace-back in the notebook

# %%
def timing(f):
    @wraps(f)
    def wrapper(*args, **kwargs):
        start = time()
        result = f(*args, **kwargs)
        end = time()
        duration = (end-start)/60
        save_duration(name=f.__name__, duration=duration)
        print('Elapsed time: {}{}'.format(duration,'min'))
        return result
    return wrapper

def save_duration(name, duration):
    function_durations.append({'name': name, 'duration': duration})

# %%
def alphanum_key(s):
    return [tryint(c) for c in re.split('([0-9]+)', s)]

def sort_nicely(x):
    x.sort(key=alphanum_key)
    
def tryint(s):
    try:
        return int(s)
    except:
        return s

# %%
@timing
def load_fictrac(root_path, fly_folder):
    print('Loading fictrac.')
    with open(os.path.join(root_path, fly_folder, 'fictrac.dat'),'r') as f:
                df = pd.DataFrame(l.rstrip().split() for l in f)

                # Name columns
                df = df.rename(index=str, columns={0: 'frameCounter',
                                               1: 'dRotCamX',
                                               2: 'dRotCamY',
                                               3: 'dRotCamZ',
                                               4: 'dRotScore',
                                               5: 'dRotLabX',
                                               6: 'dRotLabY',
                                               7: 'dRotLabZ',
                                               8: 'AbsRotCamX',
                                               9: 'AbsRotCamY',
                                               10: 'AbsRotCamZ',
                                               11: 'AbsRotLabX',
                                               12: 'AbsRotLabY',
                                               13: 'AbsRotLabZ',
                                               14: 'positionX',
                                               15: 'positionY',
                                               16: 'heading',
                                               17: 'runningDir',
                                               18: 'speed',
                                               19: 'integratedX',
                                               20: 'integratedY',
                                               21: 'timeStamp',
                                               22: 'sequence'})

                # Remove commas
                for column in df.columns.values[:-1]:
                    df[column] = [float(x[:-1]) for x in df[column]]

                fictrac_data = df
                
    # sanity check for extremely high speed (fictrac failure)
    speed = np.asarray(fictrac_data['speed'])
    max_speed = np.max(speed)
    if max_speed > 10:
        raise Exception('Fictrac ball tracking failed (reporting impossibly high speed).')
    return fictrac_data

# %%
def align_volume(fixed, moving, vol):        
    moving_vol = ants.from_numpy(moving[:,:,:,vol])
    motCorr_vol = ants.registration(fixed, moving_vol, type_of_transform='SyN')
    return motCorr_vol

def save_motCorr_brain(brain, folder, suffix):
    brain = np.moveaxis(np.asarray(brain),0,3)
    motCorr_brain_ants = ants.from_numpy(brain)
    save_file = os.path.join(folder, 'motcorr_' + suffix + '.nii')
    ants.image_write(motCorr_brain_ants, save_file)
    return motCorr_brain_ants

@timing
def motion_correction(brain_master=None, brain_slave=None, folder=None):
    # old: numpy_brain, folder
    if brain_master is None:
        raise Exception('Must supply brain_master.')
    elif brain_master is not None and np.shape(brain_master) != np.shape(brain_slave):
        raise Exception('Dimensions of master and slave brain must match.')
    
    # Make mean brain
    print('Creating meanbrain...', end='')
    t = time()
    meanbrain = ants.from_numpy(np.mean(brain_master, axis=-1))
    print('Done. Duration: {:.1f}s'.format(time()-t))

    # Align each time volume to the meanbrain
    motCorr_brain_master = []
    motCorr_brain_slave = []
    transforms = []

    print('Performing motion correction...')
    for i in range(np.shape(brain_master)[3]):
        print('Aligning brain volume {} of {}...'.format(i+1, np.shape(brain_master)[3]), end='')
        t0 = time()
        
        #First, align given master volume to master meanbrain
        motCorr_vol_master = align_volume(fixed=meanbrain, moving=brain_master, vol=i)
        motCorr_brain_master.append(motCorr_vol_master['warpedmovout'].numpy())
        transforms.append(motCorr_vol_master['fwdtransforms'])
        
        #Then, use warp parameters on slave volume
        if brain_slave is not None:
            fixed = meanbrain
            moving = ants.from_numpy(brain_slave[:,:,:,i])
            transformlist = motCorr_vol_master['fwdtransforms']
            motCorr_brain_slave.append(ants.apply_transforms(fixed,moving,transformlist).numpy())
        
        print('Done. Duration: {:.1f}s'.format(time()-t0))

    # Save motcorr brain(s)
    print('Saving brain...', end='')
    t = time()
    brain_master_motCorr = save_motCorr_brain(motCorr_brain_master, folder, suffix='red')
    
    if brain_slave is not None:
        brain_slave_motCorr = save_motCorr_brain(motCorr_brain_slave, folder, suffix='green')
    print('Done. Duration: {:.1f}s'.format(time()-t))

    # Organize mat transform file
    print('Organizing transform file.')
    transform_matrix = []
    for i, transform in enumerate(transforms):
        for x in transform:
            if '.mat' in x:
                temp = ants.read_transform(x)
                transform_matrix.append(temp.parameters)
    transform_matrix = np.array(transform_matrix)

    # Save mat transform file
    print('Saving transform file.')
    save_file = os.path.join(folder, 'motcorr_params')
    np.save(save_file,transform_matrix)

    # Get voxel resolution for figure
    print('Getting voxel resolution.')
    file = os.path.join(folder, 'functional.xml')
    x_res, y_res, z_res = get_resolution(file)

    # Save figure of motion over time
    print('Saving motion correction figure.')
    save_file = os.path.join(folder, 'motion_correction.png')
    plt.figure(figsize=(10,10))
    plt.plot(transform_matrix[:,9]*x_res, label = 'y') # note, resolutions are switched since axes are switched
    plt.plot(transform_matrix[:,10]*y_res, label = 'x')
    plt.plot(transform_matrix[:,11]*z_res, label = 'z')
    plt.ylabel('Motion Correction, um')
    plt.xlabel('Time')
    plt.title(folder)
    plt.legend()
    plt.savefig(save_file, bbox_inches='tight', dpi=300)
    
    if brain_slave is not None:
        return brain_master_motCorr, brain_slave_motCorr
    else:
        return brain_master_motCorr

# %%
@timing
def load_timestamps(folder, file='functional.xml'):
    print('Loading timestamps.')
    # load from h5py if it exists, otherwise load from xml and create h5py
    try:
        timestamps = bruker_timestamps_import(folder, file, False)
    except:
        timestamps = bruker_timestamps_import(folder, file, True)
    return timestamps
        
@timing
def prep_fictrac(fictrac, timestamps, fps, dur):
    print('Preping fictrac.')
    camera_rate = 1/fps * 1000 # camera frame rate in ms
    raw_fictrac_times = np.arange(0,dur,camera_rate)
    
    # Cut off any extra frames (only happened with brain 4)
    fictrac = fictrac[:90000]
    
    # Smooth
    fictrac_smoothed = scipy.ndimage.filters.gaussian_filter(np.asarray(fictrac['speed']),sigma=3)
    
    # Interpolate
    # Warning: interp1d set to fill in out of bounds times
    fictrac_interp_temp = interp1d(raw_fictrac_times, fictrac_smoothed, bounds_error = False)
    fictrac_interp = fictrac_interp_temp(timestamps)
    
    # Replace Nans with zeros (for later code)
    np.nan_to_num(fictrac_interp, copy=False);
    
    return fictrac_interp

@timing
def get_motcorr_brain(folder, channel=None):
    # Make subfolder if it doesn't exist
    subfolder = 'motcorr'
    directory = os.path.join(folder, subfolder)
    if not os.path.exists(directory):
        os.makedirs(directory)
    # If it exists, load motion correction brain, else make it
    if channel == 'green':
        # try to open motcorr_green, else make it (and make red)
        try:
            print('Trying to load green motion-corrected brain.')
            brain_file = os.path.join(directory, 'motcorr_green.nii')
            brain = load_numpy_brain(brain_file)
            print('Loaded green motion-corrected brain.')
        except:
            print('Failed to load green motion-corrected brain.')
            print('Trying to load functional brain.')
            brain_file = folder + '/functional.nii'
            brain_green = load_numpy_brain(brain_file, channel='green')
            brain_red = load_numpy_brain(brain_file, channel='red')
            print('Loaded green and red functional brains.')

            ### Perform motion correction ###
            print('Performing motion-correction.')
            brain_red, brain_green = motion_correction(brain_master=brain_red, brain_slave=brain_green, folder=directory)
        
        dims = get_dims(brain_green)
        return brain_green, dims
    
    elif channel == 'red':
        # try to open motcorr_red, else make it (and make green)
        try:
            print('Trying to load red motion-corrected brain.')
            brain_file = os.path.join(directory, 'motcorr_red.nii')
            brain = load_numpy_brain(brain_file)
            print('Loaded red motion-corrected brain.')
        except:
            print('Failed to load red motion-corrected brain.')
            print('Trying to load functional brain.')
            brain_file = folder + '/functional.nii'
            brain_green = load_numpy_brain(brain_file, channel='green')
            brain_red = load_numpy_brain(brain_file, channel='red')
            print('Loaded green and red functional brains.')

            ### Perform motion correction ###
            print('Performing motion-correction.')
            brain_red, brain_green = motion_correction(brain_master=brain_red, brain_slave=brain_green, folder=directory)
            
        dims = get_dims(brain_red)
        return brain_red, dims
    
    elif channel == None:
        # try to open motcorr, else make it
        try:
            print('Trying to load motion-corrected brain.')
            brain_file = folder + '/motcorr.nii'
            brain = load_numpy_brain(brain_file)
            print('Loaded motion-corrected brain.')
        except:
            # next, try loading the functional brain and perform motion correction
            print('Failed to load motion-corrected brain.')
            print('Trying to load functional brain.')
            brain_file = folder + '/functional.nii'
            brain_green = load_numpy_brain(brain_file, channel='green')
            print('Loaded functional brain.')

            ### Perform motion correction ###
            print('Performing motion-correction.')
            brain_green = motion_correction(brain_master=brain_green, folder=folder)

        dims = get_dims(brain)
        return brain, dims
    
    else:
        raise Exception('Invalid channel type.')

def get_dims(brain):
    y = brain.shape[0]
    x = brain.shape[1]
    z = brain.shape[2]
    t = brain.shape[3]
    return {'x': x, 'y': y, 'z': z, 't': t}

@timing
def bleaching_correction(brain):
    print('Bleaching correction.')
    smoothed = scipy.ndimage.gaussian_filter1d(brain,sigma=200,axis=3,truncate=1)
    brain = brain - smoothed
    return brain

@timing
def z_score_brain(brain):
    print('Z-score brain.')
    brain_mean  = np.mean(brain, axis=3)
    brain_std = np.std(brain, axis=3)
    brain = (brain - brain_mean[:,:,:,None]) / brain_std[:,:,:,None]
    return brain

@timing
def fit_glm(brain, dims, fictrac, beta_len):
    print('Fit GLM.')
    middle = int((beta_len - 1) / 2)
    models = []
    scores = []
    for z in range(dims['z']):
        print('~~ z:{} ~~ '.format(z), end = '')
        Y = fictrac[:,z]
        for x in range(dims['x']):
            for y in range(dims['y']):
                voxel_activity = brain[y,x,z,:]
                X = toeplitz(voxel_activity, np.zeros(beta_len))
                X = np.roll(X, middle)
                model = LassoLarsIC(criterion='bic')
                model.fit(X, Y)
                #models.append(model)
                scores.append(model.score(X,Y))
    scores = np.reshape(scores, (dims['z'], dims['x'], dims['y']))
    return scores

def save_glm_map(vol, folder, channel):
    print('Saving glm vol.')
    file = 'multivariate_analysis_' + channel + '.nii'
    save_file = os.path.join(folder, file)
    brain_to_save = np.swapaxes(vol, 0, 2)
    ants.image_write(ants.from_numpy(brain_to_save), save_file)

# %% [markdown]
# # Create fly objects and import data

# %%
class Fly:
    def __init__(self):
        pass
    
root_path = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20190101_walking_dataset/'


fly_folders = sorted(os.listdir(root_path))
fly_folders = [x for x in fly_folders if 'fly' in x]
sort_nicely(fly_folders)

flies = [Fly() for i in range(len(fly_folders))]

print('Created flies from folders {}'.format(fly_folders))
# Out:
# Created flies from folders ['fly_1', 'fly_2', 'fly_3', 'fly_4', 'fly_5', 'fly_6', 'fly_7', 'fly_8', 'fly_9', 'fly_10', 'fly_11', 'fly_12', 'fly_13', 'fly_14', 'fly_15', 'fly_16', 'fly_17', 'fly_18', 'fly_19', 'fly_20', 'fly_21', 'fly_22', 'fly_23', 'fly_24', 'fly_25', 'fly_26']

# %% [markdown]
# ### Can select subset of flies if desired

# %%
desired_flies = [21] # 1 index
fly_folders = [fly_folders[i-1] for i in desired_flies]
flies = [flies[i-1] for i in desired_flies]
print(fly_folders)
# Out:
# ['fly_21']

# %%
beta_len = 21 #MUST BE ODD
fps = 50 #of fictrac camera
dur = 30 * 60 * 1000 # experiment duration in ms
vols_to_clip = 200

for fly_idx, fly in enumerate(flies):
    
    ### Send email and define folder path ###
    function_durations = []
    print('Starting analysis of {}.'.format(fly_folders[fly_idx]))
    send_email('Starting {} ({} of {}).'.format(fly_folders[fly_idx], fly_idx+1, len(flies)), 'wow')
    folder = root_path + fly_folders[fly_idx]

    ### Load timestamps ###
    timestamps = load_timestamps(folder)
    
    ### Load fictrac (and prep) ###
    # add sanity check for failed frames. Simply check if and speed measurements are over 10
    fictrac = load_fictrac(root_path, fly_folders[fly_idx])
    fictrac_interp = prep_fictrac(fictrac, timestamps, fps, dur)
    
    # remove first bit of data since it often has some weirdness
    timestamps = timestamps[vols_to_clip:,:]
    fictrac_interp = fictrac_interp[vols_to_clip:,:]

    ############# Do remaining analysis on both brain channels ###############
    channels = ['green', 'red']
    for channel in channels:
        ### Load brain ###
        brain, dims = get_motcorr_brain(folder, channel=channel)

        # remove first bit of data since it often has some weirdness
        brain = brain[:,:,:,vols_to_clip:]
        dims['t'] = brain.shape[3]

        ### Bleaching correction (per voxel) ###
        brain = bleaching_correction(brain)

        ### Z-score brain ###
        brain = z_score_brain(brain)

        ### Fit GLM ###
        scores = fit_glm(brain, dims, fictrac_interp, beta_len)

        ### Save brain ###
        save_glm_map(scores, folder, channel)

        ### Send email ###

        # Prep timing string
        func_str = ''
        for func in function_durations:
            func_str += '{} ===== {:.2f} min\n'.format(func['name'], func['duration'])

        send_email('Success {} ({} of {}): {} channel.'.format(
            fly_folders[fly_idx], fly_idx+1, len(flies)), func_str, channel)
# Out:
# Starting analysis of fly_21.
# Loading timestamps.
# loading timestamp data from hdf5 file... done
# Elapsed time: 0.0004818598429361979min
# Loading fictrac.
# Elapsed time: 0.04904476801554362min
# Preping fictrac.
# Elapsed time: 0.00028884410858154297min
# Trying to load green motion-corrected brain.
# Failed to load green motion-corrected brain.
# Trying to load functional brain.
# Loaded green and red functional brains.
# Performing motion-correction.
# Creating meanbrain...Done. Duration: 2.2s
# Performing motion correction...
# Aligning brain volume 1 of 4370...Done. Duration: 2.7s
# Aligning brain volume 2 of 4370...Done. Duration: 2.8s
# Aligning brain volume 3 of 4370...Done. Duration: 2.6s
# Aligning brain volume 4 of 4370...Done. Duration: 3.0s
# Aligning brain volume 5 of 4370...Done. Duration: 2.5s
# Aligning brain volume 6 of 4370...Done. Duration: 2.6s
# Aligning brain volume 7 of 4370...Done. Duration: 2.8s
# Aligning brain volume 8 of 4370...Done. Duration: 3.0s
# Aligning brain volume 9 of 4370...Done. Duration: 2.6s
# Aligning brain volume 10 of 4370...Done. Duration: 2.8s
# Aligning brain volume 11 of 4370...Done. Duration: 2.6s
# Aligning brain volume 12 of 4370...Done. Duration: 2.7s
# Aligning brain volume 13 of 4370...Done. Duration: 2.6s
# Aligning brain volume 14 of 4370...Done. Duration: 2.5s
# Aligning brain volume 15 of 4370...Done. Duration: 2.8s
# Aligning brain volume 16 of 4370...Done. Duration: 2.4s
# Aligning brain volume 17 of 4370...Done. Duration: 2.9s
# Aligning brain volume 18 of 4370...Done. Duration: 2.5s
# Aligning brain volume 19 of 4370...Done. Duration: 2.9s
# Aligning brain volume 20 of 4370...Done. Duration: 2.7s
# Aligning brain volume 21 of 4370...Done. Duration: 2.8s
# Aligning brain volume 22 of 4370...Done. Duration: 3.0s
# Aligning brain volume 23 of 4370...Done. Duration: 2.7s
# Aligning brain volume 24 of 4370...Done. Duration: 2.8s
# Aligning brain volume 25 of 4370...Done. Duration: 2.8s
# Aligning brain volume 26 of 4370...Done. Duration: 2.7s
# Aligning brain volume 27 of 4370...Done. Duration: 2.9s
# Aligning brain volume 28 of 4370...Done. Duration: 2.7s
# Aligning brain volume 29 of 4370...Done. Duration: 2.7s
# Aligning brain volume 30 of 4370...Done. Duration: 3.2s
# Aligning brain volume 31 of 4370...Done. Duration: 2.6s
# Aligning brain volume 32 of 4370...Done. Duration: 2.8s
# Aligning brain volume 33 of 4370...Done. Duration: 3.0s
# Aligning brain volume 34 of 4370...Done. Duration: 2.8s
# Aligning brain volume 35 of 4370...Done. Duration: 2.8s
# Aligning brain volume 36 of 4370...Done. Duration: 2.8s
# Aligning brain volume 37 of 4370...Done. Duration: 2.7s
# Aligning brain volume 38 of 4370...Done. Duration: 2.9s
# Aligning brain volume 39 of 4370...Done. Duration: 2.9s
# Aligning brain volume 40 of 4370...Done. Duration: 2.9s
# Aligning brain volume 41 of 4370...Done. Duration: 2.8s
# Aligning brain volume 42 of 4370...Done. Duration: 2.8s
# Aligning brain volume 43 of 4370...Done. Duration: 2.7s
# Aligning brain volume 44 of 4370...Done. Duration: 2.8s
# Aligning brain volume 45 of 4370...Done. Duration: 2.7s
# Aligning brain volume 46 of 4370...Done. Duration: 2.7s
# Aligning brain volume 47 of 4370...Done. Duration: 2.8s
# Aligning brain volume 48 of 4370...Done. Duration: 2.6s
# Aligning brain volume 49 of 4370...Done. Duration: 2.6s
# Aligning brain volume 50 of 4370...Done. Duration: 2.7s
# Aligning brain volume 51 of 4370...Done. Duration: 2.7s
# Aligning brain volume 52 of 4370...Done. Duration: 2.9s
# Aligning brain volume 53 of 4370...Done. Duration: 3.0s
# Aligning brain volume 54 of 4370...Done. Duration: 2.6s
# Aligning brain volume 55 of 4370...Done. Duration: 2.8s
# Aligning brain volume 56 of 4370...Done. Duration: 2.7s
# Aligning brain volume 57 of 4370...Done. Duration: 2.8s
# Aligning brain volume 58 of 4370...Done. Duration: 2.7s
# Aligning brain volume 59 of 4370...Done. Duration: 2.8s
# Aligning brain volume 60 of 4370...Done. Duration: 2.5s
# Aligning brain volume 61 of 4370...Done. Duration: 2.8s
# Aligning brain volume 62 of 4370...Done. Duration: 2.5s
# Aligning brain volume 63 of 4370...Done. Duration: 2.7s
# Aligning brain volume 64 of 4370...Done. Duration: 2.9s
# Aligning brain volume 65 of 4370...Done. Duration: 2.9s
# Aligning brain volume 66 of 4370...Done. Duration: 2.7s
# Aligning brain volume 67 of 4370...Done. Duration: 2.6s
# Aligning brain volume 68 of 4370...Done. Duration: 2.8s
# Aligning brain volume 69 of 4370...Done. Duration: 2.8s
# Aligning brain volume 70 of 4370...Done. Duration: 2.6s
# Aligning brain volume 71 of 4370...Done. Duration: 2.7s
# Aligning brain volume 72 of 4370...Done. Duration: 2.7s
# Aligning brain volume 73 of 4370...Done. Duration: 2.5s
# Aligning brain volume 74 of 4370...Done. Duration: 3.0s
# Aligning brain volume 75 of 4370...Done. Duration: 2.8s
# Aligning brain volume 76 of 4370...Done. Duration: 2.9s
# Aligning brain volume 77 of 4370...Done. Duration: 2.8s
# Aligning brain volume 78 of 4370...Done. Duration: 2.8s
# Aligning brain volume 79 of 4370...Done. Duration: 2.7s
# Aligning brain volume 80 of 4370...Done. Duration: 2.9s
# Aligning brain volume 81 of 4370...Done. Duration: 2.6s
# Aligning brain volume 82 of 4370...Done. Duration: 2.8s
# Aligning brain volume 83 of 4370...Done. Duration: 2.8s
# Aligning brain volume 84 of 4370...Done. Duration: 2.7s
# Aligning brain volume 85 of 4370...Done. Duration: 2.8s
# Aligning brain volume 86 of 4370...Done. Duration: 2.6s
# Aligning brain volume 87 of 4370...Done. Duration: 2.7s
# Aligning brain volume 88 of 4370...Done. Duration: 2.6s
# Aligning brain volume 89 of 4370...Done. Duration: 2.9s
# Aligning brain volume 90 of 4370...Done. Duration: 2.7s
# Aligning brain volume 91 of 4370...Done. Duration: 3.0s
# Aligning brain volume 92 of 4370...Done. Duration: 2.7s
# Aligning brain volume 93 of 4370...Done. Duration: 2.8s
# Aligning brain volume 94 of 4370...Done. Duration: 2.6s
# Aligning brain volume 95 of 4370...Done. Duration: 2.7s
# Aligning brain volume 96 of 4370...Done. Duration: 2.6s
# Aligning brain volume 97 of 4370...Done. Duration: 2.5s
# Aligning brain volume 98 of 4370...Done. Duration: 2.7s
# Aligning brain volume 99 of 4370...Done. Duration: 2.7s
# Aligning brain volume 100 of 4370...Done. Duration: 2.9s
# Aligning brain volume 101 of 4370...Done. Duration: 2.8s
# Aligning brain volume 102 of 4370...Done. Duration: 2.9s
# Aligning brain volume 103 of 4370...Done. Duration: 2.6s
# Aligning brain volume 104 of 4370...Done. Duration: 2.7s
# Aligning brain volume 105 of 4370...Done. Duration: 2.8s
# Aligning brain volume 106 of 4370...Done. Duration: 2.6s
# Aligning brain volume 107 of 4370...Done. Duration: 2.9s
# Aligning brain volume 108 of 4370...Done. Duration: 2.7s
# Aligning brain volume 109 of 4370...Done. Duration: 2.7s
# Aligning brain volume 110 of 4370...Done. Duration: 2.6s
# Aligning brain volume 111 of 4370...Done. Duration: 2.8s
# Aligning brain volume 112 of 4370...Done. Duration: 2.7s
# Aligning brain volume 113 of 4370...Done. Duration: 3.1s
# Aligning brain volume 114 of 4370...Done. Duration: 2.8s
# Aligning brain volume 115 of 4370...Done. Duration: 2.7s
# Aligning brain volume 116 of 4370...Done. Duration: 2.8s
# Aligning brain volume 117 of 4370...Done. Duration: 2.8s
# Aligning brain volume 118 of 4370...Done. Duration: 2.6s
# Aligning brain volume 119 of 4370...Done. Duration: 2.8s
# Aligning brain volume 120 of 4370...Done. Duration: 2.6s
# Aligning brain volume 121 of 4370...Done. Duration: 2.9s
# Aligning brain volume 122 of 4370...Done. Duration: 2.6s
# Aligning brain volume 123 of 4370...Done. Duration: 3.0s
# Aligning brain volume 124 of 4370...Done. Duration: 2.6s
# Aligning brain volume 125 of 4370...Done. Duration: 2.6s
# Aligning brain volume 126 of 4370...Done. Duration: 2.7s
# Aligning brain volume 127 of 4370...Done. Duration: 2.9s
# Aligning brain volume 128 of 4370...Done. Duration: 2.7s
# Aligning brain volume 129 of 4370...Done. Duration: 2.8s
# Aligning brain volume 130 of 4370...Done. Duration: 2.9s
# Aligning brain volume 131 of 4370...Done. Duration: 2.7s
# Aligning brain volume 132 of 4370...Done. Duration: 2.6s
# Aligning brain volume 133 of 4370...Done. Duration: 2.8s
# Aligning brain volume 134 of 4370...Done. Duration: 2.6s
# Aligning brain volume 135 of 4370...Done. Duration: 2.7s
# Aligning brain volume 136 of 4370...Done. Duration: 2.8s
# Aligning brain volume 137 of 4370...Done. Duration: 2.8s
# Aligning brain volume 138 of 4370...Done. Duration: 2.9s
# Aligning brain volume 139 of 4370...Done. Duration: 2.9s
# Aligning brain volume 140 of 4370...Done. Duration: 2.7s
# Aligning brain volume 141 of 4370...Done. Duration: 3.2s
# Aligning brain volume 142 of 4370...Done. Duration: 2.6s
# Aligning brain volume 143 of 4370...Done. Duration: 2.7s
# Aligning brain volume 144 of 4370...Done. Duration: 2.6s
# Aligning brain volume 145 of 4370...Done. Duration: 2.9s
# Aligning brain volume 146 of 4370...Done. Duration: 2.8s
# Aligning brain volume 147 of 4370...Done. Duration: 2.7s
# Aligning brain volume 148 of 4370...Done. Duration: 2.9s
# Aligning brain volume 149 of 4370...Done. Duration: 2.6s
# Aligning brain volume 150 of 4370...Done. Duration: 2.9s
# Aligning brain volume 151 of 4370...Done. Duration: 2.7s
# Aligning brain volume 152 of 4370...Done. Duration: 2.7s
# Aligning brain volume 153 of 4370...Done. Duration: 2.8s
# Aligning brain volume 154 of 4370...Done. Duration: 2.8s
# Aligning brain volume 155 of 4370...Done. Duration: 3.0s
# Aligning brain volume 156 of 4370...Done. Duration: 3.0s
# Aligning brain volume 157 of 4370...Done. Duration: 2.9s
# Aligning brain volume 158 of 4370...Done. Duration: 2.7s
# Aligning brain volume 159 of 4370...Done. Duration: 2.8s
# Aligning brain volume 160 of 4370...Done. Duration: 2.6s
# Aligning brain volume 161 of 4370...Done. Duration: 2.6s
# Aligning brain volume 162 of 4370...Done. Duration: 2.8s
# Aligning brain volume 163 of 4370...Done. Duration: 2.8s
# Aligning brain volume 164 of 4370...Done. Duration: 2.7s
# Aligning brain volume 165 of 4370...Done. Duration: 2.8s
# Aligning brain volume 166 of 4370...Done. Duration: 2.8s
# Aligning brain volume 167 of 4370...Done. Duration: 2.8s
# Aligning brain volume 168 of 4370...Done. Duration: 2.5s
# Aligning brain volume 169 of 4370...Done. Duration: 2.7s
# Aligning brain volume 170 of 4370...Done. Duration: 2.7s
# Aligning brain volume 171 of 4370...Done. Duration: 3.0s
# Aligning brain volume 172 of 4370...Done. Duration: 2.7s
# Aligning brain volume 173 of 4370...Done. Duration: 2.7s
# Aligning brain volume 174 of 4370...Done. Duration: 2.9s
# Aligning brain volume 175 of 4370...Done. Duration: 2.7s
# Aligning brain volume 176 of 4370...Done. Duration: 2.9s
# Aligning brain volume 177 of 4370...Done. Duration: 2.9s
# Aligning brain volume 178 of 4370...Done. Duration: 2.9s
# Aligning brain volume 179 of 4370...Done. Duration: 2.5s
# Aligning brain volume 180 of 4370...Done. Duration: 2.7s
# Aligning brain volume 181 of 4370...Done. Duration: 2.9s
# Aligning brain volume 182 of 4370...Done. Duration: 2.7s
# Aligning brain volume 183 of 4370...Done. Duration: 2.7s
# Aligning brain volume 184 of 4370...Done. Duration: 2.8s
# Aligning brain volume 185 of 4370...Done. Duration: 2.9s
# Aligning brain volume 186 of 4370...Done. Duration: 2.7s
# Aligning brain volume 187 of 4370...Done. Duration: 2.8s
# Aligning brain volume 188 of 4370...Done. Duration: 2.8s
# Aligning brain volume 189 of 4370...Done. Duration: 2.6s
# Aligning brain volume 190 of 4370...Done. Duration: 2.7s
# Aligning brain volume 191 of 4370...Done. Duration: 2.8s
# Aligning brain volume 192 of 4370...Done. Duration: 2.9s
# Aligning brain volume 193 of 4370...Done. Duration: 2.7s
# Aligning brain volume 194 of 4370...Done. Duration: 2.9s
# Aligning brain volume 195 of 4370...Done. Duration: 2.7s
# Aligning brain volume 196 of 4370...Done. Duration: 2.8s
# Aligning brain volume 197 of 4370...Done. Duration: 2.7s
# Aligning brain volume 198 of 4370...Done. Duration: 2.8s
# Aligning brain volume 199 of 4370...Done. Duration: 3.1s
# Aligning brain volume 200 of 4370...Done. Duration: 2.5s
# Aligning brain volume 201 of 4370...Done. Duration: 2.7s
# Aligning brain volume 202 of 4370...Done. Duration: 2.7s
# Aligning brain volume 203 of 4370...Done. Duration: 2.6s
# Aligning brain volume 204 of 4370...Done. Duration: 2.8s
# Aligning brain volume 205 of 4370...Done. Duration: 2.7s
# Aligning brain volume 206 of 4370...Done. Duration: 2.7s
# Aligning brain volume 207 of 4370...Done. Duration: 2.8s
# Aligning brain volume 208 of 4370...Done. Duration: 2.7s
# Aligning brain volume 209 of 4370...Done. Duration: 2.7s
# Aligning brain volume 210 of 4370...Done. Duration: 2.9s
# Aligning brain volume 211 of 4370...Done. Duration: 2.5s
# Aligning brain volume 212 of 4370...Done. Duration: 2.6s
# Aligning brain volume 213 of 4370...Done. Duration: 2.8s
# Aligning brain volume 214 of 4370...Done. Duration: 2.9s
# Aligning brain volume 215 of 4370...Done. Duration: 2.8s
# Aligning brain volume 216 of 4370...Done. Duration: 2.7s
# Aligning brain volume 217 of 4370...Done. Duration: 2.7s
# Aligning brain volume 218 of 4370...Done. Duration: 2.7s
# Aligning brain volume 219 of 4370...Done. Duration: 2.6s
# Aligning brain volume 220 of 4370...Done. Duration: 2.9s
# Aligning brain volume 221 of 4370...Done. Duration: 3.0s
# Aligning brain volume 222 of 4370...Done. Duration: 2.8s
# Aligning brain volume 223 of 4370...Done. Duration: 2.8s
# Aligning brain volume 224 of 4370...Done. Duration: 2.6s
# Aligning brain volume 225 of 4370...Done. Duration: 2.8s
# Aligning brain volume 226 of 4370...Done. Duration: 2.8s
# Aligning brain volume 227 of 4370...Done. Duration: 2.8s
# Aligning brain volume 228 of 4370...Done. Duration: 2.7s
# Aligning brain volume 229 of 4370...Done. Duration: 2.8s
# Aligning brain volume 230 of 4370...Done. Duration: 2.8s
# Aligning brain volume 231 of 4370...Done. Duration: 2.6s
# Aligning brain volume 232 of 4370...Done. Duration: 2.7s
# Aligning brain volume 233 of 4370...Done. Duration: 2.7s
# Aligning brain volume 234 of 4370...Done. Duration: 2.7s
# Aligning brain volume 235 of 4370...Done. Duration: 2.8s
# Aligning brain volume 236 of 4370...Done. Duration: 2.8s
# Aligning brain volume 237 of 4370...Done. Duration: 2.6s
# Aligning brain volume 238 of 4370...Done. Duration: 2.7s
# Aligning brain volume 239 of 4370...Done. Duration: 2.8s
# Aligning brain volume 240 of 4370...Done. Duration: 2.8s
# Aligning brain volume 241 of 4370...Done. Duration: 3.0s
# Aligning brain volume 242 of 4370...Done. Duration: 3.0s
# Aligning brain volume 243 of 4370...Done. Duration: 2.8s
# Aligning brain volume 244 of 4370...Done. Duration: 2.7s
# Aligning brain volume 245 of 4370...Done. Duration: 2.8s
# Aligning brain volume 246 of 4370...Done. Duration: 2.8s
# Aligning brain volume 247 of 4370...Done. Duration: 2.7s
# Aligning brain volume 248 of 4370...Done. Duration: 2.9s
# Aligning brain volume 249 of 4370...Done. Duration: 2.7s
# Aligning brain volume 250 of 4370...Done. Duration: 2.8s
# Aligning brain volume 251 of 4370...Done. Duration: 2.9s
# Aligning brain volume 252 of 4370...Done. Duration: 3.0s
# Aligning brain volume 253 of 4370...Done. Duration: 2.8s
# Aligning brain volume 254 of 4370...Done. Duration: 2.7s
# Aligning brain volume 255 of 4370...Done. Duration: 2.8s
# Aligning brain volume 256 of 4370...Done. Duration: 2.8s
# Aligning brain volume 257 of 4370...Done. Duration: 2.7s
# Aligning brain volume 258 of 4370...Done. Duration: 2.9s
# Aligning brain volume 259 of 4370...Done. Duration: 2.7s
# Aligning brain volume 260 of 4370...Done. Duration: 2.9s
# Aligning brain volume 261 of 4370...Done. Duration: 2.8s
# Aligning brain volume 262 of 4370...Done. Duration: 2.6s
# Aligning brain volume 263 of 4370...Done. Duration: 2.6s
# Aligning brain volume 264 of 4370...Done. Duration: 2.8s
# Aligning brain volume 265 of 4370...Done. Duration: 3.2s
# Aligning brain volume 266 of 4370...Done. Duration: 2.8s
# Aligning brain volume 267 of 4370...Done. Duration: 2.6s
# Aligning brain volume 268 of 4370...Done. Duration: 2.9s
# Aligning brain volume 269 of 4370...Done. Duration: 2.8s
# Aligning brain volume 270 of 4370...Done. Duration: 3.0s
# Aligning brain volume 271 of 4370...Done. Duration: 2.7s
# Aligning brain volume 272 of 4370...Done. Duration: 2.6s
# Aligning brain volume 273 of 4370...Done. Duration: 2.6s
# Aligning brain volume 274 of 4370...Done. Duration: 2.8s
# Aligning brain volume 275 of 4370...Done. Duration: 2.8s
# Aligning brain volume 276 of 4370...Done. Duration: 2.5s
# Aligning brain volume 277 of 4370...Done. Duration: 2.6s
# Aligning brain volume 278 of 4370...Done. Duration: 2.6s
# Aligning brain volume 279 of 4370...Done. Duration: 2.7s
# Aligning brain volume 280 of 4370...Done. Duration: 2.9s
# Aligning brain volume 281 of 4370...Done. Duration: 2.7s
# Aligning brain volume 282 of 4370...Done. Duration: 2.7s
# Aligning brain volume 283 of 4370...Done. Duration: 2.7s
# Aligning brain volume 284 of 4370...Done. Duration: 2.6s
# Aligning brain volume 285 of 4370...Done. Duration: 2.9s
# Aligning brain volume 286 of 4370...Done. Duration: 2.6s
# Aligning brain volume 287 of 4370...Done. Duration: 2.8s
# Aligning brain volume 288 of 4370...Done. Duration: 2.6s
# Aligning brain volume 289 of 4370...Done. Duration: 2.5s
# Aligning brain volume 290 of 4370...Done. Duration: 2.9s
# Aligning brain volume 291 of 4370...Done. Duration: 2.7s
# Aligning brain volume 292 of 4370...Done. Duration: 2.7s
# Aligning brain volume 293 of 4370...Done. Duration: 2.7s
# Aligning brain volume 294 of 4370...Done. Duration: 2.8s
# Aligning brain volume 295 of 4370...Done. Duration: 2.8s
# Aligning brain volume 296 of 4370...Done. Duration: 2.8s
# Aligning brain volume 297 of 4370...Done. Duration: 3.1s
# Aligning brain volume 298 of 4370...Done. Duration: 2.7s
# Aligning brain volume 299 of 4370...Done. Duration: 2.7s
# Aligning brain volume 300 of 4370...Done. Duration: 2.9s
# Aligning brain volume 301 of 4370...Done. Duration: 2.6s
# Aligning brain volume 302 of 4370...Done. Duration: 2.8s
# Aligning brain volume 303 of 4370...Done. Duration: 2.6s
# Aligning brain volume 304 of 4370...Done. Duration: 2.8s
# Aligning brain volume 305 of 4370...Done. Duration: 2.7s
# Aligning brain volume 306 of 4370...Done. Duration: 2.9s
# Aligning brain volume 307 of 4370...Done. Duration: 2.8s
# Aligning brain volume 308 of 4370...Done. Duration: 2.8s
# Aligning brain volume 309 of 4370...Done. Duration: 3.0s
# Aligning brain volume 310 of 4370...Done. Duration: 2.6s
# Aligning brain volume 311 of 4370...Done. Duration: 2.8s
# Aligning brain volume 312 of 4370...Done. Duration: 2.7s
# Aligning brain volume 313 of 4370...Done. Duration: 2.7s
# Aligning brain volume 314 of 4370...Done. Duration: 2.7s
# Aligning brain volume 315 of 4370...Done. Duration: 2.7s
# Aligning brain volume 316 of 4370...Done. Duration: 2.6s
# Aligning brain volume 317 of 4370...Done. Duration: 2.7s
# Aligning brain volume 318 of 4370...Done. Duration: 2.7s
# Aligning brain volume 319 of 4370...Done. Duration: 2.9s
# Aligning brain volume 320 of 4370...Done. Duration: 2.6s
# Aligning brain volume 321 of 4370...Done. Duration: 2.8s
# Aligning brain volume 322 of 4370...Done. Duration: 3.0s
# Aligning brain volume 323 of 4370...Done. Duration: 2.7s
# Aligning brain volume 324 of 4370...Done. Duration: 2.6s
# Aligning brain volume 325 of 4370...Done. Duration: 2.6s
# Aligning brain volume 326 of 4370...Done. Duration: 2.6s
# Aligning brain volume 327 of 4370...Done. Duration: 2.6s
# Aligning brain volume 328 of 4370...Done. Duration: 2.9s
# Aligning brain volume 329 of 4370...Done. Duration: 2.7s
# Aligning brain volume 330 of 4370...Done. Duration: 2.8s
# Aligning brain volume 331 of 4370...Done. Duration: 2.4s
# Aligning brain volume 332 of 4370...Done. Duration: 3.0s
# Aligning brain volume 333 of 4370...Done. Duration: 2.8s
# Aligning brain volume 334 of 4370...Done. Duration: 2.7s
# Aligning brain volume 335 of 4370...Done. Duration: 2.7s
# Aligning brain volume 336 of 4370...Done. Duration: 2.6s
# Aligning brain volume 337 of 4370...Done. Duration: 2.8s
# Aligning brain volume 338 of 4370...Done. Duration: 2.7s
# Aligning brain volume 339 of 4370...Done. Duration: 2.8s
# Aligning brain volume 340 of 4370...Done. Duration: 2.8s
# Aligning brain volume 341 of 4370...Done. Duration: 2.7s
# Aligning brain volume 342 of 4370...Done. Duration: 2.9s
# Aligning brain volume 343 of 4370...Done. Duration: 2.9s
# Aligning brain volume 344 of 4370...Done. Duration: 2.6s
# Aligning brain volume 345 of 4370...Done. Duration: 2.7s
# Aligning brain volume 346 of 4370...Done. Duration: 2.7s
# Aligning brain volume 347 of 4370...Done. Duration: 2.9s
# Aligning brain volume 348 of 4370...Done. Duration: 2.6s
# Aligning brain volume 349 of 4370...Done. Duration: 2.6s
# Aligning brain volume 350 of 4370...Done. Duration: 2.8s
# Aligning brain volume 351 of 4370...Done. Duration: 2.7s
# Aligning brain volume 352 of 4370...Done. Duration: 3.0s
# Aligning brain volume 353 of 4370...Done. Duration: 2.8s
# Aligning brain volume 354 of 4370...Done. Duration: 2.8s
# Aligning brain volume 355 of 4370...Done. Duration: 2.8s
# Aligning brain volume 356 of 4370...Done. Duration: 2.6s
# Aligning brain volume 357 of 4370...Done. Duration: 2.6s
# Aligning brain volume 358 of 4370...Done. Duration: 2.5s
# Aligning brain volume 359 of 4370...Done. Duration: 2.8s
# Aligning brain volume 360 of 4370...Done. Duration: 2.7s
# Aligning brain volume 361 of 4370...Done. Duration: 3.0s
# Aligning brain volume 362 of 4370...Done. Duration: 2.9s
# Aligning brain volume 363 of 4370...Done. Duration: 2.8s
# Aligning brain volume 364 of 4370...Done. Duration: 2.7s
# Aligning brain volume 365 of 4370...Done. Duration: 2.6s
# Aligning brain volume 366 of 4370...Done. Duration: 2.8s
# Aligning brain volume 367 of 4370...Done. Duration: 2.8s
# Aligning brain volume 368 of 4370...Done. Duration: 2.8s
# Aligning brain volume 369 of 4370...Done. Duration: 2.7s
# Aligning brain volume 370 of 4370...Done. Duration: 2.6s
# Aligning brain volume 371 of 4370...Done. Duration: 2.8s
# Aligning brain volume 372 of 4370...Done. Duration: 2.7s
# Aligning brain volume 373 of 4370...Done. Duration: 2.8s
# Aligning brain volume 374 of 4370...Done. Duration: 2.6s
# Aligning brain volume 375 of 4370...Done. Duration: 2.8s
# Aligning brain volume 376 of 4370...Done. Duration: 2.6s
# Aligning brain volume 377 of 4370...Done. Duration: 2.7s
# Aligning brain volume 378 of 4370...Done. Duration: 2.7s
# Aligning brain volume 379 of 4370...Done. Duration: 2.8s
# Aligning brain volume 380 of 4370...Done. Duration: 2.9s
# Aligning brain volume 381 of 4370...Done. Duration: 2.8s
# Aligning brain volume 382 of 4370...Done. Duration: 2.7s
# Aligning brain volume 383 of 4370...Done. Duration: 3.2s
# Aligning brain volume 384 of 4370...Done. Duration: 2.8s
# Aligning brain volume 385 of 4370...Done. Duration: 3.0s
# Aligning brain volume 386 of 4370...Done. Duration: 2.6s
# Aligning brain volume 387 of 4370...Done. Duration: 2.8s
# Aligning brain volume 388 of 4370...Done. Duration: 2.8s
# Aligning brain volume 389 of 4370...Done. Duration: 2.8s
# Aligning brain volume 390 of 4370...Done. Duration: 2.7s
# Aligning brain volume 391 of 4370...Done. Duration: 2.8s
# Aligning brain volume 392 of 4370...Done. Duration: 2.8s
# Aligning brain volume 393 of 4370...Done. Duration: 2.6s
# Aligning brain volume 394 of 4370...Done. Duration: 2.7s
# Aligning brain volume 395 of 4370...Done. Duration: 2.6s
# Aligning brain volume 396 of 4370...Done. Duration: 3.0s
# Aligning brain volume 397 of 4370...Done. Duration: 2.7s
# Aligning brain volume 398 of 4370...Done. Duration: 2.7s
# Aligning brain volume 399 of 4370...Done. Duration: 2.7s
# Aligning brain volume 400 of 4370...Done. Duration: 2.9s
# Aligning brain volume 401 of 4370...Done. Duration: 2.7s
# Aligning brain volume 402 of 4370...Done. Duration: 2.7s
# Aligning brain volume 403 of 4370...Done. Duration: 2.9s
# Aligning brain volume 404 of 4370...Done. Duration: 2.8s
# Aligning brain volume 405 of 4370...Done. Duration: 2.7s
# Aligning brain volume 406 of 4370...Done. Duration: 3.2s
# Aligning brain volume 407 of 4370...Done. Duration: 2.6s
# Aligning brain volume 408 of 4370...Done. Duration: 2.7s
# Aligning brain volume 409 of 4370...Done. Duration: 2.9s
# Aligning brain volume 410 of 4370...Done. Duration: 2.7s
# Aligning brain volume 411 of 4370...Done. Duration: 2.8s
# Aligning brain volume 412 of 4370...Done. Duration: 2.9s
# Aligning brain volume 413 of 4370...Done. Duration: 2.7s
# Aligning brain volume 414 of 4370...Done. Duration: 2.7s
# Aligning brain volume 415 of 4370...Done. Duration: 2.7s
# Aligning brain volume 416 of 4370...Done. Duration: 2.9s
# Aligning brain volume 417 of 4370...Done. Duration: 2.7s
# Aligning brain volume 418 of 4370...Done. Duration: 2.9s
# Aligning brain volume 419 of 4370...Done. Duration: 3.0s
# Aligning brain volume 420 of 4370...Done. Duration: 2.7s
# Aligning brain volume 421 of 4370...Done. Duration: 2.9s
# Aligning brain volume 422 of 4370...Done. Duration: 2.8s
# Aligning brain volume 423 of 4370...Done. Duration: 2.2s
# Aligning brain volume 424 of 4370...Done. Duration: 2.3s
# Aligning brain volume 425 of 4370...Done. Duration: 2.2s
# Aligning brain volume 426 of 4370...Done. Duration: 2.1s
# Aligning brain volume 427 of 4370...Done. Duration: 2.1s
# Aligning brain volume 428 of 4370...Done. Duration: 2.1s
# Aligning brain volume 429 of 4370...Done. Duration: 2.5s
# Aligning brain volume 430 of 4370...Done. Duration: 2.3s
# Aligning brain volume 431 of 4370...Done. Duration: 2.2s
# Aligning brain volume 432 of 4370...Done. Duration: 2.2s
# Aligning brain volume 433 of 4370...Done. Duration: 2.3s
# Aligning brain volume 434 of 4370...Done. Duration: 2.3s
# Aligning brain volume 435 of 4370...Done. Duration: 2.2s
# Aligning brain volume 436 of 4370...Done. Duration: 2.1s
# Aligning brain volume 437 of 4370...Done. Duration: 2.1s
# Aligning brain volume 438 of 4370...Done. Duration: 1.9s
# Aligning brain volume 439 of 4370...Done. Duration: 2.1s
# Aligning brain volume 440 of 4370...Done. Duration: 2.1s
# Aligning brain volume 441 of 4370...Done. Duration: 2.1s
# Aligning brain volume 442 of 4370...Done. Duration: 1.9s
# Aligning brain volume 443 of 4370...Done. Duration: 2.3s
# Aligning brain volume 444 of 4370...Done. Duration: 2.1s
# Aligning brain volume 445 of 4370...Done. Duration: 2.0s
# Aligning brain volume 446 of 4370...Done. Duration: 2.0s
# Aligning brain volume 447 of 4370...Done. Duration: 2.2s
# Aligning brain volume 448 of 4370...Done. Duration: 2.0s
# Aligning brain volume 449 of 4370...Done. Duration: 2.2s
# Aligning brain volume 450 of 4370...Done. Duration: 2.1s
# Aligning brain volume 451 of 4370...Done. Duration: 2.2s
# Aligning brain volume 452 of 4370...Done. Duration: 2.3s
# Aligning brain volume 453 of 4370...Done. Duration: 2.1s
# Aligning brain volume 454 of 4370...Done. Duration: 2.0s
# Aligning brain volume 455 of 4370...Done. Duration: 1.9s
# Aligning brain volume 456 of 4370...Done. Duration: 2.0s
# Aligning brain volume 457 of 4370...Done. Duration: 2.0s
# Aligning brain volume 458 of 4370...Done. Duration: 2.1s
# Aligning brain volume 459 of 4370...Done. Duration: 2.1s
# Aligning brain volume 460 of 4370...Done. Duration: 2.2s
# Aligning brain volume 461 of 4370...Done. Duration: 2.1s
# Aligning brain volume 462 of 4370...Done. Duration: 2.4s
# Aligning brain volume 463 of 4370...Done. Duration: 2.2s
# Aligning brain volume 464 of 4370...Done. Duration: 2.2s
# Aligning brain volume 465 of 4370...Done. Duration: 2.1s
# Aligning brain volume 466 of 4370...Done. Duration: 2.0s
# Aligning brain volume 467 of 4370...Done. Duration: 2.0s
# Aligning brain volume 468 of 4370...Done. Duration: 2.2s
# Aligning brain volume 469 of 4370...Done. Duration: 2.2s
# Aligning brain volume 470 of 4370...Done. Duration: 2.1s
# Aligning brain volume 471 of 4370...Done. Duration: 2.1s
# Aligning brain volume 472 of 4370...Done. Duration: 2.2s
# Aligning brain volume 473 of 4370...Done. Duration: 2.2s
# Aligning brain volume 474 of 4370...Done. Duration: 2.1s
# Aligning brain volume 475 of 4370...Done. Duration: 2.2s
# Aligning brain volume 476 of 4370...Done. Duration: 2.3s
# Aligning brain volume 477 of 4370...Done. Duration: 2.3s
# Aligning brain volume 478 of 4370...Done. Duration: 2.2s
# Aligning brain volume 479 of 4370...Done. Duration: 2.1s
# Aligning brain volume 480 of 4370...Done. Duration: 2.2s
# Aligning brain volume 481 of 4370...Done. Duration: 2.2s
# Aligning brain volume 482 of 4370...Done. Duration: 2.0s
# Aligning brain volume 483 of 4370...Done. Duration: 1.9s
# Aligning brain volume 484 of 4370...Done. Duration: 2.1s
# Aligning brain volume 485 of 4370...Done. Duration: 2.2s
# Aligning brain volume 486 of 4370...Done. Duration: 2.0s
# Aligning brain volume 487 of 4370...Done. Duration: 2.2s
# Aligning brain volume 488 of 4370...Done. Duration: 2.4s
# Aligning brain volume 489 of 4370...Done. Duration: 1.9s
# Aligning brain volume 490 of 4370...Done. Duration: 2.3s
# Aligning brain volume 491 of 4370...Done. Duration: 2.2s
# Aligning brain volume 492 of 4370...Done. Duration: 2.2s
# Aligning brain volume 493 of 4370...Done. Duration: 2.3s
# Aligning brain volume 494 of 4370...Done. Duration: 2.2s
# Aligning brain volume 495 of 4370...Done. Duration: 2.1s
# Aligning brain volume 496 of 4370...Done. Duration: 2.1s
# Aligning brain volume 497 of 4370...Done. Duration: 2.0s
# Aligning brain volume 498 of 4370...Done. Duration: 2.0s
# Aligning brain volume 499 of 4370...Done. Duration: 2.3s
# Aligning brain volume 500 of 4370...Done. Duration: 2.5s
# Aligning brain volume 501 of 4370...Done. Duration: 2.1s
# Aligning brain volume 502 of 4370...Done. Duration: 2.0s
# Aligning brain volume 503 of 4370...Done. Duration: 2.1s
# Aligning brain volume 504 of 4370...Done. Duration: 2.1s
# Aligning brain volume 505 of 4370...Done. Duration: 2.0s
# Aligning brain volume 506 of 4370...Done. Duration: 2.1s
# Aligning brain volume 507 of 4370...Done. Duration: 2.1s
# Aligning brain volume 508 of 4370...Done. Duration: 2.2s
# Aligning brain volume 509 of 4370...Done. Duration: 2.1s
# Aligning brain volume 510 of 4370...Done. Duration: 2.2s
# Aligning brain volume 511 of 4370...Done. Duration: 2.0s
# Aligning brain volume 512 of 4370...Done. Duration: 2.3s
# Aligning brain volume 513 of 4370...Done. Duration: 2.1s
# Aligning brain volume 514 of 4370...Done. Duration: 2.1s
# Aligning brain volume 1232 of 4370...Done. Duration: 2.2s
# Aligning brain volume 1233 of 4370...Done. Duration: 2.3s
# Aligning brain volume 1234 of 4370...Done. Duration: 2.1s
# Aligning brain volume 2308 of 4370...Done. Duration: 2.1s
# Aligning brain volume 2309 of 4370...Done. Duration: 2.0s
# Aligning brain volume 3377 of 4370...Done. Duration: 2.1s
# Aligning brain volume 3378 of 4370...Done. Duration: 2.2s
# Aligning brain volume 3950 of 4370...Done. Duration: 2.2s
# Aligning brain volume 3951 of 4370...Done. Duration: 2.2s
# Aligning brain volume 3952 of 4370...

# %%
dims
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-36a6f5784c3d> in <module>()
# ----> 1 dims
#
# NameError: name 'dims' is not defined
