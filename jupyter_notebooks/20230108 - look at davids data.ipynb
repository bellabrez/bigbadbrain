# %%
import brainsss
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cluster import AgglomerativeClustering
import scipy
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import fcluster
from scipy.cluster import hierarchy
import matplotlib as mpl
from matplotlib.pyplot import cm
import random
from scipy.stats import sem
import time
import h5py
import ants
import nibabel as nib
import matplotlib
from scipy.ndimage import gaussian_filter1d
from scipy.fftpack import fft,fftshift,ifft
from scipy import signal
import pickle
from matplotlib.colors import Normalize
import cv2
import tqdm
# Out:
# /home/users/brezovec/.local/lib/python3.6/site-packages/ants/viz/render_surface_function.py:16: UserWarning: Cant import Plotly. Install it `pip install chart_studio` if you want to use ants.render_surface_function
#   "Cant import Plotly. Install it `pip install chart_studio` if you want to use ants.render_surface_function"

# %%
load_directory = "/oak/stanford/groups/trc/data/David/Bruker/preprocessed/SS84990_DNa03_x_GCaMP6f/fly_003/func1/"

# %%
os.listdir(os.path.join(load_directory,'imaging'))
# Out:
# ['voltage_output.xml',
#  'channel_1.nii',
#  'bleaching.png',
#  'scan.json',
#  'timestamps.h5',
#  'recording_metadata.xml',
#  'channel_1_mean.nii']

# %%
#file = os.path.join(load_directory,'channel_1_moco_zscore_highpass.nii')
file = os.path.join(load_directory,'imaging','channel_1.nii')
brain = np.asarray(nib.load(file).get_data().squeeze(), dtype='float32')

# %%
plt.imshow(brain[:,:,20,0].T)

# %%
timestamps = brainsss.load_timestamps(os.path.join(load_directory, 'imaging'),"recording_metadata.xml")
# Out:
# Trying to load timestamp data from hdf5 file.
# Success.

# %%
timestamps.shape
# Out:
# (2659, 35)

# %%
fictrac_raw = brainsss.load_fictrac(os.path.join(load_directory, 'fictrac'))
resolution = 10 #desired resolution in ms
fps = 100
expt_len = fictrac_raw.shape[0]/fps*1000

# %%
plt.plot(np.asarray(fictrac_raw['dRotLabY']))

# %%
# Get brain size
x_dim = brain.shape[0]
y_dim = brain.shape[1]
z_dim = brain.shape[2]

# %%
### Correlate ###
corr_brains = {}
for behavior,short in zip(['dRotLabZneg', 'dRotLabZpos'],['R', 'L']):
    corr_brain = np.zeros((x_dim,y_dim))
    z = 10
    fictrac_interp = brainsss.smooth_and_interp_fictrac(fictrac_raw, fps, resolution, expt_len, behavior, timestamps=timestamps, z=z)

    for i in range(x_dim):
        for j in range(y_dim):
            # nan to num should be taken care of in zscore, but checking here for some already processed brains
            if np.any(np.isnan(brain[i,j,z,:])):
                printlog(F'warning found nan at x = {i}; y = {j}; z = {z}')
                corr_brain[i,j] = 0
            elif len(np.unique(brain[i,j,z,:])) == 1:
                corr_brain[i,j] = 0
            else:
                corr_brain[i,j] = scipy.stats.pearsonr(fictrac_interp, brain[i,j,z,:])[0]
    corr_brains[short] = corr_brain

# %%
plt.imshow(corr_brains['L'].T,vmin=0,vmax=.1)

# %%
plt.imshow(corr_brains['R'].T,vmin=0,vmax=.1)
#plt.axhline(195)
#plt.axvline(97)

# %%
os.listdir('/oak/stanford/groups/trc/data/David/Bruker/preprocessed/SS84990_DNa03_x_GCaMP6f/fly_003/func1/imaging')
# Out:
# ['voltage_output.xml',
#  'channel_1.nii',
#  'bleaching.png',
#  'scan.json',
#  'recording_metadata.xml',
#  'channel_1_mean.nii']

# %%
brain.shape
# Out:
# (256, 256, 35, 2659)

# %%
plt.imshow(brain[:,:,5,0].T)

# %%
plt.plot(brain[97,195,10,:])

# %%
#file = os.path.join(load_directory,'channel_1_moco_zscore_highpass.nii')
file = os.path.join(load_directory,'imaging','channel_1_mean.nii')
brainmean = np.asarray(nib.load(file).get_data().squeeze(), dtype='float32')

# %%
plt.imshow(brainmean[:,:,10].T)
plt.axhline(160)
plt.axvline(80)
