# %%
import pickle
import os
import time
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.decomposition import FastICA
from mpl_toolkits.axes_grid1 import ImageGrid
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram
import nibabel as nib
import ants
from scipy.ndimage.morphology import binary_erosion
from scipy.ndimage.morphology import binary_dilation
import cv2
import bigbadbrain as bbb
import scipy
from scipy.interpolate import interp1d
from matplotlib.colors import ListedColormap
from matplotlib.pyplot import cm
import matplotlib.colors as mcolors
import matplotlib
import tqdm
import brainsss
from scipy import signal
from scipy.ndimage.filters import gaussian_filter1d
from scipy.spatial.transform import Rotation as R
# Out:
# /home/users/brezovec/.local/lib/python3.6/site-packages/ants/viz/render_surface_function.py:16: UserWarning: Cant import Plotly. Install it `pip install chart_studio` if you want to use ants.render_surface_function
#   "Cant import Plotly. Install it `pip install chart_studio` if you want to use ants.render_surface_function"

# %%
dir_ = '/oak/stanford/groups/trc/data/Ashley2/imports/20230330__queue__'
os.listdir(dir_)
# Out:
# ['fly 2_20s switch newAB.json',
#  'fly 1_20s switch newAB.json',
#  'SingleImage-12172018-1322-001',
#  'fly1_20s_func-017',
#  'fly1_20s_anat-018',
#  'fly2_20s_switch_func-019']

# %%
file = '/oak/stanford/groups/trc/data/Ashley2/imports/20230330__queue__/fly1_20s_func-017/ch2_stitched.nii'
brain = ants.image_read(file)

# %%
brain.shape
# Out:
# (256, 128, 49, 6761)

# %%
m_brain = np.mean(brain.numpy(),axis=(0,1,2))

# %%
plt.plot(m_brain)

# %%
plt.imshow(brain[:,:,20,1000].T)

# %%
/oak/stanford/groups/trc/data/Ashley2/imports/20230405__queue__
