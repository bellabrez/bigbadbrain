# %%
import numpy as np
from time import time
import os
import sys
import scipy
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
import pandas as pd
import psutil

sys.path.insert(0, '/home/users/brezovec/.local/lib/python3.6/site-packages/lib/python/')
import ants

import BigBadBrain as bbb

# %%
first_half = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20190101_walking_dataset/fly_30/optic/motcorr/motcorr_green_first_half.nii'
second_half = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20190101_walking_dataset/fly_30/optic/motcorr/motcorr_green_second_half.nii'

# %%
brain1 = bbb.load_numpy_brain(first_half)
brain2 = bbb.load_numpy_brain(second_half)
# Out:
# ~~ load_numpy_brain ~~
# load_numpy_brain done. Duration: 23.91 sec
#
# ~~ load_numpy_brain ~~
# load_numpy_brain done. Duration: 24.57 sec

# %%
brain = np.concatenate((brain1,brain2),axis=-1)

# %%
brain.shape
# Out:
# (256, 256, 17, 5064)

# %%
brain1 = None
brain2 = None

# %%
save_file = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20190101_walking_dataset/fly_30/optic/motcorr/motcorr_green.nii'
bbb.save_brain(save_file, brain)
# Out:
# ~~ save_brain ~~

# %%
memory_usage = psutil.Process(os.getpid()).memory_info().rss*10**-9

# %%
def print_mem():
    process = psutil.Process(os.getpid())
    memory_usage = process.memory_info().rss
    print(memory_usage*10**-9)

def test():
    file = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20190101_walking_dataset/fly_30/optic/motcorr/motcorr_green_first_half.nii'
    brain = bbb.load_numpy_brain(file)
    print_mem()
    sys.stdout.flush()

# %%
print_mem()
test()
print_mem()
# Out:
# 0.60977152
#
# ~~ load_numpy_brain ~~
# load_numpy_brain done. Duration: 19.00 sec
# 23.181451264
# 0.6139985920000001

# %%
print_mem()
# Out:
# 45.748924416

# %%
memory_usage
# Out:
# 0.6139985920000001

# %%
plt.imshow(brain2[:,:,5,0])
plt.show()

# %%
process = psutil.Process(os.getpid())
memory_usage = process.memory_info().rss
print(memory_usage*10**-9)
# Out:
# 0.605372416

# %%
23.177355264000003-0.605372416
# Out:
# 22.571982848

# %%
import math

# %%
0.041889792
