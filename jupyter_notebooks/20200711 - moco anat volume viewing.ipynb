# %%
import sys
sys.path.insert(0, '/home/users/brezovec/.local/lib/python3.6/site-packages/lib/python/')
import ants
import os
import bigbadbrain as bbb
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy
import nibabel as nib
import psutil
# %matplotlib inline

# %%
root_directory = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20190101_walking_dataset/fly_171/anat_0/moco'

# %%
file = os.path.join(root_directory, 'stitched_brain_red.nii')
brain = nib.load(file).get_data()
#brain = np.asarray(nib.load(file).get_data(), dtype='float32')

# %%
brain.shape
# Out:
# (1024, 512, 241, 100)

# %%
meanbrain = np.mean(brain, axis=-1)

# %%
save_file = os.path.join(root_directory, 'stitched_brain_red_mean.nii')
aff = np.eye(4)
img = nib.Nifti1Image(meanbrain, aff)
img.to_filename(save_file)

# %%
plt.figure(figsize=(10,10))
plt.imshow(meanbrain[:,:,70].T)
