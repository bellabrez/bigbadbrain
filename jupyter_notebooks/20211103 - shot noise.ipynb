# %%
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
file = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20190101_walking_dataset/fly_087/func_0/imaging'
os.listdir(file)
#data = np.array(nib.load(file).get_data(), copy=True)
# Out:
# ['timestamps.h5',
#  'functional.xml',
#  'functional_channel_1_mean.nii',
#  'bleaching.png',
#  'functional_channel_2_mean.nii',
#  'functional_channel_2.nii',
#  'voltage_output.xml',
#  'scan.json',
#  'functional_channel_1.nii']

# %%
file = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20190101_walking_dataset/fly_087/func_0/imaging/functional_channel_2_mean.nii'
#os.listdir(file)
data = np.array(nib.load(file).get_data(), copy=True)

# %%
data.shape
# Out:
# (256, 128, 49)

# %%
plt.figure(figsize=(10,10))
plt.imshow(data[:,:,20].T)
plt.axvline(115)
plt.axhline(50)

# %%
file = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20190101_walking_dataset/fly_087/func_0/imaging/functional_channel_1.nii'
#os.listdir(file)
data = np.array(nib.load(file).get_data(), copy=True)

# %%
data.shape
# Out:
# (256, 128, 49, 3384)

# %%
plt.figure(figsize=(10,10))
plt.plot(data[115,50,20,1000:2000])

# %%
plt.hist(data[115,50,20,:],bins=100); #channel 2 (green)

# %%
plt.hist(data[115,50,20,:],bins=100);
