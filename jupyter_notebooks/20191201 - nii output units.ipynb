# %%
import sys
sys.path.insert(0, '/home/users/brezovec/.local/lib/python3.6/site-packages/lib/python/')
import ants
import os
import bigbadbrain as bbb
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy
from scipy.ndimage.filters import gaussian_filter
# %matplotlib inline

# %%
plt.rcParams.update({'font.size': 20})

# %%
root_directory = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20190101_walking_dataset/'

# %% [markdown]
# # Load Meanbrain

# %%
file = os.path.join(root_directory,
                    '20191130_meanbrain',
                    'meanbrain_syn_round2.nii')

meanbrain = bbb.load_numpy_brain(file)

# Reset spacing
meanbrain = ants.from_numpy(meanbrain)
anatomy_xml = os.path.join(root_directory, 'fly_25', 'anat_0', 'anatomy.xml')
meanbrain.set_spacing(bbb.get_resolution(anatomy_xml))
# Out:
# ~~ load_numpy_brain ~~
# load_numpy_brain done. Duration: 453.06 ms

# %%
plt.figure(figsize=(10,10))
ax = plt.subplot()
ax.imshow(meanbrain.numpy()[:,:,150].T)

# %%
save_file = os.path.join(root_directory, '20191201_meanbrain_unit_testing', 'anatomy_20191201.nii')

# %%
save_file
# Out:
# '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20190101_walking_dataset/20191201_meanbrain_unit_testing/meanbrain_20191201.nii'

# %%
meanbrain
# Out:
# ANTsImage (RAI)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (512, 368, 251)
# 	 Spacing    : (0.768, 0.768, 1.0)
# 	 Origin     : (0.0, 0.0, 0.0)
# 	 Direction  : [1. 0. 0. 0. 1. 0. 0. 0. 1.]

# %%
ants.image_write(anatomy, save_file)

# %%
file = os.path.join(root_directory, 'fly_19', 'anat_0', 'anatomy.nii')
anatomy = bbb.load_numpy_brain(file)
anatomy_xml = os.path.join(root_directory, 'fly_19', 'anat_0', 'anatomy.xml')
anatomy = ants.from_numpy(anatomy)
anatomy.set_spacing(bbb.get_resolution(anatomy_xml))
# Out:
# ~~ load_numpy_brain ~~
# load_numpy_brain done. Duration: 490.38 ms

# %%
bbb.save_brain(save_file, meanbrain)
# Out:
# ~~ save_brain ~~
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-584b18a1d360> in <module>()
# ----> 1 bbb.save_brain(save_file, meanbrain)
#
# ~/projects/bigbadbrain/bigbadbrain/utils.py in wrapper(*args, **kwargs)
#      44         print('\n~~ {} ~~'.format(f.__name__))
#      45         sys.stdout.flush()
# ---> 46         result = f(*args, **kwargs)
#      47         end = time()
#      48         duration = end-start
#
# ~/projects/bigbadbrain/bigbadbrain/brain.py in save_brain(file, brain)
#      61     Nothing. """
#      62
# ---> 63     ants.image_write(ants.from_numpy(brain), file)
#      64     memory_usage = psutil.Process(os.getpid()).memory_info().rss*10**-9
#      65     print('Current memory usage: {:.2f}GB'.format(memory_usage))
#
# ~/.local/lib/python3.6/site-packages/lib/python/ants/core/ants_image_io.py in from_numpy(data, origin, spacing, direction, has_components, is_rgb)
#     102         image with given data and any given information
#     103     """
# --> 104     data = data.astype('float32') if data.dtype.name == 'float64' else data
#     105     img = _from_numpy(data.T.copy(), origin, spacing, direction, has_components, is_rgb)
#     106     return img
#
# AttributeError: 'str' object has no attribute 'name'

# %%
bbb.save_brain?

# %%
ants.image_write?
