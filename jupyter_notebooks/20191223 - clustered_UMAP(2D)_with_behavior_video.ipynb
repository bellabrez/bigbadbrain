# %%
import numpy as np
import time
import os
import sys
import scipy
import math
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from scipy.interpolate import interp1d
import pandas as pd
import psutil
import json
from tqdm import tqdm
sys.path.insert(0, '/home/users/brezovec/.local/lib/python3.6/site-packages/lib/python/')
import ants
import bigbadbrain as bbb
from scipy.linalg import toeplitz
import scipy.linalg as sl
from scipy.signal import convolve2d
from scipy.signal import convolve
import sklearn
from sklearn.linear_model import LassoLarsIC
from sklearn.linear_model import LinearRegression
from sklearn.decomposition import PCA
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LassoCV
from sklearn.model_selection import KFold
from sklearn.feature_selection import RFE
from sklearn import linear_model

from skimage.filters import threshold_triangle
sys.path.insert(0, '/home/users/brezovec/.local/lib/python3.6/site-packages')
import os
import statsmodels.api as sm

from matplotlib.animation import FuncAnimation
from matplotlib import animation, rc
from IPython.display import HTML
from mpl_toolkits.mplot3d import Axes3D

import cv2

# %matplotlib inline

# %%
from matplotlib.patches import FancyArrowPatch
from mpl_toolkits.mplot3d import proj3d

class Arrow3D(FancyArrowPatch):
    def __init__(self, xs, ys, zs, *args, **kwargs):
        FancyArrowPatch.__init__(self, (0,0), (0,0), *args, **kwargs)
        self._verts3d = xs, ys, zs

    def draw(self, renderer):
        xs3d, ys3d, zs3d = self._verts3d
        xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
        self.set_positions((xs[0],ys[0]),(xs[1],ys[1]))
        FancyArrowPatch.draw(self, renderer)

# %%
directory = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20190101_walking_dataset/fly_19/func_0'

# %% [markdown]
# # UMAP

# %%
import umap

# %%
t0 = time.time()
save_file = os.path.join(directory, 'pca', 'loadings_(temporal).npy')
pca_loadings = np.load(save_file)
print('Duration: {}'.format(time.time()-t0))
# Out:
# Duration: 0.19443607330322266

# %%
t0 = time.time()
reducer = umap.UMAP(n_neighbors=60,min_dist=0,n_components=2)
X = reducer.fit_transform(pca_loadings[:,:10])
print('Duration: {}'.format(time.time()-t0))
# Out:
# Duration: 27.213212728500366

# %% [markdown]
# # Cluster

# %%
import hdbscan

# %%
lines4cluster = []
for i in range(X.shape[0]-1):
    lines4cluster.append(tuple(X[i:i+2,0]) + tuple(X[i:i+2,1]))
lines4cluster = np.asarray(lines4cluster)

# %%
min_cluster_size=10
min_samples=30
cluster_selection_epsilon=.5

t0 = time.time()
lines_clustered = hdbscan.HDBSCAN(min_cluster_size=min_cluster_size,
                                    min_samples=min_samples,
                                    cluster_selection_epsilon=cluster_selection_epsilon,
                                    cluster_selection_method='leaf').fit(lines4cluster)
lines_clustered.labels_ += 1
labels = lines_clustered.labels_
num_zeros = len(np.where(lines_clustered.labels_ == 0)[0])
num_points = len(lines_clustered.labels_)

print('{} clusters. {:0.0f}% timepoints in a cluster.'.format(
    max(lines_clustered.labels_),100-(num_zeros/num_points*100)))
# Out:
# 29 clusters. 32% timepoints in a cluster.

# %%
num_zeros
# Out:
# 222

# %%
for i in range(20,50):
    min_cluster_size=i#10
    min_samples=30
    cluster_selection_epsilon=.5
    t0 = time.time()
    lines_clustered = hdbscan.HDBSCAN(min_cluster_size=min_cluster_size,
                                        min_samples=min_samples,
                                        cluster_selection_epsilon=cluster_selection_epsilon,
                                        cluster_selection_method='leaf').fit(lines4cluster)
    lines_clustered.labels_ += 1
    labels = lines_clustered.labels_
    num_zeros = len(np.where(lines_clustered.labels_ == 0)[0])
    num_points = len(lines_clustered.labels_)

    print('i:{},{} clusters. {:0.0f}% timepoints in a cluster.'.format(i,
        max(lines_clustered.labels_),100-(num_zeros/num_points*100)))
# Out:
# i:20,24 clusters. 37% timepoints in a cluster.
# i:21,24 clusters. 37% timepoints in a cluster.
# i:22,24 clusters. 37% timepoints in a cluster.
# i:23,24 clusters. 37% timepoints in a cluster.
# i:24,23 clusters. 42% timepoints in a cluster.
# i:25,21 clusters. 41% timepoints in a cluster.
# i:26,21 clusters. 41% timepoints in a cluster.
# i:27,21 clusters. 41% timepoints in a cluster.
# i:28,21 clusters. 41% timepoints in a cluster.
# i:29,20 clusters. 41% timepoints in a cluster.
# i:30,19 clusters. 40% timepoints in a cluster.
# i:31,18 clusters. 44% timepoints in a cluster.
# i:32,18 clusters. 44% timepoints in a cluster.
# i:33,17 clusters. 46% timepoints in a cluster.
# i:34,16 clusters. 46% timepoints in a cluster.
# i:35,16 clusters. 46% timepoints in a cluster.
# i:36,16 clusters. 46% timepoints in a cluster.
# i:37,16 clusters. 46% timepoints in a cluster.
# i:38,16 clusters. 46% timepoints in a cluster.
# i:39,14 clusters. 45% timepoints in a cluster.
# i:40,14 clusters. 45% timepoints in a cluster.
# i:41,13 clusters. 46% timepoints in a cluster.
# i:42,13 clusters. 46% timepoints in a cluster.
# i:43,13 clusters. 46% timepoints in a cluster.
# i:44,13 clusters. 46% timepoints in a cluster.
# i:45,13 clusters. 46% timepoints in a cluster.
# i:46,13 clusters. 46% timepoints in a cluster.
# i:47,13 clusters. 46% timepoints in a cluster.
# i:48,13 clusters. 46% timepoints in a cluster.
# i:49,13 clusters. 46% timepoints in a cluster.

# %%
lines_clustered = hdbscan.HDBSCAN(min_cluster_size=8,
                                    min_samples=2,
                                    cluster_selection_epsilon=.5,
                                    cluster_selection_method='leaf').fit(lines4cluster)
lines_clustered.labels_ += 1
labels = lines_clustered.labels_
num_zeros = len(np.where(lines_clustered.labels_ == 0)[0])
num_points = len(lines_clustered.labels_)

num_clusters = max(lines_clustered.labels_)
fraction_in_clusters = 100-(num_zeros/num_points*100)

# %%
cluster_params = []

for MCS in np.arange(2, 20, 2): #10
    for MS in np.arange(2, 20, 2): #30
        for CSE in np.arange(0.1, 2, 0.2): #0.5
            MCS=int(MCS)
            MS=int(MS)
            CSE=float(CSE)
            lines_clustered = hdbscan.HDBSCAN(min_cluster_size=MCS,
                                                min_samples=MS,
                                                cluster_selection_epsilon=CSE,
                                                cluster_selection_method='leaf').fit(lines4cluster)
            lines_clustered.labels_ += 1
            labels = lines_clustered.labels_
            
            max_in_cluster = len(np.where(labels==mode(labels))[0])
            
            num_zeros = len(np.where(lines_clustered.labels_ == 0)[0])
            num_points = len(lines_clustered.labels_)

            num_clusters = max(lines_clustered.labels_)
            fraction_in_clusters = 100-(num_zeros/num_points*100)
            
            #print('i:{},{} clusters. {:0.0f}% timepoints in a cluster.'.format(i,
            #    num_clusters,100-(num_zeros/num_points*100)))
            #MCSs
            
            
            cluster_params.append({'MCS': MCS, 'MS': MS, 'CSE': CSE,
                                   'num_clusters': num_clusters,
                                   'fraction_in_clusters': fraction_in_clusters,
                                   'max_in_cluster': max_in_cluster})

# %%
fraction_in_clusters = []
num_clusters = []
MCSs = []
MSs = []
CSEs = []
max_in_clusters = []

for params in cluster_params:
    fraction_in_clusters.append(params['fraction_in_clusters'])
    num_clusters.append(params['num_clusters'])
    MCSs.append(params['MCS'])
    MSs.append(params['MS'])
    CSEs.append(params['CSE'])
    max_in_clusters.append(params['max_in_cluster'])
    
    #print('{:0.0f},{}'.format(params['fraction_in_clusters'], params['num_clusters']))

# %%
max_in_clusters
# Out:
# [1880,
#  1210,
#  849,
#  3419,
#  4381,
#  4479,
#  4518,
#  4539,
#  4539,
#  4539,
#  2649,
#  2118,
#  955,
#  2972,
#  3844,
#  4000,
#  4523,
#  4523,
#  4523,
#  4523,
#  2835,
#  2543,
#  1298,
#  2067,
#  3781,
#  3939,
#  4503,
#  4503,
#  4514,
#  4514,
#  2972,
#  2832,
#  1708,
#  1951,
#  3678,
#  3886,
#  4484,
#  4484,
#  4484,
#  4484,
#  2949,
#  2899,
#  1880,
#  1046,
#  3504,
#  3843,
#  3918,
#  3918,
#  3918,
#  3918,
#  3179,
#  3173,
#  2018,
#  1238,
#  3352,
#  3790,
#  3964,
#  3964,
#  3964,
#  3964,
#  3171,
#  3171,
#  2417,
#  1399,
#  2760,
#  3693,
#  3943,
#  3943,
#  3943,
#  3943,
#  3257,
#  3257,
#  2382,
#  1674,
#  2708,
#  3784,
#  3945,
#  3945,
#  3945,
#  3945,
#  3233,
#  3233,
#  2622,
#  1837,
#  2659,
#  3951,
#  3951,
#  3951,
#  3951,
#  3951,
#  1961,
#  1368,
#  849,
#  3419,
#  4381,
#  4488,
#  4539,
#  4539,
#  4539,
#  4539,
#  2491,
#  2061,
#  968,
#  2972,
#  3844,
#  4000,
#  4523,
#  4523,
#  4523,
#  4523,
#  2628,
#  2414,
#  1312,
#  2067,
#  3781,
#  3944,
#  4503,
#  4503,
#  4503,
#  4503,
#  2791,
#  2703,
#  1623,
#  1979,
#  3697,
#  3886,
#  4484,
#  4484,
#  4484,
#  4484,
#  2831,
#  2781,
#  1808,
#  1046,
#  3525,
#  3843,
#  3918,
#  3918,
#  3918,
#  3918,
#  3016,
#  3016,
#  2015,
#  1244,
#  3352,
#  3794,
#  3964,
#  3964,
#  3964,
#  3964,
#  2966,
#  2966,
#  2298,
#  1396,
#  2760,
#  3693,
#  3943,
#  3943,
#  3943,
#  3943,
#  3094,
#  3094,
#  2392,
#  1676,
#  2708,
#  3945,
#  3945,
#  3945,
#  3945,
#  3945,
#  3022,
#  3022,
#  2566,
#  1835,
#  2659,
#  3951,
#  3951,
#  3951,
#  3951,
#  3951,
#  1879,
#  1483,
#  856,
#  3419,
#  4388,
#  4488,
#  4539,
#  4539,
#  4539,
#  4539,
#  2316,
#  1992,
#  958,
#  3002,
#  3852,
#  4000,
#  4523,
#  4523,
#  4523,
#  4523,
#  2456,
#  2298,
#  1317,
#  2067,
#  3781,
#  3982,
#  4503,
#  4503,
#  4503,
#  4503,
#  2801,
#  2708,
#  1637,
#  1979,
#  3697,
#  3886,
#  3956,
#  3956,
#  3956,
#  3956,
#  2754,
#  2672,
#  1817,
#  1047,
#  3525,
#  3843,
#  3918,
#  3918,
#  3918,
#  3918,
#  2877,
#  2877,
#  1957,
#  1248,
#  3352,
#  3794,
#  3964,
#  3964,
#  3964,
#  3964,
#  2850,
#  2850,
#  2153,
#  1400,
#  2760,
#  3693,
#  3943,
#  3943,
#  3943,
#  3943,
#  2797,
#  2797,
#  2268,
#  1681,
#  2708,
#  3945,
#  3945,
#  3945,
#  3945,
#  3945,
#  2958,
#  2958,
#  2544,
#  1813,
#  2659,
#  3951,
#  3951,
#  3951,
#  3951,
#  3951,
#  1882,
#  1521,
#  856,
#  3419,
#  4388,
#  4495,
#  4539,
#  4539,
#  4539,
#  4539,
#  2226,
#  2019,
#  989,
#  3002,
#  3852,
#  4000,
#  4523,
#  4523,
#  4523,
#  4523,
#  2449,
#  2299,
#  1343,
#  2067,
#  3781,
#  3982,
#  4503,
#  4503,
#  4503,
#  4503,
#  2706,
#  2503,
#  1654,
#  1979,
#  3697,
#  3886,
#  3956,
#  3956,
#  3956,
#  3956,
#  2732,
#  2621,
#  1787,
#  1053,
#  3525,
#  3843,
#  3918,
#  3918,
#  3918,
#  3918,
#  2869,
#  2869,
#  1966,
#  1255,
#  3352,
#  3964,
#  3964,
#  3964,
#  3964,
#  3964,
#  2701,
#  2701,
#  2160,
#  1407,
#  2760,
#  3943,
#  3943,
#  3943,
#  3943,
#  3943,
#  2740,
#  2740,
#  2211,
#  1624,
#  2708,
#  3945,
#  3945,
#  3945,
#  3945,
#  3945,
#  

#  3956,
#  3956,
#  3956,
#  3956,
#  3956,
#  3956,
#  2466,
#  2466,
#  1751,
#  1102,
#  3525,
#  3918,
#  3918,
#  3918,
#  3918,
#  3918,
#  2602,
#  2602,
#  2011,
#  1307,
#  3352,
#  3964,
#  3964,
#  3964,
#  3964,
#  3964,
#  2642,
#  2642,
#  2178,
#  1426,
#  2760,
#  3943,
#  3943,
#  3943,
#  3943,
#  3943,
#  2561,
#  2561,
#  2195,
#  1600,
#  2708,
#  3945,
#  3945,
#  3945,
#  3945,
#  3945,
#  2670,
#  2670,
#  2437,
#  1779,
#  2659,
#  3951,
#  3951,
#  3951,
#  3951,
#  3951,
#  1986,
#  1836,
#  924,
#  3452,
#  3928,
#  3928,
#  3928,
#  3928,
#  3928,
#  3928,
#  2100,
#  2053,
#  1216,
#  3002,
#  3866,
#  4000,
#  4000,
#  4000,
#  4000,
#  4000,
#  2079,
#  2044,
#  1430,
#  2067,
#  3982,
#  3982,
#  4403,
#  4403,
#  4403,
#  4403,
#  2281,
#  2254,
#  1582,
#  1979,
#  3956,
#  3956,
#  3956,
#  3956,
#  3956,
#  3956,
#  2441,
#  2441,
#  1726,
#  1102,
#  3525,
#  3918,
#  3918,
#  3918,
#  3918,
#  3918,
#  2635,
#  2635,
#  2044,
#  1265,
#  3352,
#  3964,
#  3964,
#  3964,
#  3964,
#  3964,
#  2578,
#  2578,
#  2194,
#  1442,
#  2760,
#  3943,
#  3943,
#  3943,
#  3943,
#  3943,
#  2594,
#  2594,
#  2228,
#  1633,
#  2708,
#  3945,
#  3945,
#  3945,
#  3945,
#  3945,
#  2670,
#  2670,
#  2437,
#  1779,
#  2659,
#  3951,
#  3951,
#  3951,
#  3951,
#  3951]

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
for i in range(len(MSs)):
    if fraction_in_clusters[i] > 70:
        if num_clusters[i] < 300:
            ax.scatter(fraction_in_clusters[i],
                       num_clusters[i],marker='o',s=max_in_clusters[i]/50,zorder=1,color='k',alpha=1)
            ax.text(fraction_in_clusters[i],num_clusters[i],'{},{},{:0.2f}'.format(MCSs[i],MSs[i],CSEs[i]))
#plt.ylim(0,100)
#plt.xlim(80,100)

# %%
colors = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231',
          '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe',
          '#008080', '#e6beff', '#9a6324', '#fffac8', '#800000',
          '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080',
          '#000000']

# %% [markdown]
# # Or, just load pre-clustered

# %%
file = os.path.join(directory, 'tsne', '20191222_X_labels.npy')
labels=np.load(file)
file = os.path.join(directory, 'tsne', '20191222_X.npy')
X=np.load(file)

# %% [markdown]
# # Visualize

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.scatter(X[:,0], X[:,1],marker='o',s=1,zorder=1,color='k',alpha=0.25)

# %%
i = 10
file_ct = 100

cmap = plt.cm.magma
color = cmap(float(i+1) / float(file_ct))

# %%
color
# Out:
# (0.092949, 0.059904, 0.239164, 1.0)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
#ax.scatter(X[:,0], X[:,1],marker='o',s=1,zorder=1,color='k',alpha=0.25)
cmap = plt.cm.magma
for i in range(X.shape[0]-1):
    alpha = .5
    #color='#000000'
    color = cmap(float(i+1) / float(X.shape[0]))
    a = FancyArrowPatch(X[i,:],X[i+1,:],
                        mutation_scale=6,lw=0.25,arrowstyle="-|>",
                        color=color,alpha=alpha)
    ax.add_artist(a)
window = 6
center = np.mean(X,axis=0)
ax.set_xlim(center[0]-window,center[0]+window)
ax.set_ylim(center[1]-window,center[1]+window)
plt.axis('off')
save_path = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/figs'
timestr = time.strftime("%Y%m%d-%H%M%S")
fname = os.path.join(save_path, '{}.png'.format(timestr))
plt.savefig(fname,dpi=300,bbox_inches='tight')

# %%
len(np.where(labels==0)[0])
# Out:
# 3076

# %%
len(labels)
# Out:
# 4553

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
#ax.scatter(X[:,0], X[:,1], X[:,2],marker='o',s=1,zorder=1,color='k',alpha=0.25)
for i in range(X.shape[0]-1):
    if labels[i] == 0:
        alpha = .25
        color='#000000'
    else:
        alpha = 0
        color=colors[labels[i]%len(colors)]
    a = FancyArrowPatch(X[i,:],X[i+1,:],
                        mutation_scale=12,lw=0.25,arrowstyle="-|>",
                        color=color,alpha=alpha)
    ax.add_artist(a)
    #ax.annotate('default arrow', xy=(0.35,0.3), xytext=(0.6,0.3),
    #        arrowprops={'arrowstyle': '->'}, va='center')
    #ax.plot(X[i:i+2,0],
    #        X[i:i+2,1],
    #        X[i:i+2,2],
    #         alpha=alpha,
    #         lw=1,
    #         #solid_capstyle='butt',
    #         c=colors[lines_clustered.labels_[i]%len(colors)],
    #         zorder=0)
window = 6
center = np.mean(X,axis=0)
ax.set_xlim(center[0]-window,center[0]+window)
ax.set_ylim(center[1]-window,center[1]+window)
ax.margins(x=0, y=0)
#ax.set_proj_type('ortho')
plt.axis('off')
# for k,angle in enumerate(range(360)):
#     print(angle)
#     ax.view_init(0,angle)
#     fname = os.path.join(save_path, '{0:05d}.png'.format(k))
#     plt.savefig(fname,dpi=300,bbox_inches='tight')
# Out:
# (-8.453535318374634, 3.546464681625366, -3.186042070388794, 8.813957929611206)

# %%
lines4cluster.shape
# Out:
# (4553, 4)

# %%
clusters = {}
for i in range(max(labels)):
    indicies = np.where(labels == i)[0]
    clusters[i] = lines4cluster[indicies,:]

# %%
clusters[1]
# Out:
# array([[-1.2327762 , -3.5160298 , -1.4805764 ,  5.3034196 ],
#        [-1.5172899 , -3.5111785 , -1.2689811 ,  5.337848  ],
#        [-1.4443246 , -3.4365554 , -1.2978736 ,  5.168795  ],
#        [-1.4111454 , -3.8372133 , -1.969103  ,  4.9547467 ],
#        [-1.8214133 , -3.9724245 , -1.843819  ,  4.924122  ],
#        [-1.0838304 , -3.9911363 , -1.3885251 ,  5.0974326 ],
#        [-1.1013713 , -3.7951975 , -1.8263817 ,  5.2192554 ],
#        [-1.8424411 , -3.9944577 , -1.483952  ,  5.045989  ],
#        [-1.8129908 , -3.7271779 , -1.4263691 ,  5.2742233 ],
#        [-1.4908191 , -4.030443  , -1.7978534 ,  5.0496163 ],
#        [-1.1237122 , -3.8884797 , -1.5538213 ,  5.079287  ],
#        [-1.0613312 , -4.039548  , -1.7602108 ,  5.0655537 ],
#        [-1.057055  , -4.1115646 , -1.7557949 ,  5.039414  ],
#        [-1.1281245 , -4.0436873 , -1.8012754 ,  5.0440483 ],
#        [-0.99399835, -3.7631114 , -1.5545655 ,  5.137939  ],
#        [-1.040103  , -3.5587535 , -1.4700582 ,  5.2266035 ],
#        [-1.0494574 , -3.7315814 , -1.5886121 ,  5.18862   ],
#        [-1.8318838 , -3.5224001 , -1.89018   ,  5.2294126 ]],
#       dtype=float32)

# %%
clusters_array = {}
for i in labels:
    clusters_array[int(i)] = np.asarray(clusters[i])

# %%
cluster_means = {}
for i in range(max(labels)):
    np.mean(clusters[i],axis=0)
    cluster_means[i] = np.mean(clusters[i],axis=0)

# %%
cluster_means[1].shape
# Out:
# (4,)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
#ax.scatter(X[:,0], X[:,1], X[:,2],marker='o',s=1,zorder=1,color='k',alpha=0.25)
for i in range(len(clusters)):
    if i == 0:
        alpha = 0
        color='#000000'
    else:
        alpha = 1
        color=colors[i%len(colors)]
        #clusters[i]#currently x1,x2,y1 y2.
        # quiver wants 

    ax.quiver(clusters[i][:,0],
              clusters[i][:,2],
              clusters[i][:,1],
              clusters[i][:,3],
              scale=5)

    #a = FancyArrowPatch(clusters[i],
    #                    mutation_scale=12,lw=0.25,arrowstyle="-|>",
    #                    color=color,alpha=alpha)
    #ax.add_artist(a)
    #ax.annotate('default arrow', xy=(0.35,0.3), xytext=(0.6,0.3),
    #        arrowprops={'arrowstyle': '->'}, va='center')
    #ax.plot(X[i:i+2,0],
    #        X[i:i+2,1],
    #        X[i:i+2,2],
    #         alpha=alpha,
    #         lw=1,
    #         #solid_capstyle='butt',
    #         c=colors[lines_clustered.labels_[i]%len(colors)],
    #         zorder=0)
window = 6
center = np.mean(X,axis=0)
ax.set_xlim(center[0]-window,center[0]+window)
ax.set_ylim(center[1]-window,center[1]+window)
ax.margins(x=0, y=0)
#ax.set_proj_type('ortho')
#plt.axis('off')
# for k,angle in enumerate(range(360)):
#     print(angle)
#     ax.view_init(0,angle)
#     fname = os.path.join(save_path, '{0:05d}.png'.format(k))
#     plt.savefig(fname,dpi=300,bbox_inches='tight')
#plt.scatter(cluster_means[i][0],cluster_means[i][1],color='white',s=200,zorder=1)
#plt.text(cluster_means[i][0]-1,cluster_means[i][1]-1,str(i))

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)

x_pos = [0, -0.5]
y_pos = [0, 0.5]
x_direct = [1, 0]
y_direct = [1, -1]

ax.quiver(0,0,1,1, scale=3)
ax.axis([-1.5,1.5,-1.5,1.5])
ax.axvline(1)
ax.axhline(1)
ax.axvline(0)
ax.axhline(0)
plt.show()

# %%
cluster_means[1]
# Out:
# array([-1.3357816, -3.803941 , -1.6198862,  5.132574 ], dtype=float32)

# %%
clusters[2]
# Out:
# array([[-4.6100836, -3.0205743, -0.3724821,  3.7659686],
#        [-4.284364 , -2.162209 , -0.5520663,  4.199679 ],
#        [-4.505293 , -2.0879529, -0.4935276,  4.1992507],
#        [-4.552384 , -2.581685 , -0.3916439,  4.0313325]], dtype=float32)

# %%
plt.plot(labels,marker='x',linestyle='')

# %%
len(np.where(labels==36)[0])
# Out:
# 3419

# %%
from statistics import mode

# %%
len(np.where(labels==mode(labels))[0])
# Out:
# 3419

# %%
total=0
for i in range(37):
    #total+=len(clusters[i])
    print(len(np.where(labels==i)[0]))
# Out:
# 222
# 9
# 4
# 11
# 6
# 6
# 5
# 3
# 7
# 5
# 13
# 5
# 4
# 14
# 21
# 8
# 3
# 43
# 346
# 3
# 5
# 12
# 9
# 266
# 21
# 3
# 16
# 3
# 3
# 5
# 5
# 7
# 26
# 3
# 3
# 9
# 3419

# %%
total
# Out:
# 1134

# %%
max(labels)
# Out:
# 36

# %%
len(clusters)
# Out:
# 37

# %%
clusters = {}
for i in range(max(labels)+1):
    indicies = np.where(labels == i)[0]
    clusters[i] = lines4cluster[indicies,:]

# %%
clusters = {}
for i in range(max(labels)+1):
    indicies = np.where(labels == i)[0]
    clusters[i] = lines4cluster[indicies,:]

cluster_means = {}
for i in range(max(labels)+1):
    cluster_means[i] = np.mean(clusters[i],axis=0)

fig = plt.figure(figsize=(20,10))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
#ax.scatter(X[:,0], X[:,1], X[:,2],marker='o',s=1,zorder=1,color='k',alpha=0.25)
for i in range(X.shape[0]-1):
    if labels[i] == 0:
        alpha = .5
        color='#000000'
        a = FancyArrowPatch(X[i,:],X[i+1,:],
                    mutation_scale=6,lw=0.25,arrowstyle="-|>",
                    color=color,alpha=alpha)
        ax2.add_artist(a)
    else:
        alpha = .5
        color=colors[labels[i]%len(colors)]
        a = FancyArrowPatch(X[i,:],X[i+1,:],
                    mutation_scale=6,lw=0.25,arrowstyle="-|>",
                    color=color,alpha=alpha)
        ax1.add_artist(a)

    
#clusters[i]#currently x1,x2,y1 y2.
#arrow patch wants x1,y1,x2,y2
CM=cluster_means
for i in range(len(cluster_means)):
    if i == 0:
        alpha = 0
        color='#000000'
    else:
        alpha = .3
        color='#000000'
    a = FancyArrowPatch(CM[i][[0,2]],CM[i][[1,3]],
                        mutation_scale=10,lw=1,arrowstyle="-|>",
                        color=color,alpha=alpha)
    ax1.add_artist(a)

window = 6
center = np.mean(X,axis=0)
ax1.set_xlim(center[0]-window,center[0]+window)
ax1.set_ylim(center[1]-window,center[1]+window)
ax1.axis('off')
ax2.set_xlim(center[0]-window,center[0]+window)
ax2.set_ylim(center[1]-window,center[1]+window)
ax2.axis('off')


save_path = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/figs'
timestr = time.strftime("%Y%m%d-%H%M%S")
fname = os.path.join(save_path, '{}.png'.format(timestr))
plt.savefig(fname,dpi=300,bbox_inches='tight')

# %%
X.shape
# Out:
# (4554, 2)

# %%
i=0
X[i:i+2,0]
# Out:
# array([-5.1292696, -3.7641215], dtype=float32)

# %%
i=0
X[i+1,:]#-X[i,:]
# Out:
# array([-3.7641215,  2.3057606], dtype=float32)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
#ax.scatter(X[:,0], X[:,1], X[:,2],marker='o',s=1,zorder=1,color='k',alpha=0.25)
for i in range(X.shape[0]-1):
    if labels[i] == 0:
        alpha = 0
        color='#000000'
    else:
        alpha = 1
        color=colors[labels[i]%len(colors)]
    a = Arrow3D(X[i:i+2,0],X[i:i+2,1],X[i:i+2,2],
                mutation_scale=6,lw=0.25,arrowstyle="-|>",
                color=color,alpha=alpha)
    ax.add_artist(a)
    #ax.plot(X[i:i+2,0],
    #        X[i:i+2,1],
    #        X[i:i+2,2],
    #         alpha=alpha,
    #         lw=1,
    #         #solid_capstyle='butt',
    #         c=colors[lines_clustered.labels_[i]%len(colors)],
    #         zorder=0)
window = 2.5
center = np.mean(X,axis=0)
ax.set_xlim(center[0]-window,center[0]+window)
ax.set_ylim(center[1]-window,center[1]+window)
ax.set_zlim(center[2]-window,center[2]+window)
ax.margins(x=0, y=0)
#ax.set_proj_type('ortho')
plt.axis('off')
ax.view_init(0,0)

# for k,angle in enumerate(range(360)):
#     print(angle)
#     ax.view_init(0,angle)
#     fname = os.path.join(save_path, '{0:05d}.png'.format(k))
#     plt.savefig(fname,dpi=300,bbox_inches='tight')

# %% [markdown]
# # Load Video

# %%
timestamps = bbb.load_timestamps(os.path.join(directory, 'imaging'))
fictrac = bbb.load_fictrac(os.path.join(directory, 'fictrac'))
# Out:
# ~~ load_timestamps ~~
# Trying to load timestamp data from hdf5 file.
# Success.
# load_timestamps done. Duration: 4.64 ms
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 2.94 sec

# %%
cap = cv2.VideoCapture('/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/imports/fictrac/fictrac-20190218_133014-raw.avi')
i=0
frames = []
ret = True
while ret is True and i<90000:
    i+=1
    if i%1000 == 0:
        print(i)
    # Capture frame-by-frame
    ret, frame = cap.read()
    frames.append(frame)
cap.release()
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000

# %%
def interp_fictrac(fictrac, behavior, fps, resolution, expt_len, timestamps, interp_to):
    camera_rate = 1/fps * 1000 # camera frame rate in ms
    sphere_radius = 4.5e-3
    filter_window = 51
    
    x_original = np.arange(0,expt_len,camera_rate)
    
    if behavior == 'all':
        dx = np.asarray(fictrac['dRotLabX'])
        dy = np.asarray(fictrac['dRotLabY'])
        dz = np.asarray(fictrac['dRotLabZ'])
        dx = scipy.signal.savgol_filter(dx,filter_window,3) * sphere_radius * 50 * 100 * 10
        dy = scipy.signal.savgol_filter(dy,filter_window,3) * sphere_radius * 50 * 100 * 10
        dz = scipy.signal.savgol_filter(dz,filter_window,3) * 180 / np.pi * 50
        fictrac_smoothed = np.sqrt(dx*dx + dy*dy + dz*dz)
    elif behavior == 'Y':
        dy = np.asarray(fictrac['dRotLabY'])
        fictrac_smoothed = scipy.signal.savgol_filter(dy,filter_window,3) * sphere_radius * 50 * 100 * 10
    elif behavior == 'Z':
        dz = np.asarray(fictrac['dRotLabZ'])
        fictrac_smoothed = scipy.signal.savgol_filter(dz,filter_window,3) * 180 / np.pi * 50
    else:
        print('invalid behavior')
    
    #fictrac_smoothed = np.abs(fictrac_smoothed)
    fictrac_interp_temp = interp1d(x_original, fictrac_smoothed, bounds_error = False)
    xnew = np.arange(0,expt_len,resolution) #0 to last time at subsample res
    
    if interp_to is 'timestamps':
        fictrac_interp = fictrac_interp_temp(timestamps[:,25])
    elif interp_to is 'xnew':
        fictrac_interp = fictrac_interp_temp(xnew)
    else:
        print('Invalid interp_to ({})'.format(interp_to))

    # Replace Nans with zeros (for later code)
    np.nan_to_num(fictrac_interp, copy=False);
    
    return fictrac_interp

# %%
resolution = 20 #desired resolution in ms
expt_len = 1000*30*60
fps = 50 #of fictrac camera
xnew = np.arange(0,expt_len,resolution)

fictracs_high_res = {}
for behavior in ['all', 'Y', 'Z']:
    fictracs_high_res[behavior] = interp_fictrac(fictrac, behavior, fps, resolution, expt_len, timestamps, 'xnew')

fictracs = {}
for behavior in ['all', 'Y', 'Z']:
    fictracs[behavior] = interp_fictrac(fictrac, behavior, fps, resolution, expt_len, timestamps, 'timestamps')

# %%
3
# Out:
# 3

# %%
3

# %%
# a reasonable looking rate of rotation is 20deg/sec
# Here, we have 20 frames a sec, so just update 1deg/frame!

# %%
save_path = os.path.join(directory,'tsne','videos','20191222_2')
#os.mkdir(save_path)

start_ms = int(19.5*60*1000)
stop_ms = int(start_ms + 5*60*1000) # seconds to ms
step_ms = 50
NUM_FRAMES = int((stop_ms-start_ms)/step_ms)
VIDEO_TIMEPOINTS = np.arange(start_ms,stop_ms,step_ms)
#NUM_FRAMES=1

for i in range(150,NUM_FRAMES):
    
    fig = plt.figure(figsize=(10,7))
    fig_ratio = 10/7

    ax1 = fig.add_subplot(111, projection='3d')
    window = 2
    center = np.mean(X,axis=0)
    ax1.set_xlim(center[0]-window,center[0]+window)
    ax1.set_ylim(center[1]-window,center[1]+window)
    ax1.set_zlim(center[2]-window,center[2]+window)
    ax1.margins(x=0, y=0)
    ax1.axis('off')
    ax1.view_init(0,0)

    ax2 = fig.add_axes([0.7, .45, 0.2, 0.8]) # fly movie
    ax2.axis('off')

    print('{} of {}'.format(i,NUM_FRAMES))
    brain_idx = np.searchsorted(timestamps[:,20], VIDEO_TIMEPOINTS[i])
    behavior_idx = np.searchsorted(xnew, VIDEO_TIMEPOINTS[i])
    
    ### PLOT UMAP
    for j in range(X.shape[0]-1):
        if labels[j] == 0:
            alpha = 0
            color='#000000'
        else:
            alpha = 1
            color=colors[labels[j]%len(colors)]
        if j==brain_idx:
            lw=4
            alpha=1
        else:
            lw=0.25
        a = Arrow3D(X[j:j+2,0],X[j:j+2,1],X[j:j+2,2],
                    mutation_scale=6,lw=lw,arrowstyle="-|>",
                    color=color,alpha=alpha)
        ax1.add_artist(a)
        
    ### PLOT FLY
    ax2.imshow(frames[behavior_idx][25:225,250:550,:])
    
    ax1.view_init(0,i%360)
    fname = os.path.join(save_path, '{0:05d}.png'.format(i))
    plt.savefig(fname,dpi=300,bbox_inches='tight')
# Out:
# 593 of 6000
# 594 of 6000
# 595 of 6000
# 596 of 6000
# 597 of 6000
# 598 of 6000
# 599 of 6000
# 600 of 6000
# 601 of 6000
# 602 of 6000
# 603 of 6000
# 604 of 6000
# 605 of 6000
# 606 of 6000
# 607 of 6000
# 608 of 6000
# 609 of 6000
# 610 of 6000
# 611 of 6000
# 612 of 6000
# 613 of 6000
# 614 of 6000
# 615 of 6000
# 616 of 6000
# 617 of 6000
# 618 of 6000
# 619 of 6000
# 620 of 6000
# 621 of 6000
# 622 of 6000
# 623 of 6000
# 624 of 6000
# 625 of 6000
# 626 of 6000
# 627 of 6000
# 628 of 6000
# 629 of 6000
# 630 of 6000
# 631 of 6000
# 632 of 6000
# 633 of 6000
# 634 of 6000
# 635 of 6000
# 636 of 6000
# 637 of 6000
# 638 of 6000
# 639 of 6000
# 640 of 6000
# 641 of 6000
# 642 of 6000
# 643 of 6000
# 644 of 6000
# 645 of 6000
# 646 of 6000
# 647 of 6000
# 648 of 6000
# 649 of 6000
# 650 of 6000
# 651 of 6000
# 652 of 6000
# 653 of 6000
# 654 of 6000
# 655 of 6000
# 656 of 6000
# 657 of 6000
# 658 of 6000
# 659 of 6000
# 660 of 6000
# 661 of 6000
# 662 of 6000
# 663 of 6000
# 664 of 6000
# 665 of 6000
# 666 of 6000
# 667 of 6000
# 668 of 6000
# 669 of 6000
# 670 of 6000
# 671 of 6000
# 672 of 6000
# 673 of 6000
# 674 of 6000
# 675 of 6000
# 676 of 6000
# 677 of 6000
# 678 of 6000
# 679 of 6000
# 680 of 6000
# 681 of 6000
# 682 of 6000
# 683 of 6000
# 684 of 6000
# 685 of 6000
# 686 of 6000
# 687 of 6000
# 688 of 6000
# 689 of 6000
# 690 of 6000
# 691 of 6000
# 692 of 6000
# 693 of 6000
# 694 of 6000
# 695 of 6000
# 696 of 6000
# 697 of 6000
# 698 of 6000
# 699 of 6000
# 700 of 6000
# 701 of 6000
# 702 of 6000
# 703 of 6000
# 704 of 6000
# 705 of 6000
# 706 of 6000
# 707 of 6000
# 708 of 6000
# 709 of 6000
# 710 of 6000
# 711 of 6000
# 712 of 6000
# 713 of 6000
# 714 of 6000
# 715 of 6000
# 716 of 6000
# 717 of 6000
# 718 of 6000
# 719 of 6000
# 720 of 6000
# 721 of 6000
# 722 of 6000
# 723 of 6000
# 724 of 6000
# 725 of 6000
# 726 of 6000
# 727 of 6000
# 728 of 6000
# 729 of 6000
# 730 of 6000
# 731 of 6000
# 732 of 6000
# 733 of 6000
# 734 of 6000
# 735 of 6000
# 736 of 6000
# 737 of 6000
# 738 of 6000
# 739 of 6000
# 740 of 6000
# 741 of 6000
# 742 of 6000
# 743 of 6000
# 744 of 6000
# 745 of 6000
# 746 of 6000
# 747 of 6000
# 748 of 6000
# 749 of 6000
# 750 of 6000
# 751 of 6000
# 752 of 6000
# 753 of 6000
# 754 of 6000
# 755 of 6000
# 756 of 6000
# 757 of 6000
# 758 of 6000
# 759 of 6000
# 760 of 6000
# 761 of 6000
# 762 of 6000
# 763 of 6000
# 764 of 6000
# 765 of 6000
# 766 of 6000
# 767 of 6000
# 768 of 6000
# 769 of 6000
# 770 of 6000
# 771 of 6000
# 772 of 6000
# 773 of 6000
# 774 of 6000
# 775 of 6000
# 776 of 6000
# 777 of 6000
# 778 of 6000
# 779 of 6000
# 780 of 6000
# 781 of 6000
# 782 of 6000
# 783 of 6000
# 784 of 6000
# 785 of 6000
# 786 of 6000
# 787 of 6000
# 788 of 6000
# 789 of 6000
# 790 of 6000
# 791 of 6000
# 792 of 6000
# 793 of 6000
# 794 of 6000
# 795 of 6000
# 796 of 6000
# 797 of 6000
# 798 of 6000
# 799 of 6000
# 800 of 6000
# 801 of 6000
# 802 of 6000
# 803 of 6000
# 804 of 6000
# 805 of 6000
# 806 of 6000
# 807 of 6000
# 808 of 6000
# 809 of 6000
# 810 of 6000
# 811 of 6000
# 812 of 6000
# 813 of 6000
# 814 of 6000
# 815 of 6000
# 816 of 6000
# 817 of 6000
# 818 of 6000
# 819 of 6000
# 820 of 6000
# 821 of 6000
# 822 of 6000
# 823 of 6000
# 824 of 6000
# 825 of 6000
# 826 of 6000
# 827 of 6000
# 828 of 6000
# 829 of 6000
# 830 of 6000
# 831 of 6000
# 832 of 6000
# 833 of 6000
# 834 of 6000
# 835 of 6000
# 836 of 6000
# 837 of 6000
# 838 of 6000
# 839 of 6000
# 840 of 6000
# 841 of 6000
# 842 of 6000
# 843 of 6000
# 844 of 6000
# 845 of 6000
# 846 of 6000
# 847 of 6000
# 848 of 6000
# 849 of 6000
# 850 of 6000
# 851 of 6000
# 852 of 6000
# 853 of 6000
# 854 of 6000
# 855 of 6000
# 856 of 6000
# 857 of 6000
# 858 of 6000
# 859 of 6000
# 860 of 6000
# 861 of 6000
# 862 of 6000
# 863 of 6000
# 864 of 6000
# 865 of 6000
# 866 of 6000
# 867 of 6000
# 868 of 6000
# 869 of 6000
# 870 of 6000
# 871 of 6000
# 872 of 6000
# 873 of 6000
# 874 of 6000
# 875 of 6000
# 876 of 6000
# 877 of 6000
# 878 of 6000
# 879 of 6000
# 880 of 6000
# 881 of 6000
# 882 of 6000
# 883 of 6000
# 884 of 6000
# 885 of 6000
# 886 of 6000
# 887 of 6000
# 888 of 6000
# 889 of 6000
# 890 of 6000
# 891 of 6000
# 892 of 6000
# 893 of 6000
# 894 of 6000
# 895 of 6000
# 896 of 6000
# 897 of 6000
# 898 of 6000
# 899 of 6000
# 900 of 6000
# 901 of 6000
# 902 of 6000
# 903 of 6000
# 904 of 6000
# 905 of 6000
# 906 of 6000
# 907 of 6000
# 908 of 6000
# 909 of 6000
# 910 of 6000
# 911 of 6000
# 912 of 6000
# 913 of 6000
# 914 of 6000
# 915 of 6000
# 916 of 6000
# 917 of 6000
# 918 of 6000
# 919 of 6000
# 920 of 6000
# 921 of 6000
# 922 of 6000
# 923 of 6000
# 924 of 6000
# 925 of 6000
# 926 of 6000
# 927 of 6000
# 928 of 6000
# 929 of 6000
# 930 of 6000
# 931 of 6000
# 932 of 6000
# 933 of 6000
# 934 of 6000
# 935 of 6000
# 936 of 6000
# 937 of 6000
# 938 of 6000
