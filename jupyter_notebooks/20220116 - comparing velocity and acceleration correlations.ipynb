# %%
import sys
sys.path.insert(0, '/home/users/brezovec/.local/lib/python3.6/site-packages/lib/python/')
import ants
import os
import bigbadbrain as bbb
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy
from scipy.ndimage.filters import gaussian_filter
from scipy.ndimage.filters import gaussian_filter1d
from scipy.signal import savgol_filter
from scipy.interpolate import interp1d

from skimage.filters import threshold_triangle
sys.path.insert(0, '/home/users/brezovec/.local/lib/python3.6/site-packages')
import os
import statsmodels.api as sm
import cv2
import matplotlib.patches as mpatches
import psutil
from mpl_toolkits.axes_grid1 import ImageGrid
from matplotlib.colors import Normalize
import matplotlib.colors as mcolors
from matplotlib import colors

# %matplotlib inline
plt.rcParams.update({'font.size': 20})

from sklearn.feature_extraction.image import grid_to_graph
from mpl_toolkits.axes_grid1 import ImageGrid
import json
from matplotlib.ticker import FuncFormatter

import nibabel as nib

from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import fcluster
from scipy.cluster import hierarchy
import itertools
import random
import matplotlib as mpl
from matplotlib.pyplot import cm

from scipy.interpolate import UnivariateSpline
from sklearn.linear_model import LinearRegression
import matplotlib.patches as patches

from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LassoCV

from scipy.fftpack import fft,fftshift,ifft
from scipy import signal
import pickle
from random import random

import colorsys
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.patches as mpatches
from matplotlib.collections import PatchCollection
import matplotlib
from numpy import inf
from scipy.ndimage.morphology import binary_erosion
from scipy.ndimage.morphology import binary_dilation

# %%
n_clusters = 2000
labels_file = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20201129_super_slices/final_9_cluster_labels_2000.npy'
cluster_model_labels = np.load(labels_file)

# %%
dataset_path = "/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20210101_correlation/"
behavior = 'Y_pos'
maps = {}

rvalues_to_load = [os.path.join(dataset_path, x) for x in os.listdir(dataset_path) if 'rvalues_{}'.format(behavior) in x]
bbb.sort_nicely(rvalues_to_load)

pvalues_to_load = [os.path.join(dataset_path, x) for x in os.listdir(dataset_path) if 'pvalues_{}'.format(behavior) in x]
bbb.sort_nicely(pvalues_to_load)

r_map = []
p_map = []
for z in range(9,40):#range(49):
    r_map.append(np.load(rvalues_to_load[z]))
    p_map.append(np.load(pvalues_to_load[z]))

# %%
os.listdir("/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20211209_red_correlation/")
# Out:
# ['rvalues_Ya_pos_z33.npy',
#  'rvalues_Y_pos_z20.npy',
#  'rvalues_Z_neg_z34.npy',
#  'pvalues_Ya_pos_z42.npy',
#  'rvalues_Ya_pos_z38.npy',
#  'pvalues_Ya_pos_z20.npy',
#  'pvalues_Z_pos_z4.npy',
#  'pvalues_Z_neg_z19.npy',
#  'pvalues_Y_pos_z17.npy',
#  'pvalues_Ya_pos_z9.npy',
#  'pvalues_Y_pos_z9.npy',
#  'pvalues_Z_pos_z25.npy',
#  'pvalues_Y_pos_z8.npy',
#  'pvalues_Y_pos_z39.npy',
#  'rvalues_Z_neg_z33.npy',
#  'rvalues_Y_pos_z37.npy',
#  'pvalues_Y_pos_z4.npy',
#  'rvalues_Z_neg_z28.npy',
#  'pvalues_Y_pos_z1.npy',
#  'pvalues_Y_pos_z11.npy',
#  'pvalues_Z_neg_z34.npy',
#  'pvalues_Z_neg_z17.npy',
#  'pvalues_Z_pos_z17.npy',
#  'rvalues_Y_pos_z17.npy',
#  'rvalues_Z_neg_z4.npy',
#  'rvalues_Y_pos_z26.npy',
#  'rvalues_Z_neg_z25.npy',
#  'pvalues_Y_pos_z15.npy',
#  'rvalues_Z_neg_z46.npy',
#  'pvalues_Z_neg_z20.npy',
#  'rvalues_Ya_pos_z11.npy',
#  'pvalues_Z_neg_z6.npy',
#  'pvalues_Ya_pos_z26.npy',
#  'rvalues_Ya_pos_z7.npy',
#  'pvalues_Z_neg_z2.npy',
#  'rvalues_Z_neg_z15.npy',
#  'rvalues_Z_neg_z48.npy',
#  'rvalues_Y_pos_z47.npy',
#  'pvalues_Z_pos_z27.npy',
#  'pvalues_Ya_pos_z28.npy',
#  'rvalues_Z_pos_z26.npy',
#  'rvalues_Y_pos_z34.npy',
#  'rvalues_Y_pos_z24.npy',
#  'rvalues_Z_neg_z2.npy',
#  'pvalues_Z_pos_z7.npy',
#  'rvalues_Y_pos_z35.npy',
#  'rvalues_Y_pos_z8.npy',
#  'pvalues_Y_pos_z25.npy',
#  'pvalues_Z_neg_z16.npy',
#  'rvalues_Y_pos_z1.npy',
#  'rvalues_Ya_pos_z26.npy',
#  'pvalues_Y_pos_z46.npy',
#  'pvalues_Z_neg_z36.npy',
#  'rvalues_Y_pos_z13.npy',
#  'pvalues_Y_pos_z5.npy',
#  'pvalues_Z_pos_z32.npy',
#  'pvalues_Y_pos_z44.npy',
#  'pvalues_Y_pos_z10.npy',
#  'rvalues_Ya_pos_z27.npy',
#  'pvalues_Z_pos_z10.npy',
#  'rvalues_Z_neg_z3.npy',
#  'rvalues_Z_neg_z16.npy',
#  'rvalues_Y_pos_z46.npy',
#  'rvalues_Z_pos_z30.npy',
#  'rvalues_Ya_pos_z18.npy',
#  'pvalues_Z_neg_z41.npy',
#  'rvalues_Ya_pos_z17.npy',
#  'pvalues_Z_pos_z39.npy',
#  'pvalues_Z_pos_z14.npy',
#  'rvalues_Y_pos_z22.npy',
#  'pvalues_Z_neg_z0.npy',
#  'rvalues_Z_neg_z21.npy',
#  'rvalues_Ya_pos_z25.npy',
#  'rvalues_Y_pos_z31.npy',
#  'rvalues_Z_neg_z13.npy',
#  'pvalues_Z_pos_z18.npy',
#  'rvalues_Z_neg_z22.npy',
#  'pvalues_Z_neg_z1.npy',
#  'pvalues_Ya_pos_z37.npy',
#  'rvalues_Y_pos_z12.npy',
#  'pvalues_Ya_pos_z6.npy',
#  'pvalues_Y_pos_z14.npy',
#  'rvalues_Z_pos_z24.npy',
#  'pvalues_Ya_pos_z31.npy',
#  'rvalues_Y_pos_z5.npy',
#  'rvalues_Z_pos_z5.npy',
#  'pvalues_Y_pos_z22.npy',
#  'pvalues_Y_pos_z18.npy',
#  'pvalues_Y_pos_z21.npy',
#  'rvalues_Z_pos_z10.npy',
#  'pvalues_Z_neg_z33.npy',
#  'pvalues_Z_neg_z28.npy',
#  'pvalues_Z_pos_z24.npy',
#  'rvalues_Z_pos_z22.npy',
#  'pvalues_Y_pos_z27.npy',
#  'rvalues_Z_neg_z9.npy',
#  'pvalues_Ya_pos_z47.npy',
#  'rvalues_Y_pos_z10.npy',
#  'rvalues_Y_pos_z27.npy',
#  'pvalues_Y_pos_z43.npy',
#  'pvalues_Ya_pos_z36.npy',
#  'rvalues_Ya_pos_z30.npy',
#  'rvalues_Z_pos_z25.npy',
#  'pvalues_Z_neg_z48.npy',
#  'pvalues_Z_pos_z20.npy',
#  'rvalues_Y_pos_z11.npy',
#  'pvalues_Z_pos_z2.npy',
#  'pvalues_Z_pos_z26.npy',
#  'rvalues_Z_neg_z11.npy',
#  'pvalues_Ya_pos_z34.npy',
#  'rvalues_Ya_pos_z10.npy',
#  'rvalues_Y_pos_z25.npy',
#  'rvalues_Z_neg_z35.npy',
#  'rvalues_Z_pos_z16.npy',
#  'rvalues_Y_pos_z0.npy',
#  'rvalues_Z_neg_z26.npy',
#  'pvalues_Ya_pos_z44.npy',
#  'pvalues_Z_neg_z4.npy',
#  'pvalues_Z_neg_z32.npy',
#  'rvalues_Z_pos_z37.npy',
#  'pvalues_Z_pos_z28.npy',
#  'pvalues_Z_neg_z46.npy',
#  'rvalues_Ya_pos_z4.npy',
#  'pvalues_Ya_pos_z5.npy',
#  'rvalues_Z_pos_z31.npy',
#  'rvalues_Ya_pos_z28.npy',
#  'pvalues_Z_neg_z21.npy',
#  'rvalues_Z_neg_z23.npy',
#  'pvalues_Y_pos_z13.npy',
#  'pvalues_Z_neg_z35.npy',
#  'rvalues_Z_pos_z42.npy',
#  'rvalues_Y_pos_z43.npy',
#  'rvalues_Y_pos_z36.npy',
#  'rvalues_Ya_pos_z36.npy',
#  'rvalues_Y_pos_z38.npy',
#  'rvalues_Z_pos_z48.npy',
#  'rvalues_Z_neg_z17.npy',
#  'rvalues_Y_pos_z21.npy',
#  'pvalues_Z_neg_z27.npy',
#  'pvalues_Z_pos_z37.npy',
#  'rvalues_Z_neg_z37.npy',
#  'pvalues_Z_neg_z14.npy',
#  'rvalues_Ya_pos_z12.npy',
#  'rvalues_Y_pos_z9.npy',
#  'rvalues_Ya_pos_z39.npy',
#  'pvalues_Ya_pos_z19.npy',
#  'rvalues_Z_pos_z21.npy',
#  'rvalues_Z_neg_z41.npy',
#  'pvalues_Ya_pos_z4.npy',
#  'rvalues_Y_pos_z32.npy',
#  'rvalues_Z_neg_z36.npy',
#  'pvalues_Z_neg_z11.npy',
#  'pvalues_Z_neg_z40.npy',
#  'rvalues_Z_pos_z47.npy',
#  'pvalues_Y_pos_z33.npy',
#  'rvalues_Z_pos_z34.npy',
#  'pvalues_Ya_pos_z41.npy',
#  'pvalues_Z_neg_z38.npy',
#  'pvalues_Z_pos_z47.npy',
#  'rvalues_Ya_pos_z9.npy',
#  'rvalues_Z_pos_z29.npy',
#  'pvalues_Ya_pos_z24.npy',
#  'rvalues_Ya_pos_z14.npy',
#  'pvalues_Y_pos_z19.npy',
#  'pvalues_Z_neg_z9.npy',
#  'pvalues_Y_pos_z24.npy',
#  'rvalues_Ya_pos_z21.npy',
#  'pvalues_Ya_pos_z33.npy',
#  'rvalues_Z_neg_z39.npy',
#  'pvalues_Ya_pos_z17.npy',
#  'pvalues_Z_pos_z16.npy',
#  'pvalues_Ya_pos_z32.npy',
#  'pvalues_Ya_pos_z7.npy',
#  'rvalues_Z_neg_z29.npy',
#  'rvalues_Y_pos_z4.npy',
#  'pvalues_Z_pos_z1.npy',
#  'rvalues_Ya_pos_z29.npy',
#  'pvalues_Y_pos_z29.npy',
#  'pvalues_Ya_pos_z13.npy',
#  'rvalues_Z_neg_z43.npy',
#  'pvalues_Ya_pos_z30.npy',
#  'rvalues_Z_neg_z5.npy',
#  'rvalues_Ya_pos_z42.npy',
#  'pvalues_Z_pos_z29.npy',
#  'rvalues_Y_pos_z28.npy',
#  'rvalues_Z_pos_z36.npy',
#  'pvalues_Y_pos_z16.npy',
#  'rvalues_Y_pos_z39.npy',
#  'rvalues_Z_pos_z14.npy',
#  'pvalues_Ya_pos_z39.npy',
#  'pvalues_Z_pos_z12.npy',
#  'rvalues_Z_pos_z43.npy',
#  'rvalues_Y_pos_z48.npy',
#  'rvalues_Y_pos_z42.npy',
#  'pvalues_Ya_pos_z25.npy',
#  'pvalues_Z_pos_z0.npy',
#  'pvalues_Ya_pos_z46.npy',
#  'pvalues_Y_pos_z35.npy',
#  'rvalues_Y_pos_z15.npy',
#  'pvalues_Z_neg_z15.npy',
#  'pvalues_Y_pos_z20.npy',
#  'rvalues_Ya_pos_z31.npy',
#  'rvalues_Z_pos_z8.npy',
#  'rvalues_Y_pos_z45.npy',
#  'rvalues_Ya_pos_z41.npy',
#  'rvalues_Z_neg_z20.npy',
#  'pvalues_Z_neg_z5.npy',
#  'rvalues_Y_pos_z14.npy',
#  'rvalues_Z_neg_z18.npy',
#  'pvalues_Z_pos_z15.npy',
#  'pvalues_Z_neg_z26.npy',
#  'rvalues_Ya_pos_z13.npy',
#  'pvalues_Ya_pos_z23.npy',
#  'pvalues_Y_pos_z47.npy',
#  'pvalues_Y_pos_z23.npy',
#  'pvalues_Z_neg_z25.npy',
#  'pvalues_Z_pos_z44.npy',
#  'pvalues_Z_pos_z21.npy',
#  'pvalues_Z_pos_z3.npy',
#  'rvalues_Z_pos_z6.npy',
#  'pvalues_Ya_pos_z38.npy',
#  'pvalues_Z_pos_z43.npy',
#  'rvalues_Ya_pos_z45.npy',
#  'pvalues_Z_pos_z42.npy',
#  'pvalues_Ya_pos_z45.npy',
#  'rvalues_Z_pos_z23.npy',
#  'rvalues_Z_pos_z38.npy',
#  'rvalues_Z_neg_z1.npy',
#  'pvalues_Y_pos_z28.npy',
#  'rvalues_Z_pos_z44.npy',
#  'rvalues_Ya_pos_z23.npy',
#  'rvalues_Y_pos_z44.npy',
#  'rvalues_Y_pos_z33.npy',
#  'pvalues_Z_neg_z24.npy',
#  'pvalues_Z_pos_z9.npy',
#  'rvalues_Y_pos_z23.npy',
#  'pvalues_Z_pos_z22.npy',
#  'rvalues_Y_pos_z29.npy',
#  'rvalues_Z_pos_z12.npy',
#  'pvalues_Ya_pos_z35.npy',
#  'pvalues_Z_neg_z39.npy',
#  'rvalues_Ya_pos_z40.npy',
#  'rvalues_Z_pos_z3.npy',
#  'pvalues_Y_pos_z6.npy',
#  'pvalues_Z_pos_z36.npy',
#  'rvalues_Z_pos_z35.npy',
#  'rvalues_Ya_pos_z35.npy',
#  'rvalues_Z_neg_z40.npy',
#  'rvalues_Ya_pos_z5.npy',
#  'pvalues_Y_pos_z34.npy',
#  'pvalues_Z_pos_z13.npy',
#  'pvalues_Y_pos_z48.npy',
#  'pvalues_Ya_pos_z40.npy',
#  'pvalues_Ya_pos_z0.npy',
#  'pvalues_Ya_pos_z29.npy',
#  'pvalues_Ya_pos_z27.npy',
#  'pvalues_Z_neg_z3.npy',
#  'pvalues_Y_pos_z36.npy',
#  'rvalues_Z_pos_z0.npy',
#  'pvalues_Z_pos_z33.npy',
#  'rvalues_Z_neg_z7.npy',
#  'rvalues_Z_pos_z11.npy',
#  'rvalues_Ya_pos_z3.npy',
#  'rvalues_Z_neg_z19.npy',
#  'rvalues_Z_neg_z24.npy',
#  'pvalues_Ya_pos_z8.npy',
#  'rvalues_Z_pos_z27.npy',
#  'rvalues_Ya_pos_z37.npy',
#  'pvalues_Z_pos_z38.npy',
#  'rvalues_Ya_pos_z20.npy',
#  'rvalues_Z_neg_z6.npy',
#  'pvalues_Y_pos_z26.npy',
#  'rvalues_Ya_pos_z44.npy',
#  'pvalues_Z_pos_z35.npy',
#  'rvalues_Z_pos_z33.npy',
#  'rvalues_Ya_pos_z8.npy',
#  'rvalues_Y_pos_z16.npy',
#  'pvalues_Y_pos_z37.npy',
#  'rvalues_Ya_pos_z34.npy',
#  'pvalues_Z_pos_z34.npy',
#  'rvalues_Y_pos_z18.npy',
#  'pvalues_Ya_pos_z2.npy',
#  'rvalues_Z_pos_z40.npy',
#  'pvalues_Z_neg_z23.npy',
#  'rvalues_Ya_pos_z24.npy',
#  'rvalues_Z_pos_z20.npy',
#  'rvalues_Z_pos_z13.npy',
#  'rvalues_Z_pos_z18.npy',
#  'rvalues_Y_pos_z6.npy',
#  'rvalues_Y_pos_z2.npy',
#  'rvalues_Z_pos_z19.npy',
#  'pvalues_Ya_pos_z48.npy',
#  'rvalues_Z_neg_z10.npy',
#  'rvalues_Y_pos_z41.npy',
#  'rvalues_Ya_pos_z43.npy',
#  'pvalues_Ya_pos_z10.npy',
#  'pvalues_Z_neg_z30.npy',
#  'rvalues_Y_pos_z30.npy',
#  'pvalues_Z_neg_z10.npy',
#  'pvalues_Ya_pos_z3.npy',
#  'pvalues_Z_neg_z18.npy',
#  'pvalues_Z_neg_z22.npy',
#  'pvalues_Ya_pos_z15.npy',
#  'rvalues_Z_neg_z47.npy',
#  'rvalues_Ya_pos_z0.npy',
#  'rvalues_Z_pos_z4.npy',
#  'rvalues_Z_pos_z9.npy',
#  'pvalues_Ya_pos_z14.npy',
#  'pvalues_Y_pos_z38.npy',
#  'pvalues_Z_neg_z42.npy',
#  'pvalues_Ya_pos_z12.npy',
#  'pvalues_Z_pos_z48.npy',
#  'rvalues_Z_pos_z1.npy',
#  'pvalues_Z_neg_z29.npy',
#  'rvalues_Ya_pos_z2.npy',
#  'rvalues_Z_pos_z2.npy',
#  'rvalues_Ya_pos_z47.npy',
#  'rvalues_Z_pos_z28.npy',
#  'pvalues_Z_neg_z7.npy',
#  'pvalues_Z_pos_z46.npy',
#  'pvalues_Y_pos_z40.npy',
#  'rvalues_Z_neg_z31.npy',
#  'rvalues_Ya_pos_z48.npy',
#  'rvalues_Z_pos_z32.npy',
#  'pvalues_Z_neg_z12.npy',
#  'rvalues_Z_pos_z39.npy',
#  'pvalues_Ya_pos_z11.npy',
#  'pvalues_Z_neg_z43.npy',
#  'pvalues_Z_pos_z11.npy',
#  'rvalues_Ya_pos_z22.npy',
#  'rvalues_Z_pos_z15.npy',
#  'pvalues_Ya_pos_z1.npy',
#  'pvalues_Z_neg_z45.npy',
#  'rvalues_Z_neg_z27.npy',
#  'pvalues_Z_pos_z6.npy',
#  'rvalues_Z_pos_z7.npy',
#  'pvalues_Z_pos_z19.npy',
#  'pvalues_Y_pos_z7.npy',
#  'rvalues_Z_pos_z17.npy',
#  'pvalues_Ya_pos_z18.npy',
#  'rvalues_Y_pos_z40.npy',
#  'pvalues_Y_pos_z12.npy',
#  'rvalues_Y_pos_z7.npy',
#  'pvalues_Y_pos_z41.npy',
#  'pvalues_Y_pos_z2.npy',
#  'pvalues_Z_neg_z44.npy',
#  'pvalues_Y_pos_z32.npy',
#  'rvalues_Ya_pos_z16.npy',
#  'rvalues_Ya_pos_z15.npy',
#  'pvalues_Y_pos_z45.npy',
#  'rvalues_Y_pos_z3.npy',
#  'pvalues_Ya_pos_z21.npy',
#  'pvalues_Z_neg_z8.npy',
#  'pvalues_Z_neg_z13.npy',
#  'pvalues_Ya_pos_z43.npy',
#  'rvalues_Z_neg_z32.npy',
#  'rvalues_Z_neg_z12.npy',
#  'pvalues_Z_neg_z47.npy',
#  'pvalues_Z_pos_z31.npy',
#  'rvalues_Z_neg_z14.npy',
#  'rvalues_Y_pos_z19.npy',
#  'pvalues_Y_pos_z31.npy',
#  'pvalues_Z_neg_z31.npy',
#  'pvalues_Y_pos_z30.npy',
#  'pvalues_Z_pos_z5.npy',
#  'pvalues_Z_pos_z40.npy',
#  'pvalues_Z_pos_z30.npy',
#  'rvalues_Z_pos_z46.npy',
#  'rvalues_Z_neg_z30.npy',
#  'pvalues_Ya_pos_z22.npy',
#  'pvalues_Z_pos_z41.npy',
#  'rvalues_Ya_pos_z46.npy',
#  'rvalues_Ya_pos_z32.npy',
#  'rvalues_Z_neg_z8.npy',
#  'rvalues_Z_neg_z45.npy',
#  'rvalues_Z_neg_z38.npy',
#  'rvalues_Ya_pos_z19.npy',
#  'rvalues_Z_neg_z0.npy',
#  'pvalues_Z_pos_z45.npy',
#  'rvalues_Z_neg_z44.npy',
#  'rvalues_Ya_pos_z1.npy',
#  'rvalues_Z_pos_z41.npy',
#  'pvalues_Y_pos_z42.npy',
#  'rvalues_Ya_pos_z6.npy',
#  'pvalues_Z_pos_z23.npy',
#  'pvalues_Ya_pos_z16.npy',
#  'pvalues_Y_pos_z3.npy',
#  'rvalues_Z_neg_z42.npy',
#  'pvalues_Z_neg_z37.npy',
#  'pvalues_Y_pos_z0.npy',
#  'pvalues_Z_pos_z8.npy',
#  'rvalues_Z_pos_z45.npy']

# %%
# accidentely saved in red folder, but thats fine
dataset_path = "/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20211209_red_correlation/"
behavior = 'Ya_pos'
maps = {}

rvalues_to_load = [os.path.join(dataset_path, x) for x in os.listdir(dataset_path) if 'rvalues_{}'.format(behavior) in x]
bbb.sort_nicely(rvalues_to_load)

pvalues_to_load = [os.path.join(dataset_path, x) for x in os.listdir(dataset_path) if 'pvalues_{}'.format(behavior) in x]
bbb.sort_nicely(pvalues_to_load)

r_map = []
p_map = []
for z in range(9,40):
    r_map.append(np.load(rvalues_to_load[z]))
    p_map.append(np.load(pvalues_to_load[z]))

# %%
plt.hist(np.asarray(r_map).flatten(),bins=100);
plt.xlim(-.05,.1)
# Out:
# (-0.05, 0.1)

# %%
np.mean(np.nan_to_num(r_map))
# Out:
# 0.014978807433697516

# %%
plt.hist(np.asarray(r_map).flatten(),bins=100);
plt.xlim(-.01,.21)
# Out:
# (-0.01, 0.21)
