# %%
from neuprint import Client
from neuprint import NeuronCriteria as NC
from neuprint import fetch_neurons
from neuprint import fetch_adjacencies
from neuprint.utils import connection_table_to_matrix
import bokeh.palettes
from bokeh.plotting import figure, show, output_notebook
output_notebook()
import hvplot.pandas
import holoviews as hv
import numpy as np
import pandas as pd
import ants
import nibabel as nib
import os
import pickle
import scipy
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import networkx as nx
from fa2 import ForceAtlas2
from nxviz import CircosPlot
import nxviz as nv
import tqdm
import time
from scipy.ndimage.morphology import binary_erosion
from scipy.ndimage.morphology import binary_dilation
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import fcluster
from scipy.cluster import hierarchy
from scipy.fftpack import fft,fftshift,ifft
from scipy import signal
import bigbadbrain as bbb
from scipy.ndimage.filters import gaussian_filter1d
import matplotlib.colors as mcolors
import brainsss
import cv2
from sklearn.linear_model import RidgeCV
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# /home/users/brezovec/.local/lib/python3.6/site-packages/ants/viz/render_surface_function.py:16: UserWarning: Cant import Plotly. Install it `pip install chart_studio` if you want to use ants.render_surface_function
#   "Cant import Plotly. Install it `pip install chart_studio` if you want to use ants.render_surface_function"

# %%
cluster_dir = "/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20221109_cluster_pca/"

# %%
file = os.path.join(cluster_dir, 'superclusters_more.npy')
superclusters = np.load(file)
#with 249 there will be clusters 1-250 inclusive (len=250). cluster 140 is background
superclusters_250 = superclusters[:,:,:,249]
# right brain gets +250 to cluster ID so now 500 clusters
superclusters_250[157:,:,:] += 250

# %%
file = os.path.join(cluster_dir,"20221128_sv_to_sc.npy")
sv_to_sc = np.load(file)

# %%
sv_to_sc.shape
# Out:
# (49, 2000)

# %%
cluster=77
ind = np.where(sv_to_sc==cluster)

# %%
### Load GLM output
main_dir = f'/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20210208_inst_uniq_glm'

### this is what I initially warped into FDA but probably want the other one
#main_dir = f'/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20210309_inst_uniq_glm_state_sub'

all_scores = []
for z in range(49):
    file = [os.path.join(main_dir, i) for i in os.listdir(main_dir) if f'Z{z}.' in i][0]
    with open(file, 'rb') as handle:
        scores = pickle.load(handle)
    all_scores.append(scores)

# %%
zpos_means = []
zneg_means = []

for cluster in range(501):
    ind = np.where(sv_to_sc==cluster)

    sv_score_zpos = []
    sv_score_zneg = []

    for i in range(len(ind[0])):
        sv_score_zpos.append(all_scores[ind[0][i]]['scores_all'][ind[1][i]] -
                        all_scores[ind[0][i]]['scores_zpos_unique'][ind[1][i]])
        sv_score_zneg.append(all_scores[ind[0][i]]['scores_all'][ind[1][i]] -
                        all_scores[ind[0][i]]['scores_zneg_unique'][ind[1][i]])

    zpos_means.append(np.mean(sv_score_zpos))
    zneg_means.append(np.mean(sv_score_zneg))
        
#     plt.plot(sv_score_zpos,label='L')
#     plt.plot(sv_score_zneg,label='R')
#     plt.legend()

# %%
plt.plot(zpos_means,label='L')
plt.plot(zneg_means,label='R')
plt.legend()

# %%
plt.plot(sv_score_zpos,label='L')
plt.plot(sv_score_zneg,label='R')
plt.legend()

# %% [markdown]
# # Most trustworthy version argues for Left turning

# %%
# ok what am i trying to do...
# 1) according to 20221127_unique_glm_indiv_FDA, cluster 77 is left turning
# and according to 20221122_unique_glm (20210208_inst_uniq_glm warped to FDA) it is left turning
# 2) according to 20210208_inst_uniq_glm and sv_to_sc it is right turning

#...

# so probably 20221122 - PCA clusters, get full neural recordings is WRONG
# Actually I think I don't even need to figure out what exactly is wrong; I can just not do it.
# So instead I will always just average over signals in the supercluster
# How exactly do I implement this for 1d and 2d behavior?
# Warping GLM and temporal maps into FDA worked great (this giant 314,146,91,2000 was OK)
# So I COULD warp through the 2d hists as (314,146,91,25,25)

# I would love to warp the 500 clusters into OG luke space.
# Then

# %%
file = os.path.join(cluster_dir,"20221122_unique_glm.npy")
unique_glm = np.load(file)
unique_glm.shape
# Out:
# (314, 146, 91, 3)

# %%
def plot_crosshairs():
    plt.axhline(95,color='w',linestyle='--')
    plt.axvline(120,color='w',linestyle='--')

plt.figure(figsize=(10,6))
plt.subplot(2,2,1)
plt.imshow(unique_glm[:,:,57,1].T)
plot_crosshairs()
plt.subplot(2,2,2)
plt.imshow(superclusters_250[:,:,57].T==77)
plot_crosshairs()
plt.subplot(2,2,3)
plt.imshow(np.max(unique_glm,axis=2)[:,:,1].T)
plot_crosshairs()
plt.subplot(2,2,4)
plt.imshow(np.max(superclusters_250==77,axis=-1).T)
plot_crosshairs()

# %%
#zneg is red

# %% [markdown]
# # Scrutinize the sv to sc map

# %%
sv_to_sc.shape
# Out:
# (49, 2000)

# %%
n_clusters = 2000
labels_file = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20201129_super_slices/cluster_labels.npy'
cluster_model_labels_2000 = np.load(labels_file)
cluster_model_labels_2000.shape
cluster_model_labels_2000_3d = np.reshape(cluster_model_labels_2000,(49,256,128))

# %%
len(np.unique(cluster_model_labels_2000[0,:]))
# Out:
# 2000

# %%
plt.imshow(cluster_model_labels_2000_3d[10,:,:].T)

# %%
sv_to_sc_map = np.zeros((256,128,49))
for z in range(49):
    for cluster in range(2000):
        sc = sv_to_sc[z,cluster]
        inds = np.where(cluster_model_labels_2000_3d[z,:,:]==cluster)
        sv_to_sc_map[inds[0],inds[1],z] = sc

# %%
plt.imshow(sv_to_sc_map[:,:,10].T)

# %%
cluster_model_labels_2000_3d.shape
# Out:
# (49, 256, 128)

# %%
sv_to_sc_map.shape
# Out:
# (256, 128, 49)

# %%
ind = np.where(sv_to_sc_map==77)
scs = cluster_model_labels_2000_3d[ind[2],ind[0],ind[1]]
zs = ind[2]
full_scs = [(zs[i],scs[i]) for i in range(len(zs))]

# %%
empty = np.zeros((256,128,49))
for sc in full_scs:

# %%
full_scs
# Out:
# [(31, 589),
#  (31, 589),
#  (31, 589),
#  (31, 589),
#  (31, 589),
#  (31, 589),
#  (31, 589),
#  (31, 589),
#  (29, 391),
#  (29, 391),
#  (29, 391),
#  (29, 391),
#  (29, 391),
#  (29, 391),
#  (29, 391),
#  (29, 391),
#  (22, 457),
#  (22, 457),
#  (20, 43),
#  (20, 1972),
#  (21, 477),
#  (20, 1972),
#  (21, 477),
#  (22, 1896),
#  (20, 1972),
#  (21, 1087),
#  (22, 457),
#  (20, 1972),
#  (21, 1087),
#  (22, 457),
#  (20, 43),
#  (22, 457),
#  (20, 43),
#  (22, 1701),
#  (22, 1701),
#  (22, 417),
#  (22, 417),
#  (21, 477),
#  (20, 1972),
#  (21, 477),
#  (20, 1972),
#  (21, 477),
#  (22, 1896),
#  (20, 1972),
#  (21, 1087),
#  (22, 1896),
#  (20, 1972),
#  (21, 1087),
#  (22, 457),
#  (20, 43),
#  (21, 1087),
#  (22, 457),
#  (20, 43),
#  (22, 1701),
#  (22, 1701),
#  (21, 256),
#  (21, 256),
#  (22, 417),
#  (22, 417),
#  (20, 1391),
#  (22, 417),
#  (20, 1391),
#  (21, 477),
#  (22, 1896),
#  (20, 1972),
#  (21, 477),
#  (22, 1896),
#  (20, 1972),
#  (21, 477),
# ...

# %%
plt.imshow(sv_to_sc_map[:,:,20].T)

# %%
plt.imshow(np.max(sv_to_sc_map==77,axis=2).T)

# %%
temp = np.zeros((256,128))
np.where(empty==77)

# %%
cluster = 77
ind = np.where(sv_to_sc==cluster)
ind_pairs = [(ind[0][i],ind[1][i]) for i in range(len(ind[0]))]
ind_pairs
#
# Out:
# [(14, 211),
#  (14, 903),
#  (15, 154),
#  (18, 1674),
#  (19, 111),
#  (19, 264),
#  (19, 645),
#  (19, 1336),
#  (19, 1502),
#  (19, 1592),
#  (19, 1818),
#  (19, 1900),
#  (20, 43),
#  (20, 569),
#  (20, 847),
#  (20, 1033),
#  (20, 1391),
#  (20, 1598),
#  (20, 1753),
#  (20, 1972),
#  (21, 184),
#  (21, 256),
#  (21, 477),
#  (21, 1050),
#  (21, 1087),
#  (21, 1379),
#  (21, 1672),
#  (21, 1688),
#  (21, 1699),
#  (22, 417),
#  (22, 457),
#  (22, 1546),
#  (22, 1701),
#  (22, 1896),
#  (29, 391),
#  (31, 589),
#  (37, 1884),
#  (38, 54),
#  (39, 1438)]

# %%
cluster_model_labels_2000_3d.shape
# Out:
# (49, 256, 128)

# %%
cluster_model_labels_2000.shape
# Out:
# (49, 32768)

# %%
empty = np.zeros((32768,49))
for i in range(len(ind_pairs)):
    inds = np.where(cluster_model_labels_2000[ind_pairs[i][0],:]==ind_pairs[i][1])
    empty[inds,[i][0]] = 1
empty = np.reshape(empty,(256,128,49))

# %%
plt.imshow(np.max(empty,axis=2).T)

# %%
plt.imshow(np.max(empty,axis=0).T)

# %% [markdown]
# # fresh

# %%
file = os.path.join(cluster_dir,'20221130_pca_clsuters_in_luke_OG.npy')
sc_map = np.load(file)
sc_map.shape
# Out:
# (256, 128, 49)

# %%
plt.imshow(sc_map[:,:,20].T)

# %%
plt.imshow(sv_to_sc_map[:,:,29].T)

# %%
plt.imshow(np.max(sv_to_sc_map==77,axis=2).T)

# %%
file = os.path.join(cluster_dir, 'superclusters_more.npy')
superclusters = np.load(file)
#with 249 there will be clusters 1-250 inclusive (len=250). cluster 140 is background
superclusters_250 = superclusters[:,:,:,249]
# right brain gets +250 to cluster ID so now 500 clusters
superclusters_250[157:,:,:] += 250

# %%
plt.imshow(np.max(superclusters_250==77,axis=2).T)

# %%
### Load GLM output
main_dir = f'/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20210208_inst_uniq_glm'

### this is what I initially warped into FDA but probably want the other one
#main_dir = f'/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20210309_inst_uniq_glm_state_sub'

all_scores = []
for z in range(49):
    file = [os.path.join(main_dir, i) for i in os.listdir(main_dir) if f'Z{z}.' in i][0]
    with open(file, 'rb') as handle:
        scores = pickle.load(handle)
    all_scores.append(scores)

# %%
scores1='scores_all'
uniques = ['scores_ypos_unique', 'scores_zpos_unique', 'scores_zneg_unique']
maps = {}

for unique in uniques:
    all_colored_by_betas = []
    for z in range(49):
        colored_by_betas = np.zeros(256*128)
        for cluster_num in range(len(np.unique(cluster_model_labels_2000[z]))):
            cluster_indicies = np.where(cluster_model_labels_2000[z]==cluster_num)[0]
            value = all_scores[z][scores1][cluster_num] - all_scores[z][unique][cluster_num]
            colored_by_betas[cluster_indicies] = value

            if len(cluster_indicies) > 100:
                colored_by_betas[cluster_indicies] = 0
            if colored_by_betas[cluster_indicies][0] == 1:
                colored_by_betas[cluster_indicies] = 0
        colored_by_betas = colored_by_betas.reshape(256,128)
        all_colored_by_betas.append(colored_by_betas)
    all_colored_by_betas = np.asarray(all_colored_by_betas)
    maps[unique] = all_colored_by_betas

# %%
z=30
values = np.asarray(all_scores[z][scores1]) - np.asarray(all_scores[z]['scores_zpos_unique'])
np.argsort(values)
# Out:
# array([ 263,  307, 1083, ..., 1608, 1505, 1415])

# %%
1674
np.searchsorted(np.argsort(values),1674)
# Out:
# 1485

# %%
maps['scores_zpos_unique'].shape
# Out:
# (49, 256, 128)

# %%
sv_to_sc_map.shape
# Out:
# (256, 128, 49)

# %%
z=30
plt.imshow(maps['scores_zpos_unique'][z,:,:].T)

# %%
z=19
plt.imshow((sv_to_sc_map==77)[:,:,z].T)

# %%
def plot_crosshairs():
    plt.axhline(90,color='w',linestyle='--')
    plt.axvline(95,color='w',linestyle='--')

z=19
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.imshow(maps['scores_zpos_unique'][::-1,:,:][z,:,:].T)
plot_crosshairs()
plt.subplot(2,2,2)
plt.imshow((sv_to_sc_map==77)[:,:,z].T)
plot_crosshairs()
plt.subplot(2,2,3)
plt.imshow(np.max(maps['scores_zpos_unique'],axis=0).T)
plot_crosshairs()
plt.subplot(2,2,4)
plt.imshow(np.max(sv_to_sc_map==77,axis=2).T)
plot_crosshairs()

# %%
plt.imshow(maps['scores_zpos_unique'][10,:,:].T)

# %%
plt.imshow(sc_map[:,:,10].T)

# %%
# ok could be a z-flip issue 
# lets try to fix the 2d hist
