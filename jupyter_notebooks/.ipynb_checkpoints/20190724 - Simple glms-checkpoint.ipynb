# %%
import numpy as np
from time import time
import os
import sys
import scipy
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
import pandas as pd
import psutil
from tqdm import tqdm
sys.path.insert(0, '/home/users/brezovec/.local/lib/python3.6/site-packages/lib/python/')
import ants
import bigbadbrain as bbb
from scipy.linalg import toeplitz
import scipy.linalg as sl
from scipy.signal import convolve2d
from scipy.signal import convolve
from sklearn.linear_model import LassoLarsIC
from sklearn.linear_model import LinearRegression
from sklearn.decomposition import PCA
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LassoCV

# %%
directory = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20190101_walking_dataset/fly_25/func_0'
brain_path = os.path.join(directory, 'brain_zscored_green.nii')
brain = bbb.load_numpy_brain(brain_path)
timestamps = bbb.load_timestamps(os.path.join(directory, 'imaging'))
fictrac = bbb.load_fictrac(os.path.join(directory, 'fictrac'))
# Out:
# ~~ load_numpy_brain ~~
# load_numpy_brain done. Duration: 23.30 sec
#
# ~~ load_timestamps ~~
# Trying to load timestamp data from hdf5 file.
# Success.
# load_timestamps done. Duration: 108.04 ms
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.63 sec

# %%
dims = bbb.get_dims(brain)

# %%
resolution = 100 #desired resolution in ms
expt_len = 1000*30*60
fps = 50 #of fictrac camera
beta_len = 11

# %%
def interp_brain(brain, resolution, z, expt_len):
    #resolution is in ms
    interp = interp1d(timestamps[:,z], brain[:,:,z,:], fill_value='extrapolate')
    xnew = np.arange(0,expt_len,resolution) #0 to last time at subsample res
    y = interp(xnew)
    return y

# %%
def interp_fictrac(fictrac, fps, resolution, expt_len):
    behavior = 'dRotLabY'
    sigma = 3
    camera_rate = 1/fps * 1000 # camera frame rate in ms
    
    x_original = np.arange(0,expt_len,camera_rate)
    fictrac_smoothed = scipy.ndimage.filters.gaussian_filter(np.asarray(fictrac[behavior]),sigma=sigma)
    #fictrac_smoothed = np.abs(fictrac_smoothed)
    fictrac_smoothed = np.clip(fictrac_smoothed, a_min=0, a_max=None)
    fictrac_interp_temp = interp1d(x_original, fictrac_smoothed, bounds_error = False)
    xnew = np.arange(0,expt_len,resolution) #0 to last time at subsample res
    fictrac_interp = fictrac_interp_temp(xnew)

    # Replace Nans with zeros (for later code)
    np.nan_to_num(fictrac_interp, copy=False);
    
    return fictrac_interp

# %%
fictrac_interp = interp_fictrac(fictrac, fps, resolution, expt_len)

# %%
z=25
fictrac_interp = interp_fictrac(fictrac, fps, resolution, expt_len)
brain_interp = interp_brain(brain,resolution,z,expt_len)

# %%
np.shape(brain_interp)
# Out:
# (129, 80, 18000)

# %%
np.log(brain_interp[0,0,:])
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])

# %%
brain_interp[0,0,:]
# Out:
# array([-0.52333138, -0.54288048, -0.56242958, ..., -0.13193935,
#        -0.31843414, -0.50492894])

# %%
plt.figure(figsize=(10,10))
plt.plot(brain_interp[80,40,:])
plt.xlim(0,5000)
plt.show()

# %%
plt.hist(brain_interp[80,40,:],bins=100)
plt.show()

# %%
plt.hist(brain_interp[0,0,:],bins=100)
plt.show()

# %%
plt.hist(fictrac_interp,bins=100)
plt.show()

# %%
X = X.reshape(-1,1)

# %%
fictrac_interp.shape
# Out:
# (18000,)

# %%
fic_square = np.e**fictrac_interp

# %%
X = np.vstack((abs(fic_Y[:,25]), abs(fic_Z[:,25])))
X = X.T

# %%
X.shape
# Out:
# (4128, 2)

# %%
.shape
# Out:
# (4128, 51)

# %%
z=25

betas = []
scores = []
#X = np.abs(fic_to_brain[:,z])
#X = X.reshape(-1,1)

for x in tqdm(range(dims['x'])):
    for y in range(dims['y']):
        Y = brain[y,x,z,:]
        model = LinearRegression().fit(X, Y)
        #model = LassoLarsIC(criterion='bic').fit(X, Y)
        #model = RidgeCV().fit(X, Y)
        
        #model.coef_
        #model.intercept_ 
        
        betas.append(model.coef_)
        scores.append(model.score(X, Y))
        
scores = np.reshape(scores, (dims['x'],dims['y']))

plt.imshow(scores)
plt.show()
# Out:
# 100%|██████████| 92/92 [00:12<00:00,  7.38it/s]

# %%
betas2 = np.reshape(betas, (dims['x'],dims['y'],-1))

# %%
plt.figure(figsize=(30,20))

plt.subplot(1,3,1)
plt.axis('off')
plt.title('Forward Velocity')
plt.imshow(betas2[:,:,0])

plt.subplot(1,3,2)
plt.axis('off')
plt.title('Rotational Velocity')
plt.imshow(betas2[:,:,1])

plt.subplot(1,3,3)
plt.axis('off')
plt.title('Difference')
plt.imshow(betas2[:,:,0]-betas2[:,:,1])

plt.subplots_adjust(wspace=0, hspace=0)
plt.show()

# %%
X = np.reshape(brain[:,:,25,:],(-1,brain.shape[-1])).T

# %%
Y = np.abs(fic_to_brain[:,25])
Y = Y.reshape(-1,1)

# %%
X.shape
# Out:
# (4128, 11776)

# %%
plt.plot(Y)
plt.show()

# %%
#model = LinearRegression().fit(X, Y)
model = LassoCV().fit(X, Y)
#model = RidgeCV().fit(X, Y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-343-ce9970347db5> in <module>()
#       1 #model = LinearRegression().fit(X, Y)
# ----> 2 model = LassoCV().fit(X, Y)
#       3 #model = RidgeCV().fit(X, Y)
#
# /share/software/user/open/py-scikit-learn/0.19.1_py36/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py in fit(self, X, y)
#    1190                 for train, test in folds)
#    1191         mse_paths = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
# -> 1192                              backend="threading")(jobs)
#    1193         mse_paths = np.reshape(mse_paths, (n_l1_ratio, len(folds), -1))
#    1194         mean_mse = np.mean(mse_paths, axis=1)
#
# /share/software/user/open/py-scikit-learn/0.19.1_py36/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
# ...

# %%
out = np.reshape(model.coef_, (128,92))

# %%
plt.imshow(out.T)
plt.show()

# %%
model.score(X, Y)

# %%
3

# %%
betas = []
scores = []
X = fictrac_interp
X = X.reshape(-1,1)

for x in tqdm(range(dims['x'])):
    for y in range(dims['y']):
        Y = brain_interp[y,x,:]
        model = LinearRegression().fit(X, Y)
        
        #model.coef_
        #model.intercept_ 
        
        #betas.append(model.coef_)
        scores.append(model.score(X, Y))
        
scores = np.reshape(scores, (dims['x'],dims['y']))

plt.imshow(scores)
plt.show()
# Out:
# 100%|██████████| 92/92 [00:42<00:00,  2.03it/s]

# %%
plt.imshow(scores)
plt.show()

# %%
plt.imshow(scores)
plt.show()

# %%
betas = []
scores = []
Y = fictrac_interp
#X = X.reshape(-1,1)

for x in tqdm(range(dims['x'])):
    for y in range(dims['y']):
        X = brain_interp[y,x,:]
        X = X.reshape(-1,1)
        model = LinearRegression().fit(X, Y)
        
        #model.coef_
        #model.intercept_ 
        
        #betas.append(model.coef_)
        scores.append(model.score(X, Y))

scores = np.reshape(scores, (dims['x'],dims['y']))
plt.imshow(scores)
plt.show()
# Out:
# 100%|██████████| 80/80 [00:21<00:00,  3.50it/s]

# %%
plt.hist(np.ndarray.flatten(scores),bins=50)
plt.show()

# %%
plt.hist(np.ndarray.flatten(scores),bins=50)
plt.show()

# %%
plt.hist(np.ndarray.flatten(scores),bins=50)
plt.show()

# %%
x = brain_interp[0,0,:]
out = np.correlate(x,x,mode='full')

# %%
x = fictrac_interp
out = np.correlate(x,x,mode='full')

# %%
plt.plot(out,'x')
plt.xlim(17700,18200)
plt.show()

# %%
plt.plot(out,'x')
plt.xlim(17700,18200)
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
brain.shape
# Out:
# (128, 92, 51, 4128)

# %%
X = brain[:,:,25,:].reshape(-1,brain.shape[-1])

# %%
X.shape
# Out:
# (11776, 4128)

# %%
kmeans = KMeans(n_clusters=6, random_state=0).fit(X)

# %%
kmeans.labels_.shape
# Out:
# (11776,)

# %%
labels_filter = []
for i in kmeans.labels_:
    if i == 4:
        labels_filter.append(i)
    else:
        labels_filter.append(0)

# %%
labels_filter = np.reshape(labels_filter,(128,92))

# %%
plt.imshow(labels_filter.T)
plt.show()

# %%
plt.imshow(labels.T)
plt.show()

# %%
fic_to_brain.shape
# Out:
# (4128, 51)

# %%
fic_Z = bbb.interpolate_fictrac(fictrac,timestamps,fps,expt_len,behavior='dRotLabZ',sigma=3,sign=None)
# Out:
# ~~ interpolate_fictrac ~~
# interpolate_fictrac done. Duration: 16.15 ms

# %%
out = np.corrcoef(X, fic_to_brain[:,25])[-1,:]

# %%
np.shape(out)
# Out:
# (11777,)

# %%
out = out[:-1]

# %%
out2 = np.reshape(out,(128,92))

# %%
plt.imshow(out[0,:,:].T)
plt.show()

# %%
file = os.path.join(directory, 'glm', 'multivariate_analysis_green_dRotLabYabs.nii')
glm = bbb.load_numpy_brain(file)
# Out:
# ~~ load_numpy_brain ~~
# load_numpy_brain done. Duration: 15.09 ms

# %%
pca = PCA(n_components=20)
pca.fit(X)  
#PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#  svd_solver='auto', tol=0.0, whiten=False)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=20, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
pca.components_.shape
# Out:
# (10, 4128)

# %%
spacer = .05
plt.figure(figsize=(20,10))
plt.plot(pca.components_[0,:])
plt.plot(pca.components_[1,:]+spacer)
plt.plot(pca.components_[2,:]+spacer*2)
plt.plot(pca.components_[3,:]+spacer*3)
#plt.plot(fic_Y[:,25]*10)
plt.xlim(0,2000)
plt.show()

# %%
spacer = .05
plt.figure(figsize=(20,10))
plt.title('PC1 and Forward Velocity')
plt.plot(timestamps[:,25]/1000,pca.components_[0,:],label='PC1')
plt.plot(timestamps[:,25]/1000,fic_Z[:,25],label='Forward Velocity')
#plt.xlim(0,800)
plt.xlabel('time, sec')
plt.legend()
plt.show()

# %%
corred = np.correlate(pca.components_[0,:],np.abs(fic_Y[:,25]),mode='full')

# %%
a = [0,0,1,0,0]
v = [0,0,1,0,0]
out=np.correlate(a,v,mode='full')
plt.plot(out,'o')
plt.axvline(len(a)-1)
plt.show()
#so, if peak to left, means pc comes first

# %%
corred = np.convolve(pca.components_[0,:],np.abs(fic_Y[:,25]),mode='full')

# %%
len(corred)
# Out:
# 8255

# %%
fic_Y[:,25].shape
# Out:
# (4128, 4128)

# %%
np.diff(timestamps[:,25])
# Out:
# array([436.06224, 436.06224, 436.06224, ..., 436.06224, 436.06224,
#        436.06224])

# %%
bins = bbb.create_bins(436.06224,436.06224*4128,436.06224*4128)

# %%
bins
# Out:
# array([-1800064.92672, -1799628.86448, -1799192.80224, ...,
#         1799192.80224,  1799628.86448,  1800064.92672])

# %%
corred = np.correlate(pca.components_[18,:],np.abs(fic_Y[:,25]),mode='full')
plt.figure(figsize=(10,10))
plt.title('Cross-Correlation of PC1 and Forward Velocity')
plt.plot(bins[1:-1]/1000,corred,color='k',marker='x')
plt.xlim(-20,20)
plt.axvline(0,linestyle='--',color='r')
plt.xlabel('time, sec')
plt.show()

# %%
plt.figure(figsize=(20,10))
for i in range(10):
    plt.subplot(1,10,i+1)
    corred = np.correlate(pca.components_[i,:],np.abs(fic_Y[:,25]),mode='full')
    corred = scipy.ndimage.filters.gaussian_filter(corred,sigma=1)
    plt.title('PC {}'.format(i+1))
    plt.plot(bins[1:-1]/1000,corred,label='PC {}'.format(i+1),linewidth=3,color='k')
    plt.xlim(-20,20)
    plt.axvline(0,linestyle='--',color='r')
    plt.xlabel('time, sec')
    plt.subplots_adjust(wspace=0.1, hspace=0)
    #plt.axis('off')
    plt.gca().axes.get_yaxis().set_visible(False)
    plt.gca().axes.get_xaxis().set_visible(False)
    plt.ylim(-0.03,0.08)
    plt.axhline(0,linestyle='--',color='r')
    
#plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,10))
plt.title('Cross-Correlation of PC1 and Forward Velocity')
plt.plot(corred,color='k',marker='x')
plt.xlim(4100,4200)
plt.axvline(len(pca.components_[0,:])-1,linestyle='--',color='r')
plt.xlabel('time, sec')
plt.show()

# %%
out = np.reshape(pca.components_, (10,128,92))

# %%
pca.explained_variance_.shape
# Out:
# (10,)

# %%
plt.figure(figsize=(30,20))
for i in np.arange(5,10):
    plt.subplot(1,5,i+-4)
    plt.axis('off')
    plt.title('PC {}'.format(i+1))
    plt.imshow(out[i,:,:].T)
    plt.subplots_adjust(wspace=0, hspace=0)
plt.show()

# %%
pca = PCA(n_components=10)
pca.fit(X.T)  
#PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#  svd_solver='auto', tol=0.0, whiten=False)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=10, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
var_exp = pca.explained_variance_
normalized_var = (var_exp/np.sum(var_exp)*100)
np.cumsum(normalized_var)
# Out:
# array([ 21.11996642,  30.89501402,  39.15737077,  46.82053783,
#         53.81317331,  58.82416524,  63.26503416,  67.3451901 ,
#         70.95690388,  74.40349204,  77.60937728,  80.57001955,
#         83.42152789,  86.05571641,  88.64929795,  91.07127665,
#         93.38669114,  95.64152258,  97.84333727, 100.        ])

# %%
plt.figure(figsize=(10,10))
plt.bar(x=[i for i in range(10)],height=(pca.explained_variance_))
plt.ylabel('Cumulative variance explained')
plt.xlabel('Principle Component')
plt.title('PCA on whole-brain neural timeseries of a walking fly')
plt.show()

# %%
pca.explained_variance_
# Out:
# array([160.33326702,  39.89878236,  35.0890811 ,  32.05040003,
#         27.27860285,  20.09517915,  17.39638929,  15.933489  ,
#         14.10220898,  13.38110611])
