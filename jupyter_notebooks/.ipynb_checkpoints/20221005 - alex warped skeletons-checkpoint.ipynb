# %%
from neuprint import Client
from neuprint import NeuronCriteria as NC
from neuprint import fetch_neurons
from neuprint import fetch_adjacencies
from neuprint.utils import connection_table_to_matrix
import bokeh.palettes
from bokeh.plotting import figure, show, output_notebook
output_notebook()
import hvplot.pandas
import holoviews as hv
import numpy as np
import pandas as pd
import ants
import nibabel as nib
import os
import pickle
import scipy
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import networkx as nx
from fa2 import ForceAtlas2
from nxviz import CircosPlot
import nxviz as nv
import tqdm
import time
from scipy.ndimage.morphology import binary_erosion
from scipy.ndimage.morphology import binary_dilation
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import fcluster
from scipy.cluster import hierarchy
from scipy.fftpack import fft,fftshift,ifft
from scipy import signal
import bigbadbrain as bbb
from scipy.ndimage.filters import gaussian_filter1d
import matplotlib.colors as mcolors
import brainsss
import cv2
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# /home/users/brezovec/.local/lib/python3.6/site-packages/ants/viz/render_surface_function.py:16: UserWarning: Cant import Plotly. Install it `pip install chart_studio` if you want to use ants.render_surface_function
#   "Cant import Plotly. Install it `pip install chart_studio` if you want to use ants.render_surface_function"

# %%
connectome_dir = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20220624_supervoxels_in_FDA'

save_file = os.path.join(connectome_dir,'20220906_turn_common.npy')
cells_turn_common = np.load(save_file)
print(len(cells_turn_common))

save_file = os.path.join(connectome_dir,'20220906_fwd_common.npy')
cells_fwd_common = np.load(save_file)
print(len(cells_fwd_common))
# Out:
# 59
# 54

# %%
file = "/oak/stanford/groups/trc/data/Alex/luke_list_transformed_FDA_physical.npy"
skeletons = np.load(file)
print(skeletons.shape)
ids = np.asarray([int(i) for i in skeletons[:,3]])
# Out:
# (4154674, 4)

# %%
############################
### load behavior scores ###
############################
unique_crop = np.load(os.path.join(connectome_dir, 'unique_glm_in_hemibrain.npy'))

behavior = []
for beh in [0,1,2]:
    unique_crop_thresh = unique_crop[...,beh].copy()
    unique_crop_thresh[unique_crop[...,beh]>=.01] = 1
    unique_crop_thresh[unique_crop[...,beh]<.01] = np.nan
    behavior.append(unique_crop_thresh==1)
    
beh = 1
unique_crop_thresh = unique_crop[...,beh].copy()
unique_crop_thresh[unique_crop[...,beh]>=.01] =  1
unique_crop_thresh[unique_crop[...,beh]<.01] =  0

# %%
def load_FDA():
    FDA_file = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/anat_templates/20220301_luke_2_jfrc_affine.nii'
    FDA = np.asarray(nib.load(FDA_file).get_fdata().squeeze(), dtype='float32')
    FDA = ants.from_numpy(FDA)
    FDA.set_spacing((.38,.38,.38))
    FDA_lowres = ants.resample_image(FDA,(2.6,2.6,5),use_voxels=False)
    #FDA_lowres = ants.resample_image(FDA,(.76,.76,.76),use_voxels=False)


    return FDA, FDA_lowres

FDA, FDA_lowres = load_FDA()

# %%
file = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20220624_supervoxels_in_FDA/hemibrain_all_neurons_synapses_polypre_centrifugal_synapses.pickle'
file = open(file, 'rb')
synapses = pickle.load(file)
cell_ids = np.unique(synapses['bodyid'])

# %%
def load_roi_atlas():
    atlas_path = "/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/anat_templates/jfrc_2018_rois_improve_reorient_transformed.nii"
    atlas = np.asarray(nib.load(atlas_path).get_fdata().squeeze(), dtype='float32')
    atlas = ants.from_numpy(atlas)
    atlas.set_spacing((.76,.76,.76))
    atlas = ants.resample_image(atlas,(2.6,2.6,5),use_voxels=False)
    atlas = atlas.numpy()
    atlas_int = np.rint(atlas)
    atlas_clean = np.copy(atlas_int)
    diff_atlas = atlas_int - atlas
    thresh = 0.001
    atlas_clean[np.where(np.abs(diff_atlas)>thresh)] = 0
    return atlas_clean

atlas = load_roi_atlas()

# %%
# hemibrain bounding box
start = {'x': 46, 'y': 5, 'z': 5}
stop = {'x': 147, 'y': 89, 'z': 34}

FDA_crop = FDA_lowres[start['x']:stop['x'],
                     start['y']:stop['y'],
                     start['z']:stop['z']]

# %%
explosion_rois = brainsss.load_explosion_groups()
all_rois = brainsss.unnest_roi_groups(explosion_rois)
roi_masks = brainsss.make_single_roi_masks(all_rois, atlas)

# %%
##################
### ROI GROUPS ###
##################

select_rois= {
32: 'IVLP_R',
38: 'IPS_R',
37: 'SPS_R',
#33: 'PLP_R',
34: 'AOTU_R',
8: 'LAL_R',
}

full_group = {
26: 'FB',
4: 'NO',
5: 'BU_R',
54: 'BU_L',
8: 'LAL_R',
56: 'LAL_L',
31: 'PVLP_R',
76: 'PVLP_L',
6: 'PB',
23: 'EB',
13: 'VES_R',  
40: 'EPA_R',
35: 'GOR_R',
11: 'AMMC_R',
60: 'VES_L', 
85: 'EPA_L',
80: 'GOR_L',
58: 'AMMC_L',
50: 'PRW',
9: 'SAD',
49: 'GNG',
30: 'AVLP_R',
75: 'AVLP_L',
24: 'AL_R',
70: 'AL_L',
64: 'MB_PED_L',
65: 'MB_VL_L',
66: 'MB_ML_L',
81: 'MB_CA_L',
17: 'MB_PED_R',
18: 'MB_VL_R',
19: 'MB_ML_R',
36: 'MB_CA_R',
32: 'IVLP_R',
77: 'IVLP_L',
10: 'CAN_R',
20: 'FLA_R',
57: 'CAN_L',
67: 'FLA_L',
27: 'SLP_R',
29: 'SMP_R',
33: 'PLP_R',
7: 'LH_R',
38: 'IPS_R',
37: 'SPS_R',
16: 'CRE_R',
39: 'SCL_R',
12: 'ICL_R',
15: 'ATL_R',
14: 'IB_R',
28: 'SIP_R',#####
72: 'SLP_L',   
74: 'SMP_L',
78: 'PLP_L',
55: 'LH_L',
83: 'IPS_L',
82: 'SPS_L',
63: 'CRE_L',
84: 'SCL_L',  
59: 'ICL_L',
62: 'ATL_L',
61: 'IB_L',
73: 'SIP_L',
25: 'MED_R',
3: 'LO_R',
22: 'LP_R',
34: 'AOTU_R',
71: 'MED_L',
53: 'LO_L',
69: 'LP_L',
79: 'AOTU_L',
}

# %%
def make_single_roi_contours(roi_masks, atlas):
    roi_contours = {}
    for roi in roi_masks:
        try:
            mask = roi_masks[roi]
            _, mask_binary = cv2.threshold(np.max(mask,axis=-1).astype('uint8'), 0, 1, cv2.THRESH_BINARY) 
            contours, _ = cv2.findContours(mask_binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)#cv2.RETR_TREE

            canvas = np.ones(atlas[:,:,0].shape) #was ones for white on black
            out = cv2.drawContours(canvas, contours, -1, (0,255,0), 1)
            #out = np.abs(out-1) #flip 0/1
            roi_contour = out
            roi_contours[roi] = {}
            roi_contours[roi]['contour'] = roi_contour
        except:
            print(f"roi {roi} failed")
    return roi_contours

roi_contours = make_single_roi_contours(roi_masks, atlas)

# %%
strong_partners_unique = ['PS018_R',
 'PS013_R',
 'AOTU005_R',
 'PS059_R',
 'VES009_R',
 'LAL018_R',
 'WED075_R',
 'PS049_R',
 'LAL014_R',
 'LAL046_R',
 'PS100_R',
 'PS059_R',
 'PS274_R',
 'AOTU025_R']

strong_partners_id_unique = [5813125985,
 5813022629,
 1355115431,
 5813050791,
 5813069512,
 1140249804,
 1747625772,
 1664127054,
 1262360335,
 5813042961,
 5813057263,
 5813022547,
 1383111671,
 892294329]

DNa04 = 1262014782
DNa03 = 1139909038
DNa02 = 1140245595

# %%
strong_partners_unique[13-3]
# Out:
# 'PS100_R'

# %%
all_ = [DNa02] + [DNa03] + [DNa04] + strong_partners_id_unique

# %%
DNa04_dominant = []

# %%
cmap = matplotlib.cm.get_cmap('Spectral')
values = np.linspace(0,1,6)
colors = cmap(values)

# %%
# mask starts at (241,112,36), which is (2.6,2.6,5)
# mask is cropped to bounding box (101, 84, 29)
# then each axis is scaled by 10 (1010, 840)

# mask_crop overlays correctly with neurons
# 


# neurons are in real space
# i want to plot in 2.6um space with box crop

# %%
unique_crop_thresh.shape
# Out:
# (101, 84, 29)

# %%
plt.imshow(np.max(unique_crop_thresh,axis=-1))

# %%
plt.imshow(np.max(intersect,axis=-1))

# %%
#############################
### CREATE HIGH RES MASKS ###
#############################

### make behavior high res and smooth
behavior_highres = ants.resample_image(ants.from_numpy(unique_crop_thresh),(.1,.1,.1),use_voxels=False,interp_type=0).numpy()
behavior_highres = scipy.ndimage.gaussian_filter(behavior_highres,sigma=10)
behavior_highres[behavior_highres>.5] = 1

#masks_highres = {}
#contours_highres = {}
behavior_highres = {}

for roi in select_rois.keys():
    print(roi)
    
    mask = roi_masks[roi].copy()
    
    if roi == 32:
        ## add AMMC, as it technically belongs in the Wedge
        mask += roi_masks[11].copy()
        
    mask_crop = mask[start['x']:stop['x'],
                     start['y']:stop['y'],
                     start['z']:stop['z']]*1
    
    ### make high res mask
    mask = ants.from_numpy(mask_crop.astype('float'))
    mask_highres = ants.resample_image(mask,(.1,.1,.1),use_voxels=False,interp_type=0).numpy()
    mask_highres = scipy.ndimage.gaussian_filter(mask_highres,sigma=10)
    mask_highres[mask_highres>.5] = 1
    
    ### also produce the intersect of the roi with the behavior mask ###
    intersect = np.logical_and(mask_highres == 1, behavior_highres==1).astype('int')
    intersect = intersect.astype('float')
#     intersect = ants.from_numpy(intersect.astype('float'))
#     intersect = ants.resample_image(intersect,(.1,.1,.1),use_voxels=False,interp_type=0).numpy()
#     intersect = scipy.ndimage.gaussian_filter(intersect,sigma=10)
#     intersect[intersect>.5] = 1
    _, mask_binary = cv2.threshold(np.max(intersect,axis=-1).astype('uint8'), 0, 1, cv2.THRESH_BINARY) 
    behavior_highres[roi] = mask_binary

    ############# MAIN
#     _, mask_binary = cv2.threshold(np.max(mask_highres,axis=-1).astype('uint8'), 0, 1, cv2.THRESH_BINARY) 
#     masks_highres[roi] = mask_binary
#     contours, _ = cv2.findContours(mask_binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)#cv2.RETR_TREE
#     canvas = np.ones(mask_highres[:,:,0].shape)
#     out = cv2.drawContours(canvas, contours, -1, (0,255,0), 1)
#     out = np.abs(out-1)
#     contours_highres[roi] = out
# Out:
# 32

# %%
plt.figure(figsize=(10,10))



### PLOT GREY VOLUMES
for roi in select_rois.keys():
    temp = masks_highres[roi].T.copy()
    temp = temp.astype('float')
    temp[np.where(temp==0)]=np.nan
    plt.imshow(temp,cmap='Greys',vmin=.8,vmax=1.5)

### PLOT BEH
for roi in select_rois.keys():
    temp = behavior_highres[roi].T.copy()
    temp = temp.astype('float')
    temp[np.where(temp==0)]=np.nan
    plt.imshow(temp,cmap='Reds',vmin=.5,vmax=1)
    
### PLOT BLACK CONTOURS
for roi in select_rois.keys():
    mask_dilated = binary_dilation(contours_highres[roi], iterations=1)*1
    mask_dilated = mask_dilated.astype('float')
    mask_dilated[np.where(mask_dilated==0)] = np.nan
    plt.imshow(mask_dilated.T,cmap='Greys_r')
    
#group_colors = [, '#bc5090', '#ffa600']
colors=['k','k','k','#ffa600','#516EBD','#bc5090']
for j,id_ in enumerate(np.asarray(all_)[[0,1,2,9,13,5]]):#[1355115431,1140245595,]):#,1747625772,1262360335,1664127054]):
    out = skeletons[np.where(ids==id_)[0],:3]

    distance = (np.diff(out[:,0])**2 + np.diff(out[:,1])**2 + np.diff(out[:,2])**2)**.5
    bps = np.where(distance>4)[0]
    for i in range(len(bps)-1):
        xs = (out[bps[i]+1:bps[i+1],0]/2.6)
        ys = (out[bps[i]+1:bps[i+1],1]/2.6)#5
        xs -= start['x']
        ys -= start['y']
        # scale up to match highres contours
        xs*=10
        ys*=10

        plt.plot(xs,ys,color=colors[j],lw=.5)
        
plt.xlim(200,800)
plt.ylim(900,150)
plt.axis('off')

save_path = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/figs'
timestr = time.strftime("%Y%m%d-%H%M%S")
fname = os.path.join(save_path, f'{timestr}')
#plt.savefig(fname,dpi=300,bbox_inches='tight',transparent=True)

# %%
beh = 1
unique_crop_thresh = unique_crop[...,beh].copy()
unique_crop_thresh[unique_crop[...,beh]>=.01] =  1
unique_crop_thresh[unique_crop[...,beh]<.01] =  np.nan

# %%
# I can quickly just see what it looks like if we include the ROI masked signals

DN_crop = roi_masks[38][start['x']:stop['x'],
                     start['y']:stop['y'],
                     start['z']:stop['z']].copy()*1

intersect = np.logical_and(DN_crop == 1, unique_crop_thresh==1).astype('int')
intersect = intersect.astype('float')
intersect[intersect == 0] = np.nan

DN_crop = DN_crop.astype('float')
DN_crop[DN_crop==0] = np.nan

fig = plt.figure(figsize=(20,10))
grid = ImageGrid(fig, 111, nrows_ncols=(6, 5), axes_pad=.05)
for z in range(29):
    grid[z].imshow(FDA_crop[:,:,z].T,cmap='Greys_r')
    grid[z].imshow(DN_crop[:,:,z].T, cmap='Greens', vmin=0, vmax=1)
    grid[z].imshow(unique_crop_thresh[:,:,z].T, cmap='Reds', vmin=0, vmax=1)
    grid[z].imshow(intersect[:,:,z].T, cmap='plasma', vmin=0, vmax=1)

# %%
DN_crop = roi_masks[34][start['x']:stop['x'],
                     start['y']:stop['y'],
                     start['z']:stop['z']].copy()

# %%
roi=34
plt.imshow(masks_highres[roi].T,cmap='Greys',vmin=.5,vmax=1.5)

# %%
select_rois.keys()
# Out:
# dict_keys([32, 38, 37, 33, 34, 8])

# %%
mask_highres[8].shape
# Out:
# (840, 290)

# %%
mask_dilated.shape
# Out:
# (1010, 840)

# %%
mask_crop.shape
# Out:
# (101, 84, 29)

# %%
plt.imshow(np.max(roi_masks[34],axis=-1))

# %%
mask_crop.shape
# Out:
# (84, 101)

# %%
np.asarray(all_)[[0,9,13,16]]
# Out:
# array([1140245595, 1747625772, 5813057263,  892294329])

# %%
len(strong_partners_id_unique)
# Out:
# 14

# %%
plt.figure(figsize=(10,10))
#colors=['orange','pink','orange','b','g']
#plt.imshow(np.max(FDA_crop,axis=-1).T,cmap='Greys_r')

beh = 1
unique_crop_thresh = unique_crop[...,beh].copy()
unique_crop_thresh[unique_crop[...,beh]>=.01] =  1
unique_crop_thresh[unique_crop[...,beh]<.01] =  0
beh_mask = np.max(unique_crop_thresh[:,:,10:11],axis=-1)
#beh_mask = np.max(unique_crop_thresh[:,:,17:18],axis=-1)

beh_mask[beh_mask==0] = np.nan
plt.imshow(beh_mask.T,cmap='Reds',vmin=0,vmax=1)

for j,id_ in enumerate(all_):#[1355115431,1140245595,]):#,1747625772,1262360335,1664127054]):
    plt.subplot(5,4,j+1)
    plt.imshow(FDA_crop[:,:,10].T,cmap='Greys_r')
    out = skeletons[np.where(ids==id_)[0],:3]

    distance = (np.diff(out[:,0])**2 + np.diff(out[:,1])**2 + np.diff(out[:,2])**2)**.5
    bps = np.where(distance>4)[0]
    for i in range(len(bps)-1):
        xs = out[bps[i]+1:bps[i+1],0]/2.6
        ys = out[bps[i]+1:bps[i+1],1]/2.6
        xs -= start['x']
        ys -= start['y']

        plt.plot(xs,ys,color=colors[j],lw=.5)

# %%
9,13,16

# %%
plt.imshow(np.max(unique_crop_thresh,axis=-1).T, cmap='Reds', vmin=0, vmax=1)

# %%
beh = 1
unique_crop_thresh = unique_crop[...,beh].copy()
unique_crop_thresh[unique_crop[...,beh]>=.01] =  1
unique_crop_thresh[unique_crop[...,beh]<.01] =  0
beh_mask = np.max(unique_crop_thresh[:,:,8:12],axis=-1)
beh_mask[beh_mask==0] = np.nan
plt.imshow(beh_mask.T)

# %%
id_ = 1140245595

# %%
out = skeletons[np.where(ids==id_)[0],:3]

# %%
stop = 10
plt.figure(figsize=(10,10))
for i in range(stop):
    plt.scatter(out[:stop,0],out[:stop,1],s=20)
    plt.plot(out[:stop,0],out[:stop,1])
# Out:
# (29787, 3)

# %%
stop = 2000
plt.figure(figsize=(10,10))
for i in range(stop):
    if distance[i]>2:
        color='r'
    else:
        color='k'
    plt.scatter(out[i,0],out[i,1],s=20,color='k')
    plt.plot(out[i:i+2,0],out[i:i+2,1],color=color)

# %%
plt.figure(figsize=(10,10))
plt.imshow(FDA_lowres[:,:,100].T,cmap='Greys_r')

# %%
bps = np.where(distance>4)[0]
len(bps)
# Out:
# 192

# %%
plt.plot(breakpoints)
plt.xlim(0,1000)
# Out:
# (0, 1000)

# %%
len(distance)
# Out:
# 29786

# %%
out[i:i+1,0]
# Out:
# array([265.7361145])

# %%
distance = (np.diff(out[:,0])**2 + np.diff(out[:,1])**2 + np.diff(out[:,2])**2)**.5

# %%
plt.figure(figsize=(10,10))
plt.plot(distance)
plt.xlim(0,1000)
plt.ylim(0,40)
# Out:
# (0, 40)

# %%
plt.hist(np.diff(out[:,0]),bins=100);
plt.ylim(0,200)
# Out:
# (0, 200)

# %%
ids[-1]
# Out:
# 5813125985

# %%
out = np.reshape(skeletons,())
out.shape

# %%
file = "/oak/stanford/groups/trc/data/Alex/luke_list.nii"
skeletons = ants.image_read(file)

# %%
skeletons
# Out:
# ANTsImage (LPI)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (1652, 768, 479)
# 	 Spacing    : (1.0, 1.0, 1.0)
# 	 Origin     : (0.0, 0.0, 0.0)
# 	 Direction  : [-1.  0.  0.  0. -1.  0.  0.  0.  1.]

# %%
plt.imshow(skeletons[:,:,250].T)

# %%
file = "/oak/stanford/groups/trc/data/Alex/albert_data/LC11/anat/LC11_to_FDA/brig3.nii"
brain = ants.from_numpy(ants.image_read(file)[:,:,::-1])

# %%
"/oak/stanford/groups/trc/data/Alex/clab_data/LC11"

# %%
brain
# Out:
# ANTsImage (LPI)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (826, 384, 240)
# 	 Spacing    : (0.76, 0.76, 0.76)
# 	 Origin     : (0.0, 0.0, 0.0)
# 	 Direction  : [-1.  0.  0.  0. -1.  0.  0.  0.  1.]

# %%
FDA_lowres.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-112-536acef17769> in <module>()
# ----> 1 FDA_lowres.shape
#
# NameError: name 'FDA_lowres' is not defined

# %%
plt.figure(figsize=(10,10))
z=200
plt.subplot(2,1,1)
plt.imshow(brain[:,:,z].T)
plt.axhline(200)

plt.subplot(2,1,2)
plt.imshow(FDA_lowres[:,:,z].T)
plt.axhline(200)
