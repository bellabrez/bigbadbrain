# %%
import numpy as np
from time import time
import os
import sys
import scipy
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
from scipy.linalg import toeplitz
from sklearn.linear_model import LassoLarsIC
from sklearn.linear_model import RidgeCV
from sklearn.cluster import KMeans
from skimage.filters import threshold_triangle

import bigbadbrain as bbb

# %%
flies = list(range(30,44))
fictracs = []
root_path = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20190101_walking_dataset'
for fly in flies:
    funcs = []
    fly_dir = os.path.join(root_path, 'fly_{}'.format(fly))
    funcs = os.listdir(fly_dir)
    for func in funcs:
        try:
            fictrac = bbb.load_fictrac(os.path.join(fly_dir, func, 'fictrac'))
            fictracs.append(fictrac)
            print(fly)
        except:
            pass
# Out:
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.14 sec
# 30
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.19 sec
# 33
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.26 sec
# 33
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.24 sec
# 34
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.25 sec
# 34
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.23 sec
# 35
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.12 sec
# 36
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.21 sec
# 36
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.24 sec
# 37
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.36 sec
# 37
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.53 sec
# 38
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.23 sec
# 38
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.35 sec
# 39
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.31 sec
# 39
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.19 sec
# 40
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.59 sec
# 41
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.17 sec
# 42
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.27 sec
# 43
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.45 sec
# 43
#
# ~~ load_fictrac ~~
#
# ~~ load_fictrac ~~
# load_fictrac done. Duration: 3.36 sec
# 43
#
# ~~ load_fictrac ~~

# %%
########################################
### Plot Forward Velocity Histograms ###
########################################

bins = np.ndarray.tolist(np.arange(-2,5,.1))
fig = plt.figure(figsize=(10,10))
behavior = 'dRotLabY'
sphere_radius = 3.175e-3 #4.5e-3
binned_data = []
#for i in range(len(fictracs)):
for i in [9, 11,  2, 19, 12, 13,  8, 18, 17, 14]:
    vector = fictracs[i][behavior]*sphere_radius # now in m per 20ms
    vector = vector * 100 * 100 # multiply by Hz and cm/meter # now in cm per sec
    weights = np.ones_like(vector)/float(len(vector))
    binned,throwaway,throwaway2=plt.hist(vector,bins,weights=weights,label = str(i),stacked=True, histtype = 'step')
    binned_data.append(binned)
plt.legend()
plt.xlim(-2,5)
plt.xlabel("Velocity (cm/sec)")
plt.ylabel("Frequency, Normalized")
plt.title("Forward Velocity Histograms")
plt.show()

# %%
plt.rcParams.update({'font.size': 36})

# %%
########################################
### Plot Forward Velocity Histograms ###
########################################

bins = np.ndarray.tolist(np.arange(0,5,.1))
fig = plt.figure(figsize=(10,10))
behavior = 'dRotLabY'
sphere_radius = 4.5e-3 #3.175e-3 #
binned_data = []
#for i in range(len(fictracs)):
for i in [9, 11,  2, 19, 12, 13,  8, 18, 17, 14]:
    vector = fictracs[i][behavior]*sphere_radius # now in m per 20ms
    vector = vector * 100 * 100 # multiply by Hz and cm/meter # now in cm per sec
    weights = np.ones_like(vector)/float(len(vector))
    binned,throwaway,throwaway2=plt.hist(vector,bins,weights=weights,label = str(i),stacked=True, histtype = 'step',linewidth=3)
    binned_data.append(binned)
plt.xlim(0,5)
plt.ylim(0,.25)
plt.xlabel("Velocity (cm/sec)")
plt.ylabel("Frequency, Normalized")
#plt.title("Forward Velocity Histograms")
plt.show()

# %%
sums = []
for i in range(len(fictracs)):
    vector = fictracs[i][behavior]*sphere_radius # now in m per 20ms
    sums.append(np.sum(vector))

# %%
np.argsort(sums)
# Out:
# array([ 4,  1, 15,  0, 16,  6,  7,  3,  5, 10,  9, 11,  2, 19, 12, 13,  8,
#        18, 17, 14])

# %%
sums[14]
# Out:
# 2.050918964157814

# %%
weights[100:]
# Out:
# array([1.1080578e-05, 1.1080578e-05, 1.1080578e-05, ..., 1.1080578e-05,
#        1.1080578e-05, 1.1080578e-05])

# %%
np.ones_like([4,3,4])
# Out:
# array([1, 1, 1])

# %%
np.min(vector)
# Out:
# -5.605062425446455

# %%
########################################
### Plot Angular Velocity Histograms ###
########################################

bins = np.ndarray.tolist(np.arange(-500,500,10))
fig = plt.figure(figsize=(10,10))
behavior = 'dRotLabZ'
sphere_radius = 4.5e-3 #3.175e-3 #
binned_data = []
for i in range(len(fictracs)):
    vector = np.rad2deg(fictracs[i][behavior]) # now in deg per 20ms
    vector = vector * 50 # now in deg per sec
    weights = np.ones_like(vector)/float(len(vector))
    binned,throwaway,throwaway2=plt.hist(vector,bins,weights=weights,label = str(i),stacked=True, linewidth=3,histtype = 'step')
    binned_data.append(binned)

#plt.legend()
plt.xlim(-500,500)
plt.xlabel("Velocity (deg/sec)")
plt.ylabel("Frequency, Normalized")
#plt.title("Side-slip Velocity")
plt.show()

# %%
root_path = 'C:/Users/User/Downloads/drive-download-20190606T161949Z-001'
files = [os.path.join(root_path, file) for file in os.listdir(root_path)]

fictracs = []
for file in files:
    fictracs.append(load_fictrac2(file))

# %%
len(fictracs)
# Out:
# 21

# %%
thing
# Out:
# 'C:/Users/User/Downloads/drive-download-20190606T161949Z-001\\fictrac (1).dat'

# %%
def load_fictrac2(directory):
    """ Loads fictrac data from .dat file that fictrac outputs.

    To-do: change units based on diameter of ball etc.
    For speed sanity check, instead remove bad frames so we don't have to throw out whole trial.

    Parameters
    ----------
    directory: string of full path to file
    file: string of file name

    Returns
    -------
    fictrac_data: pandas dataframe of all parameters saved by fictrac """

    with open(directory,'r') as f:
        df = pd.DataFrame(l.rstrip().split() for l in f)

        # Name columns
        df = df.rename(index=str, columns={0: 'frameCounter',
                                       1: 'dRotCamX',
                                       2: 'dRotCamY',
                                       3: 'dRotCamZ',
                                       4: 'dRotScore',
                                       5: 'dRotLabX',
                                       6: 'dRotLabY',
                                       7: 'dRotLabZ',
                                       8: 'AbsRotCamX',
                                       9: 'AbsRotCamY',
                                       10: 'AbsRotCamZ',
                                       11: 'AbsRotLabX',
                                       12: 'AbsRotLabY',
                                       13: 'AbsRotLabZ',
                                       14: 'positionX',
                                       15: 'positionY',
                                       16: 'heading',
                                       17: 'runningDir',
                                       18: 'speed',
                                       19: 'integratedX',
                                       20: 'integratedY',
                                       21: 'timeStamp',
                                       22: 'sequence'})

        # Remove commas
        for column in df.columns.values[:-1]:
            df[column] = [float(x[:-1]) for x in df[column]]

        fictrac_data = df
                
    # sanity check for extremely high speed (fictrac failure)
    speed = np.asarray(fictrac_data['speed'])
    max_speed = np.max(speed)
    if max_speed > 10:
        raise Exception('Fictrac ball tracking failed (reporting impossibly high speed).')
    return fictrac_data

# %%
#####################
###  Define Data  ###
#####################

Path = '/oak/stanford/groups/trc/data/Brezovec/VRArena/exps'
#Path = '/scratch/users/brezovec/exps'

Expts = ['exp-20181102-165424',
         'exp-20181102-175232',
         'exp-20181103-184106',
         'exp-20181104-162518',
         'exp-20181105-115608',
         'exp-20181107-181316',
         'exp-20181108-111101',
         'exp-20181108-143044',
         'exp-20181109-084314']

#Expts = ['exp-20181031-190938']

# %%
###########################
###  Define Trial Class ###
###########################

class Trial:
    def __init__ (self, dirName):
        print('Importing from: {}'.format(Path))
        self.cam = Cam(os.path.join(dirName, 'cam.txt'))
        self.cnc = Cnc(os.path.join(dirName, 'cnc.txt'))
        self.stimuli = Stimuli(os.path.join(dirName, 'stimuli.txt'), mode='static_stim')
        
class Cam:
    def __init__ (self, fname):
        print(fname)
        self.tvec = np.genfromtxt(fname, delimiter=',',skip_header=1,usecols=(0,))
        self.xvec = np.genfromtxt(fname, delimiter=',',skip_header=1,usecols=(2,))
        self.yvec = np.genfromtxt(fname, delimiter=',',skip_header=1,usecols=(3,))
        self.pvec = np.genfromtxt(fname, delimiter=',',skip_header=1,usecols=(1,), dtype=bool)
        self.avec = np.genfromtxt(fname, delimiter=',',skip_header=1,usecols=(6,))

class Cnc:
    def __init__ (self, fname):
        print(fname)
        self.tvec = np.genfromtxt(fname, delimiter=',',skip_header=1,usecols=(0,))
        self.xvec = np.genfromtxt(fname, delimiter=',',skip_header=1,usecols=(1,))
        self.yvec = np.genfromtxt(fname, delimiter=',',skip_header=1,usecols=(2,))

class Stimuli:
    def __init__ (self, fname, mode):
        print(fname)
        
        if mode == 'static_stim':
            self.dict = stim_parser(fname)
            
        elif mode == 'moving_stim':
            with open(fname) as file:  
                data = file.read() 
            d=data.split('@')
            newStimTimes = [item for item in d if 'NewStim' in item]
            updateStimTimes = [item for item in d if 'UpdateStim' in item]
            StimTimesMessy = newStimTimes + updateStimTimes
            StimTimes = [float(item.split(' ')[0]) for item in StimTimesMessy]
            self.stimtimes = StimTimes

            ratesMessy = [item.split('\n') for item in StimTimesMessy]
            rates_nice = [item for sublist in ratesMessy for item in sublist]
            rates_only = [item for item in rates_nice if 'rate' in item]
            rates = [int(item.split(' ')[3]) for item in rates_only]
            self.rates = rates
            
        else:
            assert('invalid stimuli mode')
        
## For importing files in correct order:
def tryint(s):
    try:
        return int(s)
    except:
        return s

def alphanum_key(s):
    return [tryint(c) for c in re.split('([0-9]+)', s)]

def sort_nicely(x):
    x.sort(key=alphanum_key)
    
def stim_parser(fname):
    with open(fname) as file:  
        data = file.read() 
    d = data.split('\n')
    kv_pair = [item for item in d if ':' in item and '@' not in item]
    stim_dict = {}
    for item in kv_pair:
        key = item.split(':')[0]
        value = item.split(':')[1]
        key = re.sub(" |'|\"|,", "", key)
        value = re.sub(" |'|\"|,", "", value)
        stim_dict[key] = value
    return stim_dict

# %%
import re
from scipy.ndimage.interpolation import shift

# %%
#####################
###  Import Data  ###
#####################

trials = []        
for expt in Expts:
    dirNames = os.listdir(os.path.join(Path, expt))
    dirNames = [x for x in dirNames if 'trial' in x]
    sort_nicely(dirNames)
    trials.append(([Trial(os.path.join(Path, expt, dirName)) for dirName in dirNames]))
trials = [item for sublist in trials for item in sublist]
# Out:
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-1-20181102-170040/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-1-20181102-170040/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-1-20181102-170040/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-2-20181102-170055/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-2-20181102-170055/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-2-20181102-170055/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-3-20181102-170301/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-3-20181102-170301/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-3-20181102-170301/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-4-20181102-170450/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-4-20181102-170450/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-4-20181102-170450/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-5-20181102-171828/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-5-20181102-171828/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-5-20181102-171828/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-6-20181102-171943/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-6-20181102-171943/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-6-20181102-171943/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-7-20181102-172336/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-7-20181102-172336/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-7-20181102-172336/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-8-20181102-174336/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-8-20181102-174336/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-165424/trial-8-20181102-174336/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-1-20181102-175407/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-1-20181102-175407/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-1-20181102-175407/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-2-20181102-181157/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-2-20181102-181157/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-2-20181102-181157/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-3-20181102-181608/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-3-20181102-181608/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-3-20181102-181608/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-4-20181102-182236/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-4-20181102-182236/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-4-20181102-182236/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-5-20181102-185119/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-5-20181102-185119/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-5-20181102-185119/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-6-20181102-185241/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-6-20181102-185241/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-6-20181102-185241/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-7-20181102-185519/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-7-20181102-185519/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-7-20181102-185519/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-8-20181102-190427/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-8-20181102-190427/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-8-20181102-190427/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-9-20181102-190835/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-9-20181102-190835/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-9-20181102-190835/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-10-20181102-191055/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-10-20181102-191055/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-10-20181102-191055/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-11-20181102-191542/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-11-20181102-191542/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-11-20181102-191542/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-12-20181102-192052/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-12-20181102-192052/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-12-20181102-192052/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-13-20181102-192522/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-13-20181102-192522/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-13-20181102-192522/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-14-20181102-192609/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-14-20181102-192609/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-14-20181102-192609/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-15-20181102-192931/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-15-20181102-192931/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-15-20181102-192931/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-16-20181102-193118/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-16-20181102-193118/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-16-20181102-193118/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-17-20181102-193340/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-17-20181102-193340/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-17-20181102-193340/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-18-20181102-193643/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-18-20181102-193643/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-18-20181102-193643/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-19-20181102-193904/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-19-20181102-193904/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-19-20181102-193904/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-20-20181102-195800/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-20-20181102-195800/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181102-175232/trial-20-20181102-195800/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-1-20181103-184419/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-1-20181103-184419/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-1-20181103-184419/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-2-20181103-185019/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-2-20181103-185019/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-2-20181103-185019/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-3-20181103-185630/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-3-20181103-185630/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-3-20181103-185630/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-4-20181103-185643/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-4-20181103-185643/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-4-20181103-185643/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-5-20181103-190014/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-5-20181103-190014/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-5-20181103-190014/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-6-20181103-190234/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-6-20181103-190234/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-6-20181103-190234/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-7-20181103-190743/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-7-20181103-190743/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-7-20181103-190743/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-8-20181103-190946/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-8-20181103-190946/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-8-20181103-190946/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-9-20181103-191141/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-9-20181103-191141/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-9-20181103-191141/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-10-20181103-191421/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-10-20181103-191421/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-10-20181103-191421/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-11-20181103-192241/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-11-20181103-192241/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-11-20181103-192241/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-12-20181103-192557/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-12-20181103-192557/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-12-20181103-192557/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-13-20181103-193508/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-13-20181103-193508/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-13-20181103-193508/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-14-20181103-194339/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-14-20181103-194339/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-14-20181103-194339/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-15-20181103-194919/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-15-20181103-194919/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-15-20181103-194919/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-16-20181103-213635/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-16-20181103-213635/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-16-20181103-213635/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-17-20181103-223722/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-17-20181103-223722/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181103-184106/trial-17-20181103-223722/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-1-20181104-162936/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-1-20181104-162936/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-1-20181104-162936/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-2-20181104-163037/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-2-20181104-163037/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-2-20181104-163037/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-3-20181104-163536/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-3-20181104-163536/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-3-20181104-163536/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-4-20181104-164018/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-4-20181104-164018/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-4-20181104-164018/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-5-20181104-164141/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-5-20181104-164141/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-5-20181104-164141/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-6-20181104-164403/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-6-20181104-164403/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-6-20181104-164403/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-7-20181104-164938/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-7-20181104-164938/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-7-20181104-164938/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-8-20181104-185134/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-8-20181104-185134/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-8-20181104-185134/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-9-20181104-185515/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-9-20181104-185515/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-9-20181104-185515/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-10-20181104-195223/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-10-20181104-195223/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-10-20181104-195223/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-11-20181105-115526/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-11-20181105-115526/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181104-162518/trial-11-20181105-115526/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-1-20181105-115917/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-1-20181105-115917/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-1-20181105-115917/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-2-20181105-120518/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-2-20181105-120518/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-2-20181105-120518/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-3-20181105-121229/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-3-20181105-121229/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-3-20181105-121229/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-4-20181105-122848/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-4-20181105-122848/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-4-20181105-122848/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-5-20181105-124019/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-5-20181105-124019/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-5-20181105-124019/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-6-20181105-124714/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-6-20181105-124714/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-6-20181105-124714/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-7-20181105-124958/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-7-20181105-124958/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-7-20181105-124958/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-8-20181105-125904/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-8-20181105-125904/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-8-20181105-125904/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-9-20181105-130753/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-9-20181105-130753/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-9-20181105-130753/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-10-20181105-131242/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-10-20181105-131242/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-10-20181105-131242/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-11-20181105-131734/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-11-20181105-131734/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-11-20181105-131734/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-12-20181105-132004/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-12-20181105-132004/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-12-20181105-132004/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-13-20181105-132423/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-13-20181105-132423/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-13-20181105-132423/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-14-20181105-132951/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-14-20181105-132951/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-14-20181105-132951/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-15-20181105-133315/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-15-20181105-133315/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-15-20181105-133315/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-16-20181105-134018/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-16-20181105-134018/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-16-20181105-134018/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-17-20181105-134255/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-17-20181105-134255/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-17-20181105-134255/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-18-20181105-134823/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-18-20181105-134823/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-18-20181105-134823/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-19-20181105-135304/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-19-20181105-135304/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-19-20181105-135304/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-20-20181105-135717/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-20-20181105-135717/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-20-20181105-135717/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-21-20181105-135914/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-21-20181105-135914/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-21-20181105-135914/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-22-20181105-135943/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-22-20181105-135943/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-22-20181105-135943/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-23-20181105-141227/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-23-20181105-141227/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-23-20181105-141227/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-24-20181105-141537/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-24-20181105-141537/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-24-20181105-141537/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-25-20181105-142611/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-25-20181105-142611/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-25-20181105-142611/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-26-20181105-143508/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-26-20181105-143508/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-26-20181105-143508/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-27-20181105-144406/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-27-20181105-144406/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-27-20181105-144406/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-28-20181105-144813/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-28-20181105-144813/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-28-20181105-144813/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-29-20181105-145437/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-29-20181105-145437/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-29-20181105-145437/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-30-20181105-150628/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-30-20181105-150628/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-30-20181105-150628/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-31-20181105-152448/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-31-20181105-152448/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181105-115608/trial-31-20181105-152448/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-1-20181107-181948/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-1-20181107-181948/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-1-20181107-181948/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-2-20181107-182044/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-2-20181107-182044/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-2-20181107-182044/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-3-20181107-182605/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-3-20181107-182605/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-3-20181107-182605/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-4-20181107-183035/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-4-20181107-183035/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-4-20181107-183035/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-5-20181107-183124/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-5-20181107-183124/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-5-20181107-183124/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-6-20181107-183703/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-6-20181107-183703/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-6-20181107-183703/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-7-20181107-184415/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-7-20181107-184415/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-7-20181107-184415/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-8-20181107-184915/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-8-20181107-184915/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-8-20181107-184915/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-9-20181107-185022/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-9-20181107-185022/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-9-20181107-185022/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-10-20181107-185206/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-10-20181107-185206/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-10-20181107-185206/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-11-20181107-185402/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-11-20181107-185402/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-11-20181107-185402/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-12-20181107-185617/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-12-20181107-185617/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-12-20181107-185617/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-13-20181107-185752/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-13-20181107-185752/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-13-20181107-185752/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-14-20181107-185856/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-14-20181107-185856/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-14-20181107-185856/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-15-20181107-190032/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-15-20181107-190032/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-15-20181107-190032/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-16-20181107-190148/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-16-20181107-190148/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-16-20181107-190148/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-17-20181107-190310/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-17-20181107-190310/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-17-20181107-190310/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-18-20181107-190450/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-18-20181107-190450/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-18-20181107-190450/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-19-20181107-190828/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-19-20181107-190828/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-19-20181107-190828/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-20-20181107-191037/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-20-20181107-191037/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-20-20181107-191037/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-21-20181107-191239/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-21-20181107-191239/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-21-20181107-191239/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-22-20181107-191545/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-22-20181107-191545/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-22-20181107-191545/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-23-20181107-192031/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-23-20181107-192031/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-23-20181107-192031/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-24-20181107-192324/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-24-20181107-192324/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181107-181316/trial-24-20181107-192324/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-1-20181108-111445/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-1-20181108-111445/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-1-20181108-111445/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-2-20181108-111603/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-2-20181108-111603/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-2-20181108-111603/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-3-20181108-112450/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-3-20181108-112450/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-3-20181108-112450/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-4-20181108-113930/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-4-20181108-113930/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-4-20181108-113930/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-5-20181108-114125/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-5-20181108-114125/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-5-20181108-114125/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-6-20181108-114232/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-6-20181108-114232/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-6-20181108-114232/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-7-20181108-114733/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-7-20181108-114733/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-7-20181108-114733/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-8-20181108-114822/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-8-20181108-114822/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-8-20181108-114822/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-9-20181108-114938/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-9-20181108-114938/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-9-20181108-114938/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-10-20181108-115139/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-10-20181108-115139/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-10-20181108-115139/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-11-20181108-115348/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-11-20181108-115348/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-11-20181108-115348/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-12-20181108-115555/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-12-20181108-115555/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-12-20181108-115555/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-13-20181108-115751/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-13-20181108-115751/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-13-20181108-115751/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-111101/trial-14-20181108-115835/cam.txt
# ...
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-6-20181108-150740/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-7-20181108-150854/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-7-20181108-150854/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-7-20181108-150854/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-8-20181108-151227/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-8-20181108-151227/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-8-20181108-151227/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-9-20181108-152645/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-9-20181108-152645/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-9-20181108-152645/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-10-20181108-153307/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-10-20181108-153307/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-10-20181108-153307/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-11-20181108-154102/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-11-20181108-154102/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-11-20181108-154102/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-12-20181108-154149/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-12-20181108-154149/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-12-20181108-154149/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-13-20181108-154720/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-13-20181108-154720/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-13-20181108-154720/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-14-20181108-154747/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-14-20181108-154747/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-14-20181108-154747/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-15-20181108-154904/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-15-20181108-154904/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-15-20181108-154904/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-16-20181108-155314/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-16-20181108-155314/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-16-20181108-155314/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-17-20181108-155404/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-17-20181108-155404/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-17-20181108-155404/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-18-20181108-160123/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-18-20181108-160123/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-18-20181108-160123/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-19-20181108-160249/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-19-20181108-160249/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-19-20181108-160249/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-20-20181108-160440/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-20-20181108-160440/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-20-20181108-160440/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-21-20181108-161627/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-21-20181108-161627/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-21-20181108-161627/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-22-20181108-161752/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-22-20181108-161752/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-22-20181108-161752/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-23-20181108-161853/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-23-20181108-161853/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-23-20181108-161853/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-24-20181108-161922/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-24-20181108-161922/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-24-20181108-161922/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-25-20181108-162146/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-25-20181108-162146/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-25-20181108-162146/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-26-20181108-162929/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-26-20181108-162929/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-26-20181108-162929/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-27-20181108-163447/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-27-20181108-163447/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-27-20181108-163447/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-28-20181108-163501/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-28-20181108-163501/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-28-20181108-163501/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-29-20181108-164101/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-29-20181108-164101/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-29-20181108-164101/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-30-20181108-165733/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-30-20181108-165733/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-30-20181108-165733/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-31-20181108-182724/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-31-20181108-182724/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181108-143044/trial-31-20181108-182724/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-1-20181109-085552/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-1-20181109-085552/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-1-20181109-085552/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-2-20181109-090315/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-2-20181109-090315/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-2-20181109-090315/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-3-20181109-090425/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-3-20181109-090425/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-3-20181109-090425/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-4-20181109-090724/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-4-20181109-090724/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-4-20181109-090724/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-5-20181109-090820/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-5-20181109-090820/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-5-20181109-090820/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-6-20181109-091659/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-6-20181109-091659/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-6-20181109-091659/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-7-20181109-091729/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-7-20181109-091729/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-7-20181109-091729/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-8-20181109-092927/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-8-20181109-092927/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-8-20181109-092927/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-9-20181109-093940/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-9-20181109-093940/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-9-20181109-093940/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-10-20181109-094144/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-10-20181109-094144/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-10-20181109-094144/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-11-20181109-094716/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-11-20181109-094716/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-11-20181109-094716/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-12-20181109-094827/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-12-20181109-094827/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-12-20181109-094827/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-13-20181109-095009/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-13-20181109-095009/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-13-20181109-095009/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-14-20181109-095122/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-14-20181109-095122/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-14-20181109-095122/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-15-20181109-100123/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-15-20181109-100123/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-15-20181109-100123/stimuli.txt
# Importing from: /oak/stanford/groups/trc/data/Brezovec/VRArena/exps
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-16-20181109-103143/cam.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-16-20181109-103143/cnc.txt
# /oak/stanford/groups/trc/data/Brezovec/VRArena/exps/exp-20181109-084314/trial-16-20181109-103143/stimuli.txt

# %%
########################
### Define Fly Class ###
########################

class Fly:
    def __init__ (self,trial,time_res=0.01,sigma=0):
        mode = 'static_stim'
        if np.any(trial.cam.pvec):
            # Get cam data (only time points where pvec is true, aka fly is present)
            camt = trial.cam.tvec[trial.cam.pvec]
            #Interpolate
            cama = interp1d(camt, trial.cam.avec[trial.cam.pvec],kind='nearest')
            camx = interp1d(camt, trial.cam.xvec[trial.cam.pvec])
            camy = interp1d(camt, trial.cam.yvec[trial.cam.pvec])
            # Get cnc data
            cncx = interp1d(trial.cnc.tvec, trial.cnc.xvec)
            cncy = interp1d(trial.cnc.tvec, trial.cnc.yvec)
            tmin = max(camt[0], trial.cnc.tvec[0])
            tmax = min(camt[-1], trial.cnc.tvec[-1])
            # Pull from interpolated data at chosen time resolution, and add camera and cnc positions
            self.t = np.arange(tmin, tmax, time_res)
            self.x = camx(self.t) + cncx(self.t)
            self.y = camy(self.t) + cncy(self.t)
            self.a = cama(self.t)
            # Unwrap angles and rotate
            self.angleUnwrapper()
            #self.a=angleChangeOrigin(self.a)
            self.a = 90-self.a #rotate angles 90deg to change ellipse fitting defined angles
            self.a = -self.a #flip angle horizontally due to camera flip
            # Smooth if asked to
            if sigma is not 0:
                self.x = scipy.ndimage.filters.gaussian_filter1d(self.x,sigma)
                self.y = scipy.ndimage.filters.gaussian_filter1d(self.y,sigma)
                self.a = scipy.ndimage.filters.gaussian_filter1d(self.a,sigma)
            self.tvid = self.t - camt[0] #for video debugging
            self.velocity()
            x_covered = np.sum(np.abs(np.diff(self.x)))
            y_covered = np.sum(np.abs(np.diff(self.y)))
            self.dist_covered = x_covered + y_covered
            self.duration = self.t[-1]-self.t[0]
            self.a_covered = np.sum(np.abs(np.diff(self.a)))
            
            if mode == 'static_stim':
                self.stimdict = trial.stimuli.dict

            elif mode == 'moving_stim':
                self.stimtimes = trial.stimuli.stimtimes
                self.rates = trial.stimuli.rates
            
        else:
            self.t = None
            self.x = None
            self.y = None
            self.a = None
            self.v = None
            self.tvid = None    
    def angleUnwrapper(self):
        jumpThresh=150
        angles=[]
        angle_offset=0
        for k, angle in enumerate(self.a):
            if k == 0:
                angles.append(angle)
                continue
            angle += angle_offset
            if angles[-1]-angle > jumpThresh:
                angle_offset += 180
                angle += 180
            elif angle-angles[-1] > jumpThresh:
                angle_offset -= 180
                angle -= 180
            angles.append(angle)
        self.a = np.array(angles)
    def velocity(self):
        x1 = self.x
        y1 = self.y
        a1 = self.a
        x2 = shift(x1,-1,cval=np.NaN)
        y2 = shift(y1,-1,cval=np.NaN)
        a2 = shift(a1,-1,cval=np.NaN)
        # Calculate velocity
        dist = (((x2-x1)**2)+((y2-y1)**2))**0.5
        self.v = dist[:-2]
        #
        vel_x = x2-x1
        self.vx = vel_x[:-2]
        vel_y = y2-y1
        self.vy = vel_y[:-2]
        # Calculate angle of velocity
        velocity_angle = np.rad2deg(np.arctan2((y2-y1),(x2-x1)))
        #fly_angle = self.a%(360)
        #angle_difference = velocity_angle-fly_angle
        #forward_component = (np.cos(angle_difference*np.pi/180))
        #self.vf = forward_component[:-2]
        self.va = velocity_angle[:-2]
        # Calculate angular velocity
        angular_velocity = a2-a1
        self.av = angular_velocity[:-2]

# %%
# output is meters per time point (which is 10ms)
# so * 100, then in m/sec. to get to cm/sec, need *100*100

# %%
###################
### BUILD FLIES ###
###################

flies = [Fly(trial,sigma=10) for trial in trials]

# %%
################################################
### Assign fly types based on visual stimuli ###
################################################

for fly in flies:
    if fly.stimdict['name'] == 'ConstantBackground' and fly.stimdict['background'] == '0.0':
        fly.type = 'dark'
    elif fly.stimdict['name'] == 'ConstantBackground' and fly.stimdict['background'] == '0.5':
        fly.type = 'grey'
    elif fly.stimdict['name'] == 'ConstantBackground' and fly.stimdict['background'] == '1.0':
        fly.type = 'bright'
    elif fly.stimdict['name'] == 'SineGrating' and fly.stimdict['angle'] == '0':
        fly.type = 'vertical'
    elif fly.stimdict['name'] == 'SineGrating' and fly.stimdict['angle'] == '90':
        fly.type = 'horizontal'
    elif fly.stimdict['name'] == 'RandomGrid':
        fly.type = 'checker'
    else:
        print('Did not assign type to fly with stimuli name: {}'.format(fly.stimdict['name']))

# %%
types
# Out:
# ['vertical', 'horizontal', 'checker', 'dark', 'grey', 'bright']

# %%
############
### Plot ###
############

fig = plt.figure(figsize=(10, 10))

types = ['vertical', 'horizontal', 'checker', 'dark', 'grey', 'bright']
bins = np.ndarray.tolist(np.arange(-3,3,.1))
behavior = 'dRotLabY'

for i, type in enumerate(['dark']):
    for k, fly in enumerate(flies):
        if fly.x is not None and fly.y is not None:
            if fly.type == type:
                vector = fly.av
                weights = np.ones_like(vector)/float(len(vector))
                binned,throwaway,throwaway2=plt.hist(vector,bins,weights=weights,label = str(i),stacked=True, histtype = 'step',linewidth=3)
    

#plt.title('Visual Stimuli')
#plt.xlim(0,5)
#plt.ylim(0,.25)
plt.xlabel('Velocity (rad/sec)')
plt.ylabel('Frequency, Normalized')
#plt.plot(0.32405,0.3207,'ko',markersize=10)
plt.show()

# %%
############
### Plot ###
############

fig = plt.figure(figsize=(10, 10))

types = ['vertical', 'horizontal', 'checker', 'dark', 'grey', 'bright']
bins = np.ndarray.tolist(np.arange(-3,3,.1))
behavior = 'dRotLabY'

for i, type in enumerate(['dark']):
    for k, fly in enumerate(flies):
        if fly.x is not None and fly.y is not None:
            if fly.type == type:
                vector = fly.av
                weights = np.ones_like(vector)/float(len(vector))
                binned,throwaway,throwaway2=plt.hist(vector,bins,weights=weights,label = str(i),stacked=True, histtype = 'step',linewidth=3)
    

#plt.title('Visual Stimuli')
#plt.xlim(0,5)
#plt.ylim(0,.25)
plt.xlabel('Velocity (rad/sec)')
plt.ylabel('Frequency, Normalized')
#plt.plot(0.32405,0.3207,'ko',markersize=10)
plt.show()

# %%
bins = np.ndarray.tolist(np.arange(-500,500,10))
fig = plt.figure(figsize=(10,10))
behavior = 'dRotLabZ'
sphere_radius = 4.5e-3 #3.175e-3 #
binned_data = []
for i in range(len(fictracs)):
    vector = np.rad2deg(fictracs[i][behavior]) # now in deg per 20ms
    vector = vector * 50 # now in deg per sec
    weights = np.ones_like(vector)/float(len(vector))
    binned,throwaway,throwaway2=plt.hist(vector,bins,weights=weights,label = str(i),stacked=True, linewidth=3,histtype = 'step')
    binned_data.append(binned)
# Out:
# 185
