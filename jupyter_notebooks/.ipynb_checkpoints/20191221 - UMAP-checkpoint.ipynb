# %%
import numpy as np
import time
import os
import sys
import scipy
import math
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from scipy.interpolate import interp1d
import pandas as pd
import psutil
import json
from tqdm import tqdm
sys.path.insert(0, '/home/users/brezovec/.local/lib/python3.6/site-packages/lib/python/')
import ants
import bigbadbrain as bbb
from scipy.linalg import toeplitz
import scipy.linalg as sl
from scipy.signal import convolve2d
from scipy.signal import convolve
import sklearn
from sklearn.linear_model import LassoLarsIC
from sklearn.linear_model import LinearRegression
from sklearn.decomposition import PCA
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LassoCV
from sklearn.model_selection import KFold
from sklearn.feature_selection import RFE
from sklearn import linear_model

from skimage.filters import threshold_triangle
sys.path.insert(0, '/home/users/brezovec/.local/lib/python3.6/site-packages')
import os
import statsmodels.api as sm

from matplotlib.animation import FuncAnimation
from matplotlib import animation, rc
from IPython.display import HTML
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline

# %%
from matplotlib.patches import FancyArrowPatch
from mpl_toolkits.mplot3d import proj3d

class Arrow3D(FancyArrowPatch):
    def __init__(self, xs, ys, zs, *args, **kwargs):
        FancyArrowPatch.__init__(self, (0,0), (0,0), *args, **kwargs)
        self._verts3d = xs, ys, zs

    def draw(self, renderer):
        xs3d, ys3d, zs3d = self._verts3d
        xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
        self.set_positions((xs[0],ys[0]),(xs[1],ys[1]))
        FancyArrowPatch.draw(self, renderer)

# %% [markdown]
# # UMAP

# %%
import umap

# %%
directory = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20190101_walking_dataset/fly_19/func_0'

# %%
t0 = time.time()
save_file = os.path.join(directory, 'pca', 'loadings_(temporal).npy')
pca_loadings = np.load(save_file)
print('Duration: {}'.format(time.time()-t0))
# Out:
# Duration: 0.07274198532104492

# %% [markdown]
# ### UMAP PARAMETERS:
# - n_neighbors: bigger for better large scale features (but could hurt small scale)
# - min_dist: lower causes final output to be clumpier

# %%
t0 = time.time()
reducer = umap.UMAP(n_neighbors=10)
embedding = reducer.fit_transform(pca_loadings[:,:100])
print('Duration: {}'.format(time.time()-t0))
# Out:
# (4554, 2)

# %%
t0 = time.time()
reducer = umap.UMAP(n_neighbors=200,min_dist=0)
embedding = reducer.fit_transform(pca_loadings[:,:100])
print('Duration: {}'.format(time.time()-t0))

plt.figure(figsize=(10,10))
plt.plot(embedding[:,0],
         embedding[:,1],
         linestyle='None',
         color='k',
         marker='x')
#plt.ylim(-50,50)
#plt.xlim(-50,50)
# Out:
# Duration: 38.98444962501526

# %%
t0 = time.time()
reducer = umap.UMAP(n_neighbors=60,min_dist=0)
embedding = reducer.fit_transform(pca_loadings[:,:100])
print('Duration: {}'.format(time.time()-t0))

plt.figure(figsize=(10,10))
plt.plot(embedding[:,0],
         embedding[:,1],
         linestyle='None',
         color='k',
         marker='x')
#plt.ylim(-50,50)
#plt.xlim(-50,50)
# Out:
# Duration: 25.308186531066895

# %%
t0 = time.time()
reducer = umap.UMAP(n_neighbors=100,min_dist=0,n_components=2)
embedding = reducer.fit_transform(pca_loadings[:,:10])
print('Duration: {}'.format(time.time()-t0))

plt.figure(figsize=(10,10))
plt.plot(embedding[:,0],
         embedding[:,1],
         linestyle='None',
         color='k',
         marker='x')
#plt.ylim(-50,50)
#plt.xlim(-50,50)
# Out:
# Duration: 25.510315418243408

# %%
# %matplotlib inline

# %%
# best: n_neighbors=60,min_dist=0,10PCs

# %%
t0 = time.time()
reducer = umap.UMAP(n_neighbors=60,min_dist=0,n_components=3)
X = reducer.fit_transform(pca_loadings[:,:10])
print('Duration: {}'.format(time.time()-t0))
# Out:
# Duration: 29.322498083114624

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], X[:,2],marker='o',s=1,color='k',alpha=0.25)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], X[:,2],marker='o',s=1,zorder=1,color='k',alpha=0.25)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
#ax.scatter(X[:,0], X[:,1], X[:,2],marker='o',s=1,zorder=1,color='k',alpha=0.25)
for i in range(X.shape[0]-1):
    a = Arrow3D(X[i:i+2,0],X[i:i+2,1],X[i:i+2,2],
                mutation_scale=12,lw=1,arrowstyle="-|>",
                color='k',alpha=.1)
    ax.add_artist(a)
plt.axis('off')

window = 2.5
center = np.mean(X,axis=0)
ax.set_xlim(center[0]-window,center[0]+window)
ax.set_ylim(center[1]-window,center[1]+window)
ax.set_zlim(center[2]-window,center[2]+window)
# Out:
# (0.09998798370361328, 5.099987983703613)

# %% [markdown]
# # Cluster

# %%
import hdbscan

# %%
lines4cluster = []
for i in range(X.shape[0]-1):
    lines4cluster.append(tuple(X[i:i+2,0]) + tuple(X[i:i+2,1]) + tuple(X[i:i+2,2]))
lines4cluster = np.asarray(lines4cluster)

# %%
for i in range(1,10,1):
    for j in range(30,60,5):
        min_cluster_size=10
        min_samples=j
        cluster_selection_epsilon=1/i

        t0 = time.time()
        lines_clustered = hdbscan.HDBSCAN(min_cluster_size=min_cluster_size,
                                            min_samples=min_samples,
                                            cluster_selection_epsilon=cluster_selection_epsilon,
                                            cluster_selection_method='leaf').fit(lines4cluster)
        lines_clustered.labels_ += 1
        labels = lines_clustered.labels_
        num_zeros = len(np.where(lines_clustered.labels_ == 0)[0])
        num_points = len(lines_clustered.labels_)
        
        print('i:{};j:{};{} clusters. {:0.0f}% timepoints in a cluster.'.format(i,j,
            max(lines_clustered.labels_),num_zeros/num_points*100))
        #print('{:0.0f}% timepoints in a cluster.'.format(num_zeros/num_points*100))
# Out:
# i:1;j:30;9 clusters. 32% timepoints in a cluster.
# i:1;j:35;10 clusters. 34% timepoints in a cluster.
# i:1;j:40;11 clusters. 38% timepoints in a cluster.
# i:1;j:45;10 clusters. 39% timepoints in a cluster.
# i:1;j:50;8 clusters. 41% timepoints in a cluster.
# i:1;j:55;9 clusters. 45% timepoints in a cluster.
# i:2;j:30;28 clusters. 66% timepoints in a cluster.
# i:2;j:35;25 clusters. 66% timepoints in a cluster.
# i:2;j:40;21 clusters. 64% timepoints in a cluster.
# i:2;j:45;18 clusters. 62% timepoints in a cluster.
# i:2;j:50;16 clusters. 65% timepoints in a cluster.
# i:2;j:55;16 clusters. 66% timepoints in a cluster.
# i:3;j:30;28 clusters. 66% timepoints in a cluster.
# i:3;j:35;25 clusters. 66% timepoints in a cluster.
# i:3;j:40;21 clusters. 64% timepoints in a cluster.
# i:3;j:45;18 clusters. 62% timepoints in a cluster.
# i:3;j:50;16 clusters. 65% timepoints in a cluster.
# i:3;j:55;16 clusters. 66% timepoints in a cluster.
# i:4;j:30;28 clusters. 66% timepoints in a cluster.
# i:4;j:35;25 clusters. 66% timepoints in a cluster.
# i:4;j:40;21 clusters. 64% timepoints in a cluster.
# i:4;j:45;18 clusters. 62% timepoints in a cluster.
# i:4;j:50;16 clusters. 65% timepoints in a cluster.
# i:4;j:55;16 clusters. 66% timepoints in a cluster.
# i:5;j:30;28 clusters. 66% timepoints in a cluster.
# i:5;j:35;25 clusters. 66% timepoints in a cluster.
# i:5;j:40;21 clusters. 64% timepoints in a cluster.
# i:5;j:45;18 clusters. 62% timepoints in a cluster.
# i:5;j:50;16 clusters. 65% timepoints in a cluster.
# i:5;j:55;16 clusters. 66% timepoints in a cluster.
# i:6;j:30;28 clusters. 66% timepoints in a cluster.
# i:6;j:35;25 clusters. 66% timepoints in a cluster.
# i:6;j:40;21 clusters. 64% timepoints in a cluster.
# i:6;j:45;18 clusters. 62% timepoints in a cluster.
# i:6;j:50;16 clusters. 65% timepoints in a cluster.
# i:6;j:55;16 clusters. 66% timepoints in a cluster.
# i:7;j:30;28 clusters. 66% timepoints in a cluster.
# i:7;j:35;25 clusters. 66% timepoints in a cluster.
# i:7;j:40;21 clusters. 64% timepoints in a cluster.
# i:7;j:45;18 clusters. 62% timepoints in a cluster.
# i:7;j:50;16 clusters. 65% timepoints in a cluster.
# i:7;j:55;16 clusters. 66% timepoints in a cluster.
# i:8;j:30;28 clusters. 66% timepoints in a cluster.
# i:8;j:35;25 clusters. 66% timepoints in a cluster.
# i:8;j:40;21 clusters. 64% timepoints in a cluster.
# i:8;j:45;18 clusters. 62% timepoints in a cluster.
# i:8;j:50;16 clusters. 65% timepoints in a cluster.
# i:8;j:55;16 clusters. 66% timepoints in a cluster.
# i:9;j:30;28 clusters. 66% timepoints in a cluster.
# i:9;j:35;25 clusters. 66% timepoints in a cluster.
# i:9;j:40;21 clusters. 64% timepoints in a cluster.
# i:9;j:45;18 clusters. 62% timepoints in a cluster.
# i:9;j:50;16 clusters. 65% timepoints in a cluster.
# i:9;j:55;16 clusters. 66% timepoints in a cluster.

# %%
min_cluster_size=10
min_samples=30
cluster_selection_epsilon=.5

t0 = time.time()
lines_clustered = hdbscan.HDBSCAN(min_cluster_size=min_cluster_size,
                                    min_samples=min_samples,
                                    cluster_selection_epsilon=cluster_selection_epsilon,
                                    cluster_selection_method='leaf').fit(lines4cluster)
lines_clustered.labels_ += 1
labels = lines_clustered.labels_
num_zeros = len(np.where(lines_clustered.labels_ == 0)[0])
num_points = len(lines_clustered.labels_)

print('{} clusters. {:0.0f}% timepoints in a cluster.'.format(
    max(lines_clustered.labels_),num_zeros/num_points*100))
#print('{:0.0f}% timepoints in a cluster.'.format(num_zeros/num_points*100))
# Out:
# 27 clusters. 65% timepoints in a cluster.

# %%
min_cluster_size=10
min_samples=50
cluster_selection_epsilon=.5

t0 = time.time()
lines_clustered = hdbscan.HDBSCAN(min_cluster_size=min_cluster_size,
                                    min_samples=min_samples,
                                    cluster_selection_epsilon=cluster_selection_epsilon,
                                    cluster_selection_method='leaf').fit(lines4cluster)
lines_clustered.labels_ += 1
labels = lines_clustered.labels_
num_zeros = len(np.where(lines_clustered.labels_ == 0)[0])
num_points = len(lines_clustered.labels_)

print('i:{};j:{};{} clusters. {:0.0f}% timepoints in a cluster.'.format(i,j,
    max(lines_clustered.labels_),num_zeros/num_points*100))
#print('{:0.0f}% timepoints in a cluster.'.format(num_zeros/num_points*100))
# Out:
# i:4552;j:55;16 clusters. 65% timepoints in a cluster.

# %%
colors = ['#e6194b', '#3cb44b', '#ffe119', '#4363d8', '#f58231',
          '#911eb4', '#46f0f0', '#f032e6', '#bcf60c', '#fabebe',
          '#008080', '#e6beff', '#9a6324', '#fffac8', '#800000',
          '#aaffc3', '#808000', '#ffd8b1', '#000075', '#808080',
          '#000000']

# %%
save_path = os.path.join(directory,'tsne','videos','20191221_0')
#os.mkdir(save_path)
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
#ax.scatter(X[:,0], X[:,1], X[:,2],marker='o',s=1,zorder=1,color='k',alpha=0.25)
for i in range(X.shape[0]-1):
    if labels[i] == 0:
        alpha = .1
        color='#000000'
    else:
        alpha = 1
        color=colors[labels[i]%len(colors)]
    a = Arrow3D(X[i:i+2,0],X[i:i+2,1],X[i:i+2,2],
                mutation_scale=6,lw=0.25,arrowstyle="-|>",
                color=color,alpha=alpha)
    ax.add_artist(a)
    #ax.plot(X[i:i+2,0],
    #        X[i:i+2,1],
    #        X[i:i+2,2],
    #         alpha=alpha,
    #         lw=1,
    #         #solid_capstyle='butt',
    #         c=colors[lines_clustered.labels_[i]%len(colors)],
    #         zorder=0)
window = 2.5
center = np.mean(X,axis=0)
ax.set_xlim(center[0]-window,center[0]+window)
ax.set_ylim(center[1]-window,center[1]+window)
ax.set_zlim(center[2]-window,center[2]+window)
ax.margins(x=0, y=0)
#ax.set_proj_type('ortho')
plt.axis('off')
ax.view_init(15,0)

# for k,angle in enumerate(range(263,360)):
#     print(angle)
#     ax.view_init(0,angle)
#     fname = os.path.join(save_path, '{0:05d}.png'.format(k))
#     plt.savefig(fname,dpi=300,bbox_inches='tight')
# Out:
# (4554, 3)

# %%
save_path = os.path.join(directory,'tsne','videos','20191222_0')
os.mkdir(save_path)
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
#ax.scatter(X[:,0], X[:,1], X[:,2],marker='o',s=1,zorder=1,color='k',alpha=0.25)
for i in range(X.shape[0]-1):
    if labels[i] == 0:
        alpha = 0
        color='#000000'
    else:
        alpha = 1
        color=colors[labels[i]%len(colors)]
    a = Arrow3D(X[i:i+2,0],X[i:i+2,1],X[i:i+2,2],
                mutation_scale=6,lw=0.25,arrowstyle="-|>",
                color=color,alpha=alpha)
    ax.add_artist(a)
    #ax.plot(X[i:i+2,0],
    #        X[i:i+2,1],
    #        X[i:i+2,2],
    #         alpha=alpha,
    #         lw=1,
    #         #solid_capstyle='butt',
    #         c=colors[lines_clustered.labels_[i]%len(colors)],
    #         zorder=0)
window = 2.5
center = np.mean(X,axis=0)
ax.set_xlim(center[0]-window,center[0]+window)
ax.set_ylim(center[1]-window,center[1]+window)
ax.set_zlim(center[2]-window,center[2]+window)
ax.margins(x=0, y=0)
#ax.set_proj_type('ortho')
plt.axis('off')
ax.view_init(15,0)

for k,angle in enumerate(range(360)):
    print(angle)
    ax.view_init(0,angle)
    fname = os.path.join(save_path, '{0:05d}.png'.format(k))
    plt.savefig(fname,dpi=300,bbox_inches='tight')
# Out:
# 0
