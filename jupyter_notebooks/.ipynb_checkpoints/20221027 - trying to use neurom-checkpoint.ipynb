# %%
import neurom as nm
import os

# %%
import numpy as np
file = "/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20220624_supervoxels_in_FDA/20221028_nblast_hemibrain.csv"
data = np.genfromtxt(file)

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_csv(file)

# %%
data = np.asarray(df)

# %%
data.shape
# Out:
# (25625, 25626)

# %%
ids = data[:,0]
nblast = data[:,1:]
nblast.shape
# Out:
# (25625, 25625)

# %%
save_file = "/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20220624_supervoxels_in_FDA/20221028_nblast_hemibrain.npy"
np.save(save_file,nblast)

# %%
save_file = "/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20220624_supervoxels_in_FDA/20221028_nblast_hemibrain_ids.npy"
np.save(save_file,ids)

# %%
plt.imshow(nblast)
plt.show()

# %%
nblast[100,100]
# Out:
# 1.0

# %%
connectome_dir = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20220624_supervoxels_in_FDA'
file = os.path.join(connectome_dir, '203257652.swc')

# %%
m = nm.load_morphology(file)
# Out:
# ---------------------------------------------------------------------------
# RawDataError                              Traceback (most recent call last)
# /tmp/ipykernel_17256/957330142.py in <module>
# ----> 1 m = nm.load_morphology(file)
#
# ~/projects/NeuroM/neurom/io/utils.py in load_morphology(morph, reader)
#     163         return Morphology(_get_file(morph, reader))
#     164
# --> 165     return Morphology(morph, Path(morph).name)
#     166
#     167
#
# ~/projects/NeuroM/neurom/core/morphology.py in __init__(self, filename, name)
#     433             name (str): a option morphology name
#     434         """
# --> 435         super().__init__(filename)
#     436         self.name = name if name else 'Morphology'
#     437         self.morphio_soma = super().soma
#
# RawDataError:
# /oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20220624_supervoxels_in_FDA/203257652.swc:4:error
# Unsupported section type: 0

# %%
from neurom import viewer
>>> fig, ax = viewer.draw(m)
>>> fig.show()
>>>
>>> fig, ax = viewer.draw(m, mode='3d') # valid modes '2d', '3d', 'dendrogram'
>>> fig.show()
