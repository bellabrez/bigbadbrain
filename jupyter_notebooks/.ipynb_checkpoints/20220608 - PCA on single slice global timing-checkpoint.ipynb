# %%
import numpy as np
from time import time
import os
import sys
import scipy
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
import pandas as pd
import psutil
from tqdm import tqdm
import ants
import nibabel as nib
from sklearn.decomposition import PCA
import brainsss
# %matplotlib inline

# %%
func_path = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20190101_walking_dataset/fly_087/func_0'

# %%
brainfile = os.path.join(func_path, 'brain_zscored_green_high_pass_masked.nii')

# %%
img = nib.load(file) # this loads a proxy
print(img.header.get_data_shape())
data = img.dataobj[:,:,20,:]
# Out:
# (256, 128, 49, 3384)

# %%
plt.imshow(data[:,:,2751],vmin=-1,vmax=1)

# %%
plt.imshow(data[:,:,1463],vmin=-1,vmax=1)

# %%
np.argmin(meanbrain)
# Out:
# 1463

# %%
meanbrain = np.mean(data,axis=(0,1))
meanbrain.shape

# %%
timestamps = brainsss.load_timestamps(os.path.join(func_path, 'imaging'))
# Out:
# Trying to load timestamp data from hdf5 file.
# Success.

# %%
timestamps[-1,20]
# Out:
# 1800020.536195

# %%
plt.plot(timestamps[:,20],meanbrain)

# %%
plt.plot(meanbrain[500:1000])

# %%
####################
### Prep Fictrac ###
####################

fictrac_path = os.path.join(func_path, 'fictrac')
fictrac_raw = brainsss.load_fictrac(fictrac_path)

fps = 50
resolution = 10 #desired resolution in ms
expt_len = fictrac_raw.shape[0]/fps*1000
behaviors = ['dRotLabY', 'dRotLabZ']
fictrac = {}
for behavior in behaviors:
    if behavior == 'dRotLabY': short = 'Y'
    elif behavior == 'dRotLabZ': short = 'Z'
    fictrac[short] = brainsss.smooth_and_interp_fictrac(fictrac_raw, fps, resolution, expt_len, behavior)
fictrac_timestamps = np.arange(0,expt_len,resolution)

# %%
movement = ((fictrac['Y']/np.std(fictrac['Y']))**2 + (fictrac['Z']/np.std(fictrac['Z']))**2)**.5

# %%
plt.figure(figsize=(10,10))
plt.plot(fictrac_timestamps/1000, movement)
plt.plot(timestamps[:,20]/1000,(meanbrain*40)+2)
plt.plot(timestamps[:,20]/1000, pca.components_[0,:]*40)

# %%
plt.figure(figsize=(10,10))
plt.plot(fictrac_timestamps/1000, movement)
plt.plot(timestamps[:,20]/1000,(meanbrain*40)+2,marker='x')
plt.plot(timestamps[:,20]/1000, (pca.components_[0,:]*60)+1,marker='x')
shift = 0
plt.xlim(shift,shift+100)
# Out:
# (0, 100)

# %%
plt.figure(figsize=(10,10))
plt.plot(fictrac_timestamps/1000, movement)
#plt.plot(timestamps[:,20]/1000,(meanbrain*40)+2,marker='x')
plt.plot(timestamps[:,20]/1000, (pca.components_[0,:]*60)+1,marker='x')
shift = 100
plt.xlim(shift,shift+100)
# Out:
# (100, 200)

# %%
plt.figure(figsize=(10,10))
plt.plot(fictrac_timestamps/1000, fictrac['Y'])
plt.plot(timestamps[:,20]/1000,meanbrain*100)
plt.xlim(500,750)
# Out:
# (500, 750)

# %%
plt.figure(figsize=(10,10))
plt.plot(fictrac_timestamps/1000, fictrac['Y'])
plt.plot(timestamps[:,20]/1000,(meanbrain*100)+10,marker='x')
plt.xlim(1150,1200)
# Out:
# (1150, 1200)

# %%
X = brain[:,:,25,:].reshape(-1,brain.shape[-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-c482eb47783f> in <module>()
# ----> 1 X = brain[:,:,25,:].reshape(-1,brain.shape[-1])
#
# NameError: name 'brain' is not defined

# %%
t0 = time()
pca = PCA(n_components=10).fit(X.T)
print(time()-t0)
# Out:
# 4.153245449066162

# %%
out = np.reshape(pca.components_, (10,dims['y'],dims['x']))

# %%
data_flat = np.reshape(data,(256*128,3384))
data.shape, data_flat.shape
# Out:
# ((256, 128, 3384), (32768, 3384))

# %%
pca = PCA(n_components=10).fit(data_flat)

# %%
pca.components_.shape
# Out:
# (10, 3384)

# %%
plt.plot(pca.components_[0,:])

# %%
out = np.reshape(pca.components_, (10,256,128))

# %%
out.shape
# Out:
# (10, 256, 128)

# %%
plt.imshow(out[0,:,:].T)
