# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import ants
import nibabel as nib
from time import time
from xml.etree import ElementTree as ET
import os
import pandas as pd
import sys
from scipy.interpolate import interp1d
from scipy.ndimage.filters import gaussian_filter
from scipy import signal

sys.path.insert(0, '/home/users/brezovec/projects/lysis/')
from bruker import *

# %matplotlib inline

# %%
def load_brain(file):
    brain = nib.load(file).get_data()
    brain = np.swapaxes(brain, 0, 1)
    brain = ants.from_numpy(brain)
    return brain

def rotate_brain(brain):
    if type(brain) is not np.ndarray:
        brain = brain.numpy()
    brain = np.swapaxes(brain, 0, 1)
    brain = ants.from_numpy(brain)
    return brain

# %%
brain_files = ['/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20181127/fly1/TSeries-11272018-1436-000.nii',
               '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20181214/fly1/TSeries-12142018-1527-001.nii',
               '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20181214/fly2/TSeries-12142018-1527-000.nii',
               '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20181217/fly1/TSeries-12172018-1322-000.nii',
               '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20181217/fly2/TSeries-12172018-1322-001_green.nii']

# %%
brains = []

for i, brain_file in enumerate(brain_files):
    print("loading brain", i+1)
    brain = load_brain(brain_file)
    brains.append(brain)
# Out:
# loading brain 1
# loading brain 2
# loading brain 3
# loading brain 4
# loading brain 5

# %%
meanbrains = []

for i, brain in enumerate(brains):
    print("averaging brain", i+1)
    meanbrain = brain.mean(3)
    meanbrain = ants.from_numpy(meanbrain)
    meanbrains.append(meanbrain)
# Out:
# averaging brain 1
# averaging brain 2
# averaging brain 3
# averaging brain 4
# averaging brain 5

# %%
fig = plt.figure(figsize=(15,10))

for i, brain in enumerate(meanbrains):
    plt.subplot(1, len(meanbrains), i+1)
    plt.imshow(brain[:,:,20])

# %%
fig = plt.figure(figsize=(10,10))
plt.imshow(meanbrains[2][:,:,40])

# %%
fig = plt.figure(figsize=(10,10))
plt.imshow(meanbrains[4][:,:,34])

# %%
### lets align everything to meanbrain[4]

# %%
warps = []

for brain in meanbrains:
    t0 = time()
    motCorr = ants.registration(meanbrains[4],
                                brain,
                                type_of_transform='Similarity',
                                verbose=True,
                                grad_step = 0.2,
                                flow_sigma=3,
                                total_sigma=0,
                                reg_interations=(40,20,0))
    print(time()-t0)
    warped = motCorr['warpedmovout'].numpy()
    warps.append(warped)
    #warped_fixed = motCorr['warpedfixout'].numpy()
# Out:
# 1.3080596923828125
# 1.5195586681365967
# 1.6546523571014404
# 1.587204933166504
# 2.0531721115112305

# %%
warps_r = []

for brain in warps:
    brain_r = rotate_brain(brain)
    warps_r.append(brain_r)

# %%
for i, brain in enumerate(warps_r):
    save_file = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/warps2/warp' + str(i) + '.nii'
    ants.image_write(brain, save_file)

# %%
fig = plt.figure(figsize=(10,10))
plt.imshow(warped[:,:,34])

# %%
fig = plt.figure(figsize=(10,10))
plt.imshow(warps[2][:,:,34])

# %%
warp_cat = np.stack(warps)

# %%
warp_cat.shape
# Out:
# (5, 88, 128, 55)

# %%
warp_mean = np.mean(warp_cat, axis = 0)

# %%
fig = plt.figure(figsize=(10,10))
plt.imshow(warp_mean[:,:,25])

# %%
warps_SyN = []

for brain in meanbrains:
    t0 = time()
    motCorr = ants.registration(warp_mean,
                                brain,
                                type_of_transform='SyNCC')
    print(time()-t0)
    warped = motCorr['warpedmovout'].numpy()
    warps_SyN.append(warped)

# %%
warps_SyN = []

for brain in meanbrains:
    t0 = time()
    motCorr = ants.registration(warp_mean,
                                brain,
                                type_of_transform='SyNCC',
                                verbose=True,
                                grad_step = 0.2,
                                flow_sigma=3,
                                total_sigma=0,
                                reg_interations=(40,20,0))
    print(time()-t0)
    warped = motCorr['warpedmovout'].numpy()
    warps_SyN.append(warped)
# Out:
# 194.86069321632385
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-b6d0c83f096e> in <module>()
#      10                                 flow_sigma=3,
#      11                                 total_sigma=0,
# ---> 12                                 reg_interations=(40,20,0))
#      13     print(time()-t0)
#      14     warped = motCorr['warpedmovout'].numpy()
#
# ~/.local/lib/python3.6/site-packages/ants/registration/interface.py in registration(fixed, moving, type_of_transform, initial_transform, outprefix, mask, grad_step, flow_sigma, total_sigma, aff_metric, aff_sampling, syn_metric, syn_sampling, reg_iterations, verbose, **kwargs)
#     649                 processed_args = utils._int_antsProcessArguments(args)
#     650                 libfn = utils.get_lib_fn('antsRegistration')
# --> 651                 libfn(processed_args)
#     652                 afffns = glob.glob(outprefix+'*'+'[0-9]GenericAffine.mat')
#     653                 fwarpfns = glob.glob(outprefix+'*'+'[0-9]Warp.nii.gz')
#
# KeyboardInterrupt:

# %%
warp_mean = ants.from_numpy(warp_mean)
