# %%
import sys
sys.path.insert(0, '/home/users/brezovec/.local/lib/python3.6/site-packages/lib/python/')
import ants
import os
import bigbadbrain as bbb
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy
import nibabel as nib
import psutil
# %matplotlib inline

# %%
root_directory = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/imports/'

# %%
file = os.path.join(root_directory,'20200627','fly_1','anat_0','TSeries-06272020-0919-001','TSeries-06272020-0919-001_channel_1.nii')
brain = np.asarray(nib.load(file).dataobj[:,:,:,0:5], dtype='float32')

# %%
file = os.path.join(root_directory, '20200707_temp.nii')
meanbrain = np.asarray(nib.load(file).get_data(), dtype='float32')
meanbrain.shape
# Out:
# (1024, 512, 241)

# %%
plt.imshow(meanbrain[:,:,70].T)

# %%
master = ants.from_numpy(meanbrain)
slave = ants.from_numpy(brain[:,:,:,0])

# %%
t0 = time.time()
slave2master = ants.registration(master,slave,type_of_transform='SyN')
print(time.time()-t0)
# Out:
# 881.412202835083

# %%
881.412202835083/60
# Out:
# 14.690203380584716

# %%
memory_usage = psutil.Process(os.getpid()).memory_info().rss*10**-9
print('Current memory usage: {:.2f}GB'.format(memory_usage))
# Out:
# Current memory usage: 4.66GB
