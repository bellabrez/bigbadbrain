# %%
import sys
sys.path.insert(0, '/home/users/brezovec/.local/lib/python3.6/site-packages/lib/python/')
import ants
import os
import bigbadbrain as bbb
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy
from scipy.ndimage.filters import gaussian_filter
from scipy.signal import savgol_filter
from scipy.interpolate import interp1d

from skimage.filters import threshold_triangle
sys.path.insert(0, '/home/users/brezovec/.local/lib/python3.6/site-packages')
import os
import statsmodels.api as sm
import cv2
import matplotlib.patches as mpatches
import psutil
from mpl_toolkits.axes_grid1 import ImageGrid
from matplotlib.colors import Normalize
import matplotlib.colors as mcolors


# %matplotlib inline
plt.rcParams.update({'font.size': 12})

from sklearn.feature_extraction.image import grid_to_graph
from mpl_toolkits.axes_grid1 import ImageGrid
import json
from matplotlib.ticker import FuncFormatter

import nibabel as nib

from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram
import itertools
import random
from scipy.cluster import hierarchy
import matplotlib as mpl
from matplotlib.pyplot import cm

from scipy.interpolate import UnivariateSpline
from sklearn.linear_model import LinearRegression
import matplotlib.patches as patches

from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LassoCV

from scipy.fftpack import fft,fftshift,ifft

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.ndimage.filters import gaussian_filter1d

import os

# %%
save_file = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20210514_for_aws'
os.listdir(save_file)
# Out:
# ['X_all_neural.npy',
#  '6.npy',
#  '15.npy',
#  '9.npy',
#  '19.npy',
#  '0.npy',
#  '16.npy',
#  '31.npy',
#  '29.npy',
#  '28.npy',
#  '48.npy',
#  '4.npy',
#  '20210525_all_beh_time.npy',
#  '20210525_beh_interp_objs.npy',
#  '42.npy',
#  '33.npy',
#  '13.npy',
#  '34.npy',
#  '10.npy',
#  '2.npy',
#  '21.npy',
#  '20210525_beh_interp_obj.npy',
#  'X.npy',
#  '38.npy',
#  '45.npy',
#  '7.npy',
#  '5.npy',
#  '43.npy',
#  '27.npy',
#  '25.npy',
#  '24.npy',
#  '36.npy',
#  '35.npy',
#  '39.npy',
#  '46.npy',
#  '8.npy',
#  '40.npy',
#  '12.npy',
#  '30.npy',
#  '20210525_all_beh.npy',
#  '26.npy',
#  '18.npy',
#  '14.npy',
#  '32.npy',
#  'Y.npy',
#  '23.npy',
#  'X_timestamps.npy',
#  '17.npy',
#  '44.npy',
#  '20.npy',
#  '1.npy',
#  'X_all_neural_timestamps_z_t.npy',
#  'Y_behavior.npy',
#  '37.npy',
#  '3.npy',
#  '11.npy',
#  'X_all_neural_z_vox_t.npy',
#  '47.npy',
#  '22.npy',
#  '41.npy']

# %%
load_file = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20210514_for_aws/Y.npy'
neural = np.load(load_file)
print(neural.shape)
plt.plot(neural)
# Out:
# (30456,)

# %%
load_file = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20210514_for_aws/X_all_neural_timestamps_z_t.npy'
neural_timestamps = np.load(load_file)
print(neural_timestamps.shape)
neural_timestamps = neural_timestamps[:,29]
print(neural_timestamps.shape)
plt.plot(neural_timestamps)
# Out:
# (30456, 49)
# (30456,)

# %%
load_file = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20210514_for_aws/20210525_all_beh.npy'
behavior = np.load(load_file)
behavior = np.clip(behavior,0,None)
behavior = np.nan_to_num(behavior)
print(behavior.shape)
plt.plot(behavior)
# Out:
# (810000,)

# %%
plt.hist(behavior,bins=100);

# %%
load_file = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20210514_for_aws/20210525_all_beh_time.npy'
behavior_timestamps = np.load(load_file)
print(behavior_timestamps.shape)
plt.plot(behavior_timestamps)
# Out:
# (810000,)

# %%
behavior_timestamps[-1], neural_timestamps[-1]
# Out:
# (16199980.0, 16200099.027364)

# %%
neural_interp_obj = interp1d(neural_timestamps, neural, bounds_error=False)
neural_upsampled = neural_interp_obj(behavior_timestamps)
neural_upsampled = np.nan_to_num(neural_upsampled)

# %%
plt.plot(neural_upsampled)

# %%
len(neural_upsampled), len(behavior)
# Out:
# (810000, 810000)

# %%
num_tp = len(behavior)
half_tp = int(num_tp/2)
width = 250
time_res = 20 #ms

# %%
behavior_norm = behavior - np.mean(behavior)

# %%
behavior_autocorr = scipy.signal.correlate(behavior_norm, behavior_norm, mode='same')

# %%
plt.plot(behavior_autocorr)
plt.xlim(half_tp-width,half_tp+width)
plt.title('behavior auto-correlation')
# Out:
# Text(0.5, 1.0, 'behavior auto-correlation')

# %%
behneu_crosscorr = scipy.signal.correlate(behavior_norm, neural_upsampled, mode='same')

# %%
plt.plot(behneu_crosscorr)
plt.xlim(half_tp-width,half_tp+width)
plt.title('behavior-neural cross-correlation')
plt.axvline(half_tp,linestyle='--',color='k')

# %%
load_file = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20210514_for_aws/X.npy'
behavior_windows = np.load(load_file)
print(behavior_windows.shape)
plt.plot(behavior_windows[:,250])
# Out:
# (30456, 500)

# %%
neural.shape
# Out:
# (30456,)

# %%
neuwebeh_filter = np.dot(behavior_windows.T, neural)

# %%
plt.plot(neuwebeh_filter)
plt.axvline(250,linestyle='--',color='k')

# %% [markdown]
# # Wonderful. Now lets fft things and normalize

# %%
behavior_autocorr_window = behavior_autocorr[half_tp-width:half_tp+width]
plt.plot(behavior_autocorr_window)

# %%
behneu_crosscorr_window = behneu_crosscorr[half_tp-width:half_tp+width]
plt.plot(behneu_crosscorr_window)

# %%
plt.plot(behneu_crosscorr_window/np.max(behneu_crosscorr_window))
plt.plot(neuwebeh_filter/10)

# %%
kernel = ifft(fft(behneu_crosscorr_window)/(fft(behavior_autocorr_window)))
plt.plot(kernel)
# Out:
# /share/software/user/open/py-numpy/1.18.1_py36/lib/python3.6/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
# Out:
# 16200

# %%
SAMPLE_RATE = 50
DURATION = 16200 #sec
N = SAMPLE_RATE * DURATION
xf = scipy.fftpack.fftfreq(N, 1 / SAMPLE_RATE)
yf = fft(behavior_autocorr)

plt.figure(figsize=(10,10))
plt.plot(xf,np.abs(yf),'x')
plt.xlim(0,10)
plt.axvline(1/0.531995701,color='r',linestyle='--')
plt.title('fft of behavior-autocorr')
plt.xlabel('Hz')
plt.ylabel('power')
# Out:
# Text(0, 0.5, 'power')

# %%
SAMPLE_RATE = 50
DURATION = 16200 #sec
N = SAMPLE_RATE * DURATION
xf = scipy.fftpack.fftfreq(N, 1 / SAMPLE_RATE)
yf = fft(behneu_crosscorr)

plt.figure(figsize=(10,10))
plt.plot(xf,np.abs(yf),'x')
plt.xlim(0,10)
plt.axvline(1/0.531995701,color='r',linestyle='--')
plt.title('fft of behavior-autocorr')
plt.xlabel('Hz')
plt.ylabel('power')
# Out:
# Text(0, 0.5, 'power')

# %%
SAMPLE_RATE = 50
DURATION = 10 #sec
N = SAMPLE_RATE * DURATION
xf = scipy.fftpack.fftfreq(N, 1 / SAMPLE_RATE)
yf = fft(behavior_autocorr_window)

plt.figure(figsize=(10,10))
plt.plot(xf,np.abs(yf),'x')
plt.xlim(0,10)
plt.axvline(1/0.531995701,color='r',linestyle='--')
plt.title('fft of behavior-autocorr')
plt.xlabel('Hz')
plt.ylabel('power')
# Out:
# Text(0, 0.5, 'power')

# %%
SAMPLE_RATE = 50
DURATION = 10 #sec
N = SAMPLE_RATE * DURATION
xf = scipy.fftpack.fftfreq(N, 1 / SAMPLE_RATE)
yf = fft(neuwebeh_filter)

plt.figure(figsize=(10,10))
plt.plot(xf,np.abs(yf),'x')
plt.xlim(0,10)
plt.axvline(1/0.531995701,color='r',linestyle='--')
plt.title('fft of behavior-neural-crosscorr')
plt.xlabel('Hz')
plt.ylabel('power')
# Out:
# Text(0, 0.5, 'power')

# %%
SAMPLE_RATE = 50
DURATION = 10 #sec
N = SAMPLE_RATE * DURATION
xf = scipy.fftpack.fftfreq(N, 1 / SAMPLE_RATE)
yf = fft(neuwebeh_filter)

plt.figure(figsize=(10,10))
plt.plot(xf,np.abs(yf),'x')
plt.xlim(0,10)
plt.axvline(1/0.531995701,color='r',linestyle='--')
plt.title('fft of behavior-neural-crosscorr')
plt.xlabel('Hz')
plt.ylabel('power')

# %%
ifft(yf)

# %% [markdown]
# # complex conjugate version

# %%
scipy.__version__
# Out:
# '1.4.1'

# %%
from scipy.fft import fft
from scipy.fft import ifft

# %%
len(behavior)
# Out:
# 810000

# %%
window = 500
beh_ = 0
for i in range(len(behavior)-window):
    beh = behavior[i:i+window]
    beh_ += fft(beh)*np.conj(fft(beh))

# %%
plt.plot(ifft(beh))
# Out:
# /share/software/user/open/py-numpy/1.18.1_py36/lib/python3.6/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
test = ifft(np.conj(fft(behavior))*fft(neural_upsampled))

# %%
test = ifft(np.conj(fft(behavior))*fft(behavior))

# %%
fft(behavior)
# Out:
# array([4511.72947533  -0.j        ,  589.0653008 +687.20147776j,
#        -727.87368004-758.17054851j, ..., -460.03397473+892.69372295j,
#        -727.87368004+758.17054851j,  589.0653008 -687.20147776j])

# %%
np.conj(fft(behavior))
# Out:
# array([4511.72947533  +0.j        ,  589.0653008 -687.20147776j,
#        -727.87368004+758.17054851j, ..., -460.03397473-892.69372295j,
#        -727.87368004-758.17054851j,  589.0653008 +687.20147776j])

# %%
plt.plot(np.conj(fft(behavior)))
# Out:
# /share/software/user/open/py-numpy/1.18.1_py36/lib/python3.6/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.plot(fft(behavior))
# Out:
# /share/software/user/open/py-numpy/1.18.1_py36/lib/python3.6/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.plot(test)
#plt.xlim(half_tp-width,half_tp+width)
# Out:
# /share/software/user/open/py-numpy/1.18.1_py36/lib/python3.6/site-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
len(behavior), len(neural_upsampled)
# Out:
# (810000, 810000)

# %%
plt.plot(behavior)

# %% [markdown]
# # deconvolve version

# %%
plt.plot(neuwebeh_filter)

# %%
plt.plot(behavior_autocorr_window)

# %%
toe = scipy.linalg.toeplitz(behavior_autocorr_window/90)
plt.imshow(toe)

# %%
deconv = np.linalg.lstsq(toe, neuwebeh_filter.T)[0]
# Out:
# /share/software/user/open/py-jupyter/1.0.0_py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(deconv)

# %%
deconv_smooth = gaussian_filter1d(deconv,sigma=3,axis=0)
plt.plot(deconv_smooth)
