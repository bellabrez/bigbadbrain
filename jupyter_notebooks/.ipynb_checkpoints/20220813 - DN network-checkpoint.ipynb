# %%
from neuprint import Client
from neuprint import NeuronCriteria as NC
from neuprint import fetch_neurons
from neuprint import fetch_adjacencies
from neuprint.utils import connection_table_to_matrix
import bokeh.palettes
from bokeh.plotting import figure, show, output_notebook
output_notebook()
import hvplot.pandas
import holoviews as hv
import numpy as np
import pandas as pd
import ants
import nibabel as nib
import os
import pickle
import scipy
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import networkx as nx
from fa2 import ForceAtlas2
from nxviz import CircosPlot
import nxviz as nv
import tqdm
import time
from scipy.ndimage.morphology import binary_erosion
from scipy.ndimage.morphology import binary_dilation
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1003">Loading BokehJS ...</span>
#     </div>

# %%
connectome_dir = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20220624_supervoxels_in_FDA'

# %%
############################
### load behavior scores ###
############################

unique_crop = np.load(os.path.join(connectome_dir, 'unique_glm_in_hemibrain.npy'))

behavior = []
for beh in [0,1,2]:
    unique_crop_thresh = unique_crop[...,beh].copy()
    unique_crop_thresh[unique_crop[...,beh]>=.01] = 1
    unique_crop_thresh[unique_crop[...,beh]<.01] = np.nan
    behavior.append(unique_crop_thresh==1)

# %%
#############################
### load synapses and ids ###
#############################

file = os.path.join(connectome_dir,'hemibrain_all_neurons_synapses_polypre_centrifugal_synapses.pickle')
file = open(file, 'rb')
synapses = pickle.load(file)
cell_ids = np.unique(synapses['bodyid'])

# %%
#########################
### load cells in FDA ###
#########################

load_file = os.path.join(connectome_dir, 'synpervox.npy')
synpervox = np.load(load_file)

# %%
#########################
### connect to server ###
#########################

TOKEN = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6ImJyZXpvdmVjQHN0YW5mb3JkLmVkdSIsImxldmVsIjoibm9hdXRoIiwiaW1hZ2UtdXJsIjoiaHR0cHM6Ly9saDMuZ29vZ2xldXNlcmNvbnRlbnQuY29tL2EvQUl0YnZtbkRZbDlFVjYtZDhEZW5ueVUyZGNsVEtSQUYteGNXdHMtaWhQTjk9czk2LWM_c3o9NTA_c3o9NTAiLCJleHAiOjE4Mzg3ODI1NzF9.3LC0zWwmVC8RfbPZqrHz02MXk1RvbYP4ZIf6ygejh6E" # <--- Paste your token here
c = Client('neuprint.janelia.org', 'hemibrain:v1.2.1', TOKEN)

# %%
#################
### load dice ###
#################

file = os.path.join(connectome_dir, 'all_neuron_dice.npy')
all_neuron_dice = np.load(file)
all_neuron_dice.shape
# Out:
# (24691, 3)

# %%
criteria = NC(type=['DNa.*', 'DNb.*', 'DNd.*', 'DNg.*', 'DNp.*', 'DNES.*', 'Giant_Fiber', 'MDN'])
neuron_df, roi_counts_df = fetch_neurons(criteria)
print(len(neuron_df['bodyId']))
DN_ids = list(neuron_df['bodyId'])
# Out:
# 102

# %%
# get list of cell ids that synapse onto DNs
neuron_df, conn_df = fetch_adjacencies(None,NC(bodyId=DN_ids));
DN_partners_pre = list(neuron_df['bodyId'])

# get list of cell ids that DNs synapse onto
neuron_df, conn_df = fetch_adjacencies(NC(bodyId=DN_ids),None);
DN_partners_post = list(neuron_df['bodyId'])
# Out:
# hi!
#        bodyId_pre  bodyId_post  weight  \
# 0      7112625374   5813020512       1
# 1      5901223691   5813020512       2
# 2      7112616299   5813020512       1
# 3      5901195270   5813020512       1
# 4      5901118401   5813020512       1
# ...           ...          ...     ...
# 36400  1379644459   1655626125       1
# 36401  1353375816   1655626125       1
# 36402  1222592470   1655626125       2
# 36403  1191500957   1655626125       1
# 36404   861242327   1655626125       1
#
#                                                  roiInfo
# 0      {'VMNP': {'pre': 1, 'post': 1}, 'IPS(R)': {'pr...
# 1      {'VMNP': {'pre': 2, 'post': 2}, 'SPS(R)': {'pr...
# 2      {'VMNP': {'pre': 1, 'post': 1}, 'IPS(R)': {'pr...
# 3                         {'GNG': {'pre': 1, 'post': 1}}
# 4                         {'GNG': {'pre': 1, 'post': 1}}
# ...                                                  ...
# 36400  {'VMNP': {'pre': 1, 'post': 1}, 'IPS(R)': {'pr...
# ...

# %%
DN_network_cell_ids = np.unique(DN_partners_pre + DN_partners_post + DN_ids)

# %%
DN_network_cell_ids = np.unique(list(dn2_partners) + list(dn4_partners) + [1140245595, 1262014782])

# %%
len(DN_network_cell_ids)
# Out:
# 35

# %%
neuron_df, conn_df = fetch_adjacencies(NC(bodyId=DN_network_cell_ids),NC(bodyId=DN_network_cell_ids));
matrix = connection_table_to_matrix(conn_df, 'bodyId', sort_by='bodyId');
# Out:
# hi!
#      bodyId_pre  bodyId_post  weight  \
# 0    1220416666   1783915068       1
# 1    1220416666   5813054141       2
# 2    1220416666   5813050791       3
# 3    1220416666    861937730       1
# 4    1220416666   1383111671       2
# ..          ...          ...     ...
# 509  1783915068   1908356254      48
# 510  1783915068   1139909038      42
# 511  1783915068   1140245595     166
# 512  1783915068   1140923511      71
# 513  1783915068   5813042961      21
#
#                                                roiInfo
# 0    {'VMNP': {'pre': 1, 'post': 1}, 'VES(R)': {'pr...
# 1    {'VMNP': {'pre': 1, 'post': 1}, 'VES(R)': {'pr...
# 2    {'VMNP': {'pre': 3, 'post': 3}, 'VES(R)': {'pr...
# 3    {'VMNP': {'pre': 1, 'post': 1}, 'VES(R)': {'pr...
# 4    {'VMNP': {'pre': 2, 'post': 2}, 'VES(R)': {'pr...
# ..                                                 ...
# 509  {'VLNP(R)': {'pre': 11, 'post': 11}, 'WED(R)':...
# 510  {'VLNP(R)': {'pre': 9, 'post': 9}, 'WED(R)': {...
# ...

# %%
# ## the output matrix is often missing cells between axes

# for cell in matrix.columns:
#     if cell not in matrix.index:
#         matrix = matrix.drop(axis=1,labels=cell)
        
# for cell in matrix.index:
#     if cell not in matrix.columns:
#         matrix = matrix.drop(axis=0,labels=cell)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-a9f290d8118c> in <module>()
#       7 for cell in matrix.index:
#       8     if cell not in matrix.columns:
# ----> 9         matrix = matrix.drop(axis=0,labels=cell)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...

# %%
intersect_cells = np.intersect1d(list(matrix.columns), list(matrix.index))
all_cells = np.unique(list(matrix.columns) + list(matrix.index))
to_remove = [i for i in all_cells if i not in intersect_cells]

# %%
matrix = matrix.drop(axis=0, labels=to_remove)
matrix = matrix.drop(axis=1, labels=to_remove)

# %%
DN_network_cell_ids
# Out:
# array([ 611694145,  673763861,  796978752,  861937730,  892294329,
#         987117151, 1078517402, 1139909038, 1140245595, 1140249804,
#        1140923511, 1200286383, 1220416666, 1262014782, 1383111671,
#        1406798483, 1438515134, 1605518663, 1664127054, 1725924169,
#        1747625772, 1755198194, 1779343124, 1779696775, 1783915068,
#        1789613296, 1875181194, 1908356254, 5813022547, 5813022629,
#        5813042961, 5813050791, 5813054141, 5813057245, 5813125985])

# %%
adj = np.asarray(matrix)
adj.shape
# Out:
# (35, 35)

# %%
plt.figure(figsize=(10,10))
plt.imshow(adj,vmax=10)
plt.colorbar()

# %%
adj.shape
# Out:
# (17334, 17334)

# %%
file_name = os.path.join(connectome_dir, '20220813_DN_network.pkl')
matrix.to_pickle(file_name)

# %%
# adj_thresh = adj.copy()
# np.fill_diagonal(adj_thresh,0)
# threshold = 200
# adj_thresh[adj<threshold] = 0

thresh = 5000

list_a = list(np.where(np.sum(adj,axis=0) > thresh))[0]
list_b = list(np.where(np.sum(adj,axis=1) > thresh))[0]
to_keep = np.unique(list(list_a) + list(list_b))#np.intersect1d(list_a,list_b)
#to_keep = [i for i in range(adj.shape[0]) if i not in to_remove]

adj_thresh_valid = adj.copy()
adj_thresh_valid = adj_thresh_valid[to_keep,:]
adj_thresh_valid = adj_thresh_valid[:,to_keep]
adj_thresh_valid.shape
# Out:
# (186, 186)

# %%
cell_ids_valid = matrix.index[to_keep]

# %%
criteria = NC(bodyId=cell_ids_valid)
neuron_df, roi_counts_df = fetch_neurons(criteria)

# %%
len(list(neuron_df['instance']))
# Out:
# 186

# %%
plt.figure(figsize=(10,10))
plt.imshow(adj,vmax=100)
plt.colorbar()

# %%
G = nx.from_numpy_array(adj,create_using=nx.DiGraph)

forceatlas2 = ForceAtlas2(
                        # Behavior alternatives
                        outboundAttractionDistribution=True,  # Dissuade hubs
                        edgeWeightInfluence=.2,#0,#.2,

                        # Performance
                        jitterTolerance=1.0,  # Tolerance
                        barnesHutOptimize=True,
                        barnesHutTheta=1.2,

                        # Tuning
                        scalingRatio=2,#2, #How much repulsion you want. More makes a more sparse graph. Default=2
                        strongGravityMode=False,
                        gravity=1,#5,#1.0,

                        # Log
                        verbose=True)

# %%
positions = forceatlas2.forceatlas2_networkx_layout(G, pos=None, iterations=1000)
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 5999.85it/s]
# BarnesHut Approximation  took  0.03  seconds
# Repulsion forces  took  0.05  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.05  seconds
# AdjustSpeedAndApplyForces step  took  0.01  seconds

# %%
positions
# Out:
# {0: (25.715424315948866, 16.284356794912753),
#  1: (42.06468770319476, 10.102989553364502),
#  2: (57.74243267974393, 20.90129591207207),
#  3: (7.707127420507801, 17.935291223585594),
#  4: (26.489860212259295, 23.29779022100573),
#  5: (44.39202768132481, 36.573028767829676),
#  6: (31.562395437273153, 11.20373257790596),
#  7: (44.20812323596732, 22.857549237522054),
#  8: (36.36368250431141, 16.325989606629385),
#  9: (28.87294144994484, 34.11377869032274),
#  10: (67.02247024358702, 34.76057176537473),
#  11: (22.501627535107907, -9.809180233357445),
#  12: (86.77104120779691, 16.5659049916693),
#  13: (37.42816414134427, 5.32079751917737),
#  14: (24.800203035300704, 7.691658521815545),
#  15: (15.249903604014637, 51.90220646489133),
#  16: (57.7909346371198, -43.11025111754229),
#  17: (80.64810867081275, -20.71200728795789),
#  18: (53.208697246514106, -0.3527017155248867),
#  19: (69.39965430217299, 61.10559337029373),
#  20: (34.94170000121493, -26.38307592048634),
# ...

# %%
list(neuron_df['instance'])
# Out:
# ['AOTU012_R',
#  'AOTU016_R',
#  'LAL040(ADM03)_L',
#  'AOTU026_R',
#  'AOTU025_R',
#  'LAL010_R',
#  'PS011_R',
#  'DNa03_R',
#  'DNa02_R',
#  'LAL018_R',
#  'VES009_R',
#  'PS027_R',
#  None,
#  'DNa04_R',
#  'PS274_R',
#  '(PVM01)_L',
#  'PS231(PVM03)_L',
#  'AOTU019(ADM10)_L',
#  'PS049_R',
#  'IB068(PVM03)_L',
#  'WED075_R',
#  '(PVM01)_L',
#  'PLP230(PVM03)_L',
#  'LAL084(AVM09)_L',
#  '(PVM01)_L',
#  'LAL074(AVM07)_L',
#  'WED069_R',
#  '(PVM01)_L',
#  'PS059_R',
#  'PS013_R',
#  'LAL046_R',
#  'PS059_R',
#  'PLP029_R',
#  'VES008_R',
#  'PS018_R']

# %%
node_names = list(neuron_df['instance'])
DN_idx = []
for i, name in enumerate(node_names):
    if name is not None and 'DN' in name:
        DN_idx.append(i)

# %%
node_names_dict = {}
for i in range(len(node_names)):
    node_names_dict[i] = node_names[i]

# %%
widths = adj.flatten()
widths = [i/30 for i in widths if i >0]
widths = list(np.clip(widths,0,10))

# %%
plt.figure(figsize=(10,10))
#nx.draw_networkx_nodes(G, positions, node_size=100, node_color='k')
nx.draw_networkx_nodes(G, positions, node_size=200, node_shape='o')
nx.draw_networkx_nodes(G, positions, node_size=400, node_shape='v', nodelist=DN_idx)

nx.draw_networkx_edges(G, positions,
                       width=widths,
                       alpha=.1,
                       arrows=True,
                       arrowstyle='-|>',
                       arrowsize=10,
                       node_size=50,
                       edge_color='k',
                       style='solid') #, edge_color='k', alpha=0.1
#nx.draw_networkx_labels(G, positions, labels=node_names_dict, fontsize=50)

for node, (x, y) in positions.items():
    plt.text(x, y, node_names_dict[node], fontsize=8, ha='center', va='center')

plt.axis('off')
#plt.show()
save_path = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/figs'
timestr = time.strftime("%Y%m%d-%H%M%S")
fname = os.path.join(save_path, f'{timestr}')
#plt.savefig(fname,dpi=300,bbox_inches='tight')

# %%
positions
# Out:
# {0: (25.715424315948866, 16.284356794912753),
#  1: (42.06468770319476, 10.102989553364502),
#  2: (57.74243267974393, 20.90129591207207),
#  3: (7.707127420507801, 17.935291223585594),
#  4: (26.489860212259295, 23.29779022100573),
#  5: (44.39202768132481, 36.573028767829676),
#  6: (31.562395437273153, 11.20373257790596),
#  7: (44.20812323596732, 22.857549237522054),
#  8: (36.36368250431141, 16.325989606629385),
#  9: (28.87294144994484, 34.11377869032274),
#  10: (67.02247024358702, 34.76057176537473),
#  11: (22.501627535107907, -9.809180233357445),
#  12: (86.77104120779691, 16.5659049916693),
#  13: (37.42816414134427, 5.32079751917737),
#  14: (24.800203035300704, 7.691658521815545),
#  15: (15.249903604014637, 51.90220646489133),
#  16: (57.7909346371198, -43.11025111754229),
#  17: (80.64810867081275, -20.71200728795789),
#  18: (53.208697246514106, -0.3527017155248867),
#  19: (69.39965430217299, 61.10559337029373),
#  20: (34.94170000121493, -26.38307592048634),
# ...

# %%
positions2 = {}
for i in positions:
    positions2[i] = (positions[i][0], 20)

# %%
positions2
# Out:
# {0: (25.715424315948866, 20),
#  1: (42.06468770319476, 20),
#  2: (57.74243267974393, 20),
#  3: (7.707127420507801, 20),
#  4: (26.489860212259295, 20),
#  5: (44.39202768132481, 20),
#  6: (31.562395437273153, 20),
#  7: (44.20812323596732, 20),
#  8: (36.36368250431141, 20),
#  9: (28.87294144994484, 20),
#  10: (67.02247024358702, 20),
#  11: (22.501627535107907, 20),
#  12: (86.77104120779691, 20),
#  13: (37.42816414134427, 20),
#  14: (24.800203035300704, 20),
#  15: (15.249903604014637, 20),
#  16: (57.7909346371198, 20),
#  17: (80.64810867081275, 20),
#  18: (53.208697246514106, 20),
#  19: (69.39965430217299, 20),
#  20: (34.94170000121493, 20),
#  21: (1.254626153704578, 20),
#  22: (40.09400023313575, 20),
#  23: (27.52023853360144, 20),
#  24: (57.56577327644048, 20),
#  25: (24.843748860626796, 20),
#  26: (64.16841992548076, 20),
#  27: (68.06916495424207, 20),
#  28: (43.01412961996657, 20),
#  29: (32.57155727528997, 20),
#  30: (52.61484360170726, 20),
# ...

# %%
# 1) all DNs with their dice and the dice (or equivalent) of their partners
#        - 
# 2) top DNs and their specific cellular partners

# %%
DNa02_R = 1140245595
DNa03_R = 1139909038
DNa04_R = 1262014782

# %%
# lets use the dice of top 10 connected cells
# connection defined as % of the cell's synapses

# %%
rs = []
for key_cell in [1140245595]:#DN_ids:
    neuron_df, conn_df = fetch_adjacencies(None,NC(bodyId=key_cell));
    matrix = connection_table_to_matrix(conn_df, 'bodyId', sort_by='bodyId');
    
    synapse_counts = list(matrix.iloc[:,0])
    cells = list(matrix.index)
    
    ids = []
    syn_cnts = []
    for i,cell in enumerate(cells):
        try:
            idx = np.where(cell_ids==str(cell))[0][0]
            ids.append(idx)
            syn_cnts.append(synapse_counts[i])
        except:
            pass

    r_value = scipy.stats.pearsonr(dice[ids], syn_cnts)[0]
    print(r_value)
    rs.append(r_value)

# %%
rs = []
partner_dices = []
for key_cell in DN_ids:
    neuron_df, conn_df = fetch_adjacencies(None,NC(bodyId=key_cell));
    matrix = connection_table_to_matrix(conn_df, 'bodyId', sort_by='bodyId');

    synapse_counts = list(matrix.iloc[:,0])
    cells = list(matrix.index)

    ids = []
    syn_cnts = []
    for i,cell in enumerate(cells):
        try:
            idx = np.where(cell_ids==str(cell))[0][0]
            ids.append(idx)
            syn_cnts.append(synapse_counts[i])
        except:
            pass

    partner_dice = np.mean(all_neuron_dice[np.asarray(ids)[np.argsort(syn_cnts)[-10:]],1])
    partner_dices.append(partner_dice)
    r_value = scipy.stats.pearsonr(all_neuron_dice[ids,1], syn_cnts)[0]
    rs.append(r_value)
# Out:
# hi!
#      bodyId_pre  bodyId_post  weight  \
# 0    5901221363    295063181       1
# 1    5901196670    295063181       1
# 2    5813069648    295063181       9
# 3    5813067666    295063181       2
# 4    5813055822    295063181      46
# ..          ...          ...     ...
# 109   298262408    295063181       6
# 110   233105330    295063181       1
# 111   294424196    295063181       1
# 112   297247801    295063181      17
# 113   294161385    295063181       1
#
#                                                roiInfo
# 0    {'SNP(R)': {'pre': 1, 'post': 1}, 'SLP(R)': {'...
# 1    {'SNP(R)': {'pre': 1, 'post': 1}, 'SMP(R)': {'...
# 2    {'SNP(R)': {'pre': 9, 'post': 9}, 'SLP(R)': {'...
# 3    {'SNP(R)': {'pre': 2, 'post': 2}, 'SMP(R)': {'...
# 4    {'SNP(R)': {'pre': 46, 'post': 46}, 'SMP(R)': ...
# ..                                                 ...
# 109  {'SNP(R)': {'pre': 6, 'post': 6}, 'SMP(R)': {'...
# 110  {'SNP(R)': {'pre': 1, 'post': 1}, 'SLP(R)': {'...
# ...

# %%
DN_ids = list(neuron_df['bodyId'])
DN_names = list(neuron_df['instance'])

# %%
DN_idxs = []
DN_names_valid = []
partner_dices_valid = []
rs_valid = []
dices = []
for i,key_cell in enumerate(DN_ids):
    try:
        DN_idx = np.where(cell_ids==str(key_cell))[0][0]
        DN_idxs.append(DN_idx)
        DN_names_valid.append(DN_names[i])
        dices.append(all_neuron_dice[DN_idx, 1])
        partner_dices_valid.append(partner_dices[i])
        rs_valid.append(rs[i])
    except:
        pass

# %%
DN_idxs = []
DN_names_valid = []
partner_dices_valid = []
rs_valid = []
dices = []
for i,key_cell in enumerate(DN_ids):
    try:
        DN_idx = np.where(cell_ids==str(key_cell))[0][0]
        DN_idxs.append(DN_idx)
        DN_names_valid.append(DN_names[i])
        dices.append(all_neuron_dice[DN_idx, 0])
        partner_dices_valid.append(partner_dices[i])
        rs_valid.append(rs[i])
    except:
        pass

# %%
plt.figure(figsize=(10,10))
plt.plot(dices,partner_dices_valid,marker='x',linestyle='')
for i in range(len(dices)):
    if DN_names_valid[i] == 'DNb06_R':
        plt.text(dices[i], partner_dices_valid[i], DN_names_valid[i])
plt.xlim(0,.01)
plt.ylim(0,.06)
plt.xlabel('DN Dice')
plt.ylabel('DN partner dice')
# Out:
# Text(0, 0.5, 'DN partner dice')

# %%
plt.figure(figsize=(10,10))
plt.plot(dices,partner_dices_valid,marker='x',linestyle='')
for i in range(len(dices)):
    plt.text(dices[i], partner_dices_valid[i], DN_names_valid[i])
plt.xlim(0,.1)
plt.ylim(0,.1)
plt.xlabel('DN Dice')
plt.ylabel('DN partner dice')
# Out:
# Text(0, 0.5, 'DN partner dice')

# %%
# can we make an argument that the dice of its partners are higher than expected?
# take top 100 dice, calc partner dice

# %%
dice_thresh = .055#.075
beh = 1
thresh_idx = np.searchsorted(np.sort(all_neuron_dice[:,beh]), dice_thresh)
top_indicies = np.argsort(all_neuron_dice[:,beh])[thresh_idx:]
top_cell_ids = cell_ids[top_indicies]
top_cell_ids = [int(i) for i in top_cell_ids]
print(len(top_cell_ids))
# Out:
# 115

# %%
dices = np.sort(all_neuron_dice[:,beh])[thresh_idx:]
dices
# Out:
# array([0.05500982, 0.05514657, 0.05522633, 0.05556904, 0.05636008,
#        0.05652061, 0.05658462, 0.05669754, 0.05679885, 0.05722071,
#        0.05741837, 0.05752832, 0.05781106, 0.05788557, 0.0580173 ,
#        0.05822725, 0.05822877, 0.05837727, 0.05847953, 0.05852449,
#        0.05867243, 0.05868518, 0.05873569, 0.05875252, 0.0589172 ,
#        0.0594343 , 0.0595723 , 0.0596904 , 0.05976096, 0.05986696,
#        0.06015038, 0.0604336 , 0.06073496, 0.06074074, 0.06103405,
#        0.06108556, 0.06122186, 0.06151815, 0.06199688, 0.06210673,
#        0.06212425, 0.06253139, 0.06256684, 0.06259947, 0.06270968,
#        0.06303879, 0.06357215, 0.06391026, 0.06421053, 0.06457199,
#        0.06459506, 0.06487976, 0.06548026, 0.06549865, 0.06568901,
#        0.06613789, 0.06664889, 0.06720566, 0.06729428, 0.06737104,
#        0.0685525 , 0.06879485, 0.06905504, 0.06919192, 0.06927711,
#        0.07010566, 0.07044865, 0.07080554, 0.07095753, 0.07124951,
# ...

# %%
len(dices)
# Out:
# 115

# %%
ids
# Out:
# [11830,
#  11888,
#  11897,
#  11900,
#  11902,
#  11911,
#  12007,
#  12070,
#  12133,
#  12149,
#  12280,
#  12283,
#  12284,
#  12285,
#  12286,
#  12287,
#  12311,
#  12325,
#  12337,
#  12361,
#  12398,
#  12399,
#  12497,
#  12527,
#  12552,
#  12553,
#  12558,
#  12563,
#  12568,
#  12579,
#  12581,
#  12588,
#  12596,
#  12598,
#  12613,
#  12646,
#  12648,
#  12649,
#  12658,
#  12662,
#  12664,
#  12665,
#  12667,
#  12670,
#  12671,
#  12672,
#  12673,
#  12674,
#  12678,
#  12690,
#  12697,
#  12712,
#  12725,
#  12803,
#  12804,
#  12805,
#  12842,
#  12853,
#  12861,
#  12880,
#  12881,
#  12882,
#  12900,
#  12903,
#  12907,
#  12910,
#  12912,
#  12920,
#  12921,
#  12922,
#  12923,
#  12926,
#  12927,
#  12937,
#  12939,
#  12942,
#  12950,
#  12953,
#  12974,
#  12978,
#  12992,
#  12995,
#  12996,
#  12997,
#  12999,
#  13005,
#  13006,
#  13007,
#  13010,
#  13011,
#  13013,
#  13014,
#  13015,
#  13016,
#  13019,
#  13020,
#  13024,
#  13027,
#  13028,
#  13029,
# ...

# %%
rs = []
partner_dices = []

for key_cell in top_cell_ids:
    neuron_df, conn_df = fetch_adjacencies(None,NC(bodyId=key_cell));
    matrix = connection_table_to_matrix(conn_df, 'bodyId', sort_by='bodyId');

    synapse_counts = list(matrix.iloc[:,0])
    cells = list(matrix.index)

    ids = []
    syn_cnts = []
    for i,cell in enumerate(cells):
        try:
            idx = np.where(cell_ids==str(cell))[0][0]
            ids.append(idx)
            syn_cnts.append(synapse_counts[i])
        except:
            pass

    partner_dice = np.mean(all_neuron_dice[np.asarray(ids)[np.argsort(syn_cnts)[-10:]],1])
    partner_dices.append(partner_dice)
    r_value = scipy.stats.pearsonr(all_neuron_dice[ids,1], syn_cnts)[0]
    rs.append(r_value)
# Out:
# hi!
#       bodyId_pre  bodyId_post  weight  \
# 0     5901227238    799868224       6
# 1     5901213440    799868224       1
# 2     5901218567    799868224       9
# 3     5901217787    799868224       1
# 4     7112624733    799868224       2
# ...          ...          ...     ...
# 1174   356429209    799868224       8
# 1175   329566174    799868224       1
# 1176   326884223    799868224       1
# 1177   264014957    799868224       1
# 1178   263674097    799868224       2
#
#                                                 roiInfo
# 0     {'VMNP': {'pre': 4, 'post': 4}, 'VES(R)': {'pr...
# 1     {'INP': {'pre': 1, 'post': 1}, 'CRE(R)': {'pre...
# 2     {'VLNP(R)': {'pre': 9, 'post': 9}, 'AOTU(R)': ...
# 3     {'LX(R)': {'pre': 1, 'post': 1}, 'LAL(R)': {'p...
# 4     {'LX(R)': {'pre': 2, 'post': 2}, 'LAL(R)': {'p...
# ...                                                 ...
# 1174  {'SNP(R)': {'pre': 8, 'post': 8}, 'SMP(R)': {'...
# ...

# %%
plt.figure(figsize=(10,10))
plt.plot(dices,partner_dices_valid,marker='x',linestyle='')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-342-ac28a2921f2c> in <module>()
#       1 plt.figure(figsize=(10,10))
# ----> 2 plt.plot(dices,partner_dices_valid,marker='x',linestyle='')
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# ...

# %%
plt.figure(figsize=(10,10))
plt.plot(rs,partner_dices,marker='x',linestyle='')

# %%
all_neuron_dice[np.asarray(ids)[np.argsort(syn_cnts)[-10:]],1]
# Out:
# array([0.01905025, 0.07010566, 0.05303576, 0.03162155, 0.09180485,
#        0.07585081, 0.08335284, 0.08061908, 0.05111821, 0.06487976])

# %%
partner_dice = np.mean(all_neuron_dice[np.asarray(ids)[np.argsort(syn_cnts)[-10:]],1])

# %%
scipy.stats.pearsonr(all_neuron_dice[ids,1], syn_cnts)[0]
# Out:
# 0.34810337537747693

# %%
plt.figure(figsize=(10,10))
plt.plot(all_neuron_dice[ids,1],frac_syn,marker='o',linestyle='')
plt.xlabel('Neuron dice')
plt.ylabel('Synapses with DNa02')
# Out:
# Text(0, 0.5, 'Synapses with DNa02')

# %%
plt.figure(figsize=(10,10))
plt.plot(all_neuron_dice[ids,1],syn_cnts,marker='o',linestyle='')
plt.xlabel('Neuron dice')
plt.ylabel('Synapses with DNa02')
# Out:
# Text(0, 0.5, 'Synapses with DNa02')

# %%
synpervox.shape
# Out:
# (24691, 101, 84, 29)

# %%
synpercell = np.sum(synpervox,axis=(1,2,3))

# %%
synpercell.shape
# Out:
# (24691,)

# %%
cell_ids.shape
# Out:
# (24691,)

# %%
DNa02_R = 1140245595
DNa03_R = 1139909038
DNa04_R = 1262014782
DNb06 = 1715999506

# %%
key_cell = 1262014782
neuron_df, conn_df = fetch_adjacencies(None,NC(bodyId=key_cell));
matrix = connection_table_to_matrix(conn_df, 'bodyId', sort_by='bodyId');

synapse_counts = list(matrix.iloc[:,0])
cells = list(matrix.index)

ids = []
syn_cnts = []
cells_valid = []
for i,cell in enumerate(cells):
    try:
        idx = np.where(cell_ids==str(cell))[0][0]
        ids.append(idx)
        syn_cnts.append(synapse_counts[i])
        cells_valid.append(cells[i])
    except:
        pass

# partner_dice = np.mean(all_neuron_dice[np.asarray(ids)[np.argsort(syn_cnts)[-10:]],1])
# partner_dices.append(partner_dice)
# r_value = scipy.stats.pearsonr(all_neuron_dice[ids,1], syn_cnts)[0]
# rs.append(r_value)
# Out:
# hi!
#      bodyId_pre  bodyId_post  weight  \
# 0    5901227238   1262014782       2
# 1    5813092338   1262014782       3
# 2    5901205733   1262014782      10
# 3    5901230859   1262014782      11
# 4    7112616299   1262014782       1
# ..          ...          ...     ...
# 838   449296405   1262014782       1
# 839   262840563   1262014782       1
# 840   262517074   1262014782       6
# 841   232513671   1262014782       3
# 842   262167456   1262014782       2
#
#                                                roiInfo
# 0    {'VMNP': {'pre': 1, 'post': 1}, 'SPS(R)': {'pr...
# 1    {'VMNP': {'pre': 2, 'post': 2}, 'SPS(R)': {'pr...
# 2                     {'GNG': {'pre': 10, 'post': 10}}
# 3    {'VMNP': {'pre': 11, 'post': 11}, 'SPS(R)': {'...
# 4    {'VLNP(R)': {'pre': 1, 'post': 1}, 'PLP(R)': {...
# ..                                                 ...
# 838  {'VMNP': {'pre': 1, 'post': 1}, 'SPS(R)': {'pr...
# 839  {'VMNP': {'pre': 1, 'post': 1}, 'IPS(R)': {'pr...
# ...

# %%
dn4_partners = np.asarray(cells_valid)[np.argsort(syn_cnts)[-20:]]

# %%
criteria = NC(instance='AOTU016_R')
neuron_df, roi_counts_df = fetch_neurons(criteria)
neuron_df
# Out:
#       bodyId   instance     type  pre  post  downstream  upstream  mito  \
# 0  673763861  AOTU016_R  AOTU016  336  1685        2518      1685   224
# 1  831225810  AOTU016_R  AOTU016  261   994        2061       994   144
# 2  861246683  AOTU016_R  AOTU016  341  1196        2837      1196   182
# 3  861260193  AOTU016_R  AOTU016  342  1304        2855      1304   188
# 4  862274410  AOTU016_R  AOTU016  326  1202        2633      1202   196
#
#         size  status  cropped     statusLabel cellBodyFiber  somaRadius  \
# 0  881149912  Traced    False  Roughly traced         ADM05       292.5
# 1  509905365  Traced    False  Roughly traced         ADM05       292.5
# 2  635915929  Traced    False  Roughly traced         ADM05       292.5
# 3  653176179  Traced    False  Roughly traced         ADM05       292.5
# 4  691381747  Traced    False  Roughly traced         ADM05       386.5
#
#             somaLocation                                            roiInfo  \
# ...

# %%
criteria = NC(bodyId=dn2_partners)
neuron_df, roi_counts_df = fetch_neurons(criteria)
print(neuron_df['bodyId'],neuron_df['instance'])
#list(neuron_df['instance'])
# Out:
# 0      611694145
# 1      796978752
# 2      892294329
# 3      987117151
# 4     1078517402
# 5     1139909038
# 6     1140249804
# 7     1140923511
# 8     1220416666
# 9     1406798483
# 10    1605518663
# 11    1664127054
# 12    1725924169
# 13    1783915068
# 14    1908356254
# 15    5813022547
# 16    5813022629
# 17    5813042961
# 18    5813050791
# 19    5813057245
# Name: bodyId, dtype: int64 0            AOTU012_R
# 1      LAL040(ADM03)_L
# 2            AOTU025_R
# 3             LAL010_R
# 4              PS011_R
# 5              DNa03_R
# 6             LAL018_R
# 7             VES009_R
# 8                 None
# 9            (PVM01)_L
# 10    AOTU019(ADM10)_L
# 11             PS049_R
# 12      IB068(PVM03)_L
# 13           (PVM01)_L
# 14           (PVM01)_L
# 15             PS059_R
# 16             PS013_R
# 17            LAL046_R
# 18             PS059_R
# 19            VES008_R
# Name: instance, dtype: object

# %%
criteria = NC(bodyId=dn2_partners)
neuron_df, roi_counts_df = fetch_neurons(criteria)
print(len(neuron_df['bodyId']))
list(neuron_df['instance'])
# Out:
# 20
# ['AOTU016_R',
#  'AOTU026_R',
#  'PS011_R',
#  'LAL018_R',
#  'PS027_R',
#  'PS274_R',
#  'PS231(PVM03)_L',
#  'AOTU019(ADM10)_L',
#  'WED075_R',
#  '(PVM01)_L',
#  'PLP230(PVM03)_L',
#  'LAL084(AVM09)_L',
#  'LAL074(AVM07)_L',
#  'WED069_R',
#  'PS059_R',
#  'PS013_R',
#  'LAL046_R',
#  'PS059_R',
#  'PLP029_R',
#  'PS018_R']

# %%
neuron_df, conn_df = fetch_adjacencies(NC(bodyId=DN_network_cell_ids),NC(bodyId=DN_network_cell_ids));
matrix = connection_table_to_matrix(conn_df, 'bodyId', sort_by='bodyId');

# %%
idx = []
for cell in DN_network_cell_ids:
    idx.append(np.where(cell_ids==str(cell))[0][0])

# %%
idx
# Out:
# [20154,
#  20882,
#  22354,
#  23057,
#  23454,
#  24675,
#  957,
#  1693,
#  1708,
#  1709,
#  1728,
#  2546,
#  2695,
#  3337,
#  4439,
#  4557,
#  4833,
#  6325,
#  6836,
#  7790,
#  8025,
#  8233,
#  8454,
#  8461,
#  8532,
#  8628,
#  9501,
#  9761,
#  17473,
#  17480,
#  18069,
#  18306,
#  18356,
#  18565,
#  19497]

# %%
plt.figure(figsize=(10,10))
plt.imshow(np.max(synpervox[1708,...],axis=2).T)
plt.colorbar()

# %%
#plt.figure(figsize=(10,10))
plt.imshow(np.max(np.sum(synpervox[idx,...],axis=0),axis=2).T,vmax=100)
plt.colorbar()

# %%
plt.imshow(np.max(unique_crop[...,1],axis=2).T,vmax=.05)

# %%
plt.figure(figsize=(10,10))
plt.imshow(np.max(synpervox[7629,...],axis=2).T)
plt.colorbar()
