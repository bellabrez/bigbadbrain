# %%
from numpy import genfromtxt
import numpy as np
import h5py
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
load_file = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20180301/fly1/photodiode.csv'
load_file = '/oak/stanford/groups/trc/data/Brezovec/2P_Imaging/20180227/fly1/photodiode.csv'
load_file = '/oak/stanford/groups/trc/data/Jolie/2P_Imaging/20201130/fly1/func0/TSeries-20201130-001_Cycle00001_VoltageRecording_001.csv'

# %%
temp = np.genfromtxt(load_file, delimiter=',',skip_header=1, max_rows=10000000)
# t = temp[:,0]
# pd1 = temp[:,1]
# pd2 = temp[:,2]
# print('done')

# %%
plt.figure(figsize=(10,10))
plt.plot(temp[:,2])
plt.plot(temp[:,1])
plt.xlim(10000,50000)
# Out:
# (10000, 50000)

# %%
plt.figure(figsize=(10,10))
plt.plot(temp[:,2]-temp[:,1])
#plt.xlim(200000,400000)

# %%
with h5py.File(load_file, 'r') as hf:
    t = hf['time'][:]
    pd1 = hf['pd1'][:]
    pd2 = hf['pd2'][:]
print('done')
return t, pd1, pd2
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-20-32c32bd5ecfa> in <module>()
# ----> 1 with h5py.File(load_file, 'r') as hf:
#       2     t = hf['time'][:]
#       3     pd1 = hf['pd1'][:]
#       4     pd2 = hf['pd2'][:]
#       5 print('done')
#
# ~/.local/lib/python3.6/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, **kwds)
#     310             with phil:
#     311                 fapl = make_fapl(driver, libver, **kwds)
# --> 312                 fid = make_fid(name, mode, userblock_size, fapl, swmr=swmr)
#     313
#     314                 if swmr_support:
#
# ~/.local/lib/python3.6/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     140         if swmr and swmr_support:
#     141             flags |= h5f.ACC_SWMR_READ
# ...
